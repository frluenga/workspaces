# %%
import scipy.stats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('bicicletas-compartidas.csv')

# %% [markdown]
# ## Categoricas

# %%
y = df['cuartil-ano'].apply(lambda x: 'cuartil-' + str(int(x)))

# %%
fig,axes = plt.subplots()
axes.bar(y.value_counts().index,y.value_counts())
axes.set_xlabel('Cuartiles del año')
axes.set_ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
fig,axes = plt.subplots()
axes.bar(y.value_counts().index,y.value_counts())
axes.set_xlabel('Cuartiles del año')
axes.set_ylabel('Frecuencia')
axes.patches[3].set_facecolor('red') # Llamar los patches es los valores que toma la variable

# %%
fig,ax = plt.subplots()
ax.pie(y.value_counts(),labels = y.value_counts().index)
ax.set_title('Diagrama de pie')
# Out:
# Text(0.5, 1.0, 'Diagrama de pie')

# %% [markdown]
# ## Numericas

# %%
y = df['viento']

# %%
fig,ax = plt.subplots()
ax.hist(y,bins = 30)
ax.set_xlabel('Viento')
ax.set_ylabel('Frecuencias')
plt.axvline(np.mean(y),c = 'r',linestyle = '--',label = 'Prom')
plt.axvline(np.mean(y) + np.std(y),c='k',linestyle='--',label = 'std + 1')
plt.axvline(np.mean(y) - np.std(y),c='k',linestyle='--',label = 'std + 1')
plt.legend()
plt.show()

# %% [markdown]
# # Boxplot y Scatterplot

# %%
y = df['bicis-compartidas']
fig,ax = plt.subplots()
sns.boxplot(x = 'cuartil-ano',y = 'bicis-compartidas',data = df)
plt.show()

# %%
fig,ax = plt.subplots()
cs = ax.scatter(df['viento'],df['bicis-compartidas'],c = df['bicis-compartidas'],cmap='viridis')
ax.set_title('Distribución Conjunta de Viento y Bicis Compartidas')
fig.colorbar(cs,ax=ax)
ax.grid(color='gray',linestyle='--', linewidth = 0.5)
ax.set_xlabel('Viento')
ax.set_ylabel('Bicis Compartidas')

ax.plot()
# Out:
# []
