# %% [markdown]
# # Solicitudes a la web

# %% [markdown]
# #### Libreria requests

# %%
import requests

# El metodo get retorna un objeto de respuesta al intentar
#conectarse a la web
response = requests.get('https://www.platzi.com')

# Se puede obtener metodos para el objeto
# Ver la respuesta
response?
# Codigo fuente
response??
#Ver todos los metodos
print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
# Retorna el atributo codigo de estado de la respuesta
print(response.status_code)
# Out:
# 200

# %%
# Retorna metadatos como tipo diccionario
print(response.headers),print(response.headers['date'])
# Out:
# {'Date': 'Thu, 03 Jun 2021 15:45:55 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'CF-Ray': '659a0d1ecdd73714-MIA', 'Access-Control-Allow-Origin': '*', 'Age': '12329', 'Cache-Control': 'no-store', 'Expires': 'Fri, 03 Jun 2022 15:45:55 GMT', 'Strict-Transport-Security': 'max-age=2592000; includeSubDomains; preload', 'Vary': 'Accept-Encoding', 'CF-Cache-Status': 'HIT', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Headers': 'X-Requested-With,content-type,X-CSRFToken', 'Access-Control-Allow-Methods': 'GET, POST', 'cf-request-id': '0a7426874100003714438a2000000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'X-Content-Type-Options': 'nosniff', 'X-DNS-Prefetch-Control': 'off', 'X-Download-Options': 'noopen', 'X-Frame-Options': 'SAMEORIGIN', 'X-Permitted-Cross-Domain-Policies': 'none', 'X-XSS-Protection': '1; mode=block', 'Server': 'cloudflare', 'Content-Encoding': 'gzip'}
# Thu, 03 Jun 2021 15:45:55 GMT
# (None, None)

# %%
print(response.text)
# Out:
#       <!DOCTYPE html>
#       <html lang=es>
#         <head>
#           <meta charset="UTF-8">
#
#
#     <link rel="canonical" href="https://platzi.com" />
#     <link rel="alternate" hreflang="x-default" href="https://platzi.com">
#     <link rel="alternate" hreflang="es" href="https://platzi.com">
#     <link rel="alternate" hreflang="pt" href="https://platzi.com.br">
#     <link rel="alternate" hreflang="en" href="https://courses.platzi.com">
#
#
#           <meta name="viewport" content="width=device-width, initial-scale=1" />
#           <meta name="referrer" content="no-referrer-when-downgrade">
#           <title>Platzi: ‎Cursos Online Profesionales de Tecnología</title>
#           <link data-chunk="components-NeverStop-NeverStop-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-NeverStop-NeverStop-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-Prizes-Prizes-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-Prizes-Prizes-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-B2B-B2B-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/6727.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="app-commons-Testimonies-Testimonies-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/app-commons-Testimonies-Testimonies-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="app-commons-Community" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/app-commons-Community.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="app-commons-LearningExperience" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/app-commons-LearningExperience.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-RecentLaunches-RecentLaunches-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-RecentLaunches-RecentLaunches-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-Schools-Schools-jsx" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/components-Schools-Schools-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="app-commons-TrustedList" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/app-commons-TrustedList.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="home-public" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/home-public.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="home-public" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/9612.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="home-public" rel="preload" as="style" href="https://static.platzi.com/mf-landings/assets/8571.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6126.f3a59cc3313eef232d35.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/9669.d1e2f3b8fa78e2787a07.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/1620.36c1cb07cea190913e27.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/4006.3bb8e264445f5619b691.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/8001.32d84d2b8ef3c5503979.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/4373.0a0263fdbfefb104bb63.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6486.f851b5b030dff11f4b10.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/3376.f8d3d1baaaac3c3921fc.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6066.d48f9f4b3702eedade65.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/7199.06cf0c15ee00a8557c33.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6838.d410234b67f3d29058a0.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/230.9941b5b943d31843f825.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/8571.bf99ef8cb7ba68ffe287.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/4559.aff5e553e3541fdaa62f.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/8538.a1c8c37e4d9ae6a63df7.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/1813.c245ca13508b04c768ff.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/5591.751546257a7a44267a98.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/1586.889a46b5da78cb23dd54.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/7305.c0c2cf8a219ebadebe0d.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/381.8497f60b8ec770d2b77c.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/9527.ab6047d475b021004c56.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/8786.8d4c09c540d61d6ab488.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/99.7cea736da192c33ecfc1.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/9224.43b63de854bb90d3ffa7.js">
# <link data-chunk="home-public" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/home-public.7c3f851ac65ec2a6cbe3.js">
# <link data-chunk="app-commons-TrustedList" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/app-commons-TrustedList.0657748bbe01e62e97be.js">
# <link data-chunk="components-Schools-Schools-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-Schools-Schools-jsx.1a31c6ac242472f2c5bb.js">
# <link data-chunk="components-RecentLaunches-RecentLaunches-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-RecentLaunches-RecentLaunches-jsx.76949b4d3588712f626c.js">
# <link data-chunk="app-commons-LearningExperience" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/app-commons-LearningExperience.6d22d993297728bec2cd.js">
# <link data-chunk="app-commons-Community" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/app-commons-Community.aa618d5a46915cc47b8b.js">
# <link data-chunk="app-commons-Testimonies-Testimonies-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/1465.9a7a7111ea42f57fde8a.js">
# <link data-chunk="app-commons-Testimonies-Testimonies-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/app-commons-Testimonies-Testimonies-jsx.af49a473b42564abb15d.js">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/6727.af93a2e6f205350f8c60.js">
# <link data-chunk="components-B2B-B2B-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-B2B-B2B-jsx.dae6387a87e56253af98.js">
# <link data-chunk="components-Prizes-Prizes-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-Prizes-Prizes-jsx.bd1c9c8b404d0fca7249.js">
# <link data-chunk="components-NeverStop-NeverStop-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/7248.68fa588de87b021cb0f8.js">
# <link data-chunk="components-NeverStop-NeverStop-jsx" rel="preload" as="script" href="https://static.platzi.com/mf-landings/assets/components-NeverStop-NeverStop-jsx.e6f7b120b81457fb46c3.js">
#           <link data-chunk="home-public" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/8571.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="home-public" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/9612.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="home-public" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/home-public.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="app-commons-TrustedList" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/app-commons-TrustedList.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-Schools-Schools-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-Schools-Schools-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-RecentLaunches-RecentLaunches-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-RecentLaunches-RecentLaunches-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="app-commons-LearningExperience" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/app-commons-LearningExperience.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="app-commons-Community" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/app-commons-Community.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="app-commons-Testimonies-Testimonies-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/app-commons-Testimonies-Testimonies-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-B2B-B2B-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/6727.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-B2B-B2B-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-B2B-B2B-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-Prizes-Prizes-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-Prizes-Prizes-jsx.9b9d80ee0103f3d15e5b.css">
# <link data-chunk="components-NeverStop-NeverStop-jsx" rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/components-NeverStop-NeverStop-jsx.9b9d80ee0103f3d15e5b.css">
#           <link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" />
#           <link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png">
#           <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" />
#
#     <meta name="description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!">
#     <meta name="theme-color" content="#15210B" />
#
#     <meta property="fb:app_id" content="263680607075199" />
#     <meta property="fb:admins" content="1030603473" />
#     <meta property="og:description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!"/>
#     <meta property="og:title" content="Platzi: ‎Cursos Online Profesionales de Tecnología" />
#     <meta property="og:type" content="website" />
#     <meta property="og:url" content="https://platzi.com" />
#     <meta property="og:image" content="https://static.platzi.com/media/meta_tags/og/OG-platzi-Dic-2019.png" />
#     <meta property="og:site_name" content="https://platzi.com" />
#
#     <meta property="twitter:account_id" content="4503599630205252" />
#     <meta name="twitter:card" content="summary_large_image" />
#     <meta name="twitter:site" content="@Platzi" />
#     <meta name="twitter:title" content="Platzi: ‎Cursos Online Profesionales de Tecnología" />
#     <meta name="twitter:description" content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!" />
#     <meta name="twitter:creator" content="@Platzi" />
#     <meta name="twitter:image" content="https://static.platzi.com/media/meta_tags/og/OG-platzi-Dic-2019.png" />
#     <meta name="twitter:domain" content="https://platzi.com" />
#
#     <meta name="p:domain_verify" content="7b60446823db932528d0528d4cb50e66" />
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/highlight.js/9.2.0/styles/monokai.min.css" rel="stylesheet" />
#     <link href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-svg-core@1.2.28/styles.css" rel="stylesheet" />
#
#
#     <script rel="preconnect" async>
#       (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#           (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#           m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#       })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#       window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#       null
#       //Platzi LATAM
#
#         ga('create', 'UA-76863-18', 'auto', 'platziPublicES');
#         ga('create', 'UA-76863-27', 'auto', 'platziFull');
#         // Require Plugins for platziPublicES
#         ga('platziPublicES.require', 'ecommerce');
#         ga('platziPublicES.require', 'outboundLinkTracker');
#         ga('platziPublicES.require', 'socialWidgetTracker');
#         // Require Plugins for platziFull
#         ga('platziFull.require', 'ecommerce');
#         ga('platziFull.require', 'outboundLinkTracker');
#         ga('platziFull.require', 'socialWidgetTracker');
#         null
#         //Send Pageview
#         ga('platziPublicES.send', 'pageview');
#         ga('platziFull.send', 'pageview');
#         null
#
#       //Platzi USA
#       null
#       //Platzi Brazil
#       null
#     </script>
#     <script rel="preconnect" async src="https://www.googletagmanager.com/gtag/js?id=AW-759649979"></script>
#     <script async>
#       window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#       gtag('config', 'AW-759649979');
#     </script>
#     <!-- Anti-flicker snippet  -->
#     <script>
#       (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;h.start=1*new Date;
#       h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
#       (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);h.timeout=c;
#       })(window,document.documentElement,'async-hide','dataLayer',4000,
#       {'GTM-MPT6TFW':true});
#     </script>
#     <!------>
#     <!-- GTM Second Stage -->
#     <script defer>
#       (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#       new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#       j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#       'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#       })(window,document,'script','dataLayer','GTM-MPT6TFW');
#     </script>
#     <!-- End GTM Second Stage -->
#     <!-- Autotrack plugin for Google Analytics -->
#     <script rel="preconnect" async src="https://cdnjs.cloudflare.com/ajax/libs/autotrack/2.4.1/autotrack.js"></script>
#     <!-- Facebook Pixel Code -->
#     <script rel="preconnect" async>
#       !function(f,b,e,v,n,t,s)
#       {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#         n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#         if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#         n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];
#         s.parentNode.insertBefore(t,s)}(window, document,'script',
#         'https://connect.facebook.net/en_US/fbevents.js');
#       fbq('init', '1545967215651797');
#       fbq('track', 'PageView');
#       null
#     </script>
#     <noscript>
#       <img
#         height="1"
#         width="1"
#         style="display:none"
#         src="https://www.facebook.com/tr?id=1545967215651797&ev=PageView&noscript=1"
#       />
#     </noscript>
#     <script rel="preconnect" async type="text/javascript">
#       _linkedin_data_partner_id = "274754";
#       </script><script type="text/javascript" async>
#       (function(){var s = document.getElementsByTagName("script")[0];
#       var b = document.createElement("script");
#       b.type = "text/javascript";b.async = true;
#       b.src = "https://snap.licdn.com/li.lms-analytics/insight.min.js";
#       s.parentNode.insertBefore(b, s);})();
#     </script>
#     <noscript>
#       <img height="1" width="1" style="display:none;" alt="" src="https://dc.ads.linkedin.com/collect/?pid=274754&fmt=gif" />
#     </noscript>
#     <!-- End Analytics and FB Pixel Code -->
#     <!-- Reddit Conversion Pixel -->
#     <script rel="preconnect" async>
#       !function(w,d){if(!w.rdt){var p=w.rdt=function(){p.sendEvent?p.sendEvent.apply(p,arguments):p.callQueue.push(arguments)};p.callQueue=[];var t=d.createElement("script");t.src="https://www.redditstatic.com/ads/pixel.js",t.async=!0;var s=d.getElementsByTagName("script")[0];s.parentNode.insertBefore(t,s)}}(window,document);rdt('init','t2_3b2gfq1n');rdt('track', 'PageVisit');
#     </script>
#     <!-- DO NOT MODIFY -->
#     <!-- End Reddit Conversion Pixel -->
#     <!-- Twitter universal website tag code -->
#     <script rel="preconnect" async>
#       !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);
#       },s.version='1.1',s.queue=[],u=t.createElement(n),u.async=!0,u.src='//static.ads-twitter.com/uwt.js',
#           a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,'script');
#       // Insert Twitter Pixel ID and Standard Event data below
#       twq('init','nyfpx');
#       twq('track','PageView');
#     </script>
#     <!-- End Twitter universal website tag code -->
#     <!-- Structured data -->
#     <script type="application/ld+json">
#       {
#         "@context": "http://schema.org",
#         "@type": "BreadcrumbList",
#         "itemListElement":
#           [{
#             "@type": "ListItem",
#             "position": 1,
#             "item":
#               {
#                 "@id": "https://platzi.com/",
#                 "name": "🚀 Platzi: ‎Cursos Online Profesionales de Tecnología"
#               }
#             }]
#       }
#     </script>
#     <!-- END Structured data -->
#
#         <script async src='/cdn-cgi/bm/cv/669835187/api.js'></script></head>
#         <body>
#           <div id="home-public"><div class="BaseLayout"><div class="Modal"><div class="Modal-wrapper"></div></div><div class="Header-v2 Header-v2-content is-dark-header"><div class="Logo"><div class="LogoHeader"><a href="/" class="LogoHeader-link"><div class="LogoHeader-container"><figure><img loading="lazy" src="https://static.platzi.com/commons/assets/image/isotipoPlatzi093f27a2fb00922bb105.png" alt="Platzi isotipo" height="25"/></figure><figure class="LogoHeader-name"><img loading="lazy" src="https://static.platzi.com/commons/assets/image/logotipo-platzie69328f33899695e31fa.png" alt="Platzi Logo" height="25"/></figure></div></a></div></div><div class="Nav-header"><div class="Actionsv2"><a class="Actionsv2-enterprise" href="/empresas/">Empresas</a></div><div class="Menu"><div class="Menu-dropdown" role="button" tabindex="0"><div class="Menu-title"><span>Menú</span></div></div><div class="Menu-content"><div><ul class="Menu-list"><li class="Menu-list-item"><a href="/cursos/"><div>Cursos</div></a></li><li class="Menu-list-item"><a href="/blog/"><div>Blog</div></a></li><li class="Menu-list-item"><a href="/foro/"><div>Foro</div></a></li><li class="Menu-list-item"><a href="/agenda/"><div>Agenda</div></a></li><li class="Menu-list-item"><a href="/live/"><div>TV</div></a></li><li class="Menu-list-item"><a href="/precios/"><div>Planes</div></a></li><li class="Menu-list-item"><div role="button" tabindex="0"><div>Contáctanos</div></div></li></ul></div></div></div><div class="ButtonLogin showButton"><div><a href="/login/" class="ButtonLogin-cta">Iniciar sesión</a></div></div><div class="MiniSearch is-tablet"><div class="MiniSearch-button MiniSearch-show" role="button" tabindex="0"><svg aria-hidden="true" focusable="false" data-prefix="far" data-icon="search" class="svg-inline--fa fa-search fa-w-16 " role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path fill="currentColor" d="M508.5 468.9L387.1 347.5c-2.3-2.3-5.3-3.5-8.5-3.5h-13.2c31.5-36.5 50.6-84 50.6-136C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c52 0 99.5-19.1 136-50.6v13.2c0 3.2 1.3 6.2 3.5 8.5l121.4 121.4c4.7 4.7 12.3 4.7 17 0l22.6-22.6c4.7-4.7 4.7-12.3 0-17zM208 368c-88.4 0-160-71.6-160-160S119.6 48 208 48s160 71.6 160 160-71.6 160-160 160z"></path></svg></div></div><div class="MiniSearch is-desktop"><div class="Searchv"><div class="Searchv-content"><form action="/search/" class=""><input type="text" placeholder="Buscar en Platzi" aria-label="Buscar en Platzi" name="search" id="search" autoComplete="off"/><button class="Searchv-icon" aria-label="Buscar en Platzi" tabindex="0"><svg aria-hidden="true" focusable="false" data-prefix="far" data-icon="search" class="svg-inline--fa fa-search fa-w-16 " role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 512 512"><path fill="currentColor" d="M508.5 468.9L387.1 347.5c-2.3-2.3-5.3-3.5-8.5-3.5h-13.2c31.5-36.5 50.6-84 50.6-136C416 93.1 322.9 0 208 0S0 93.1 0 208s93.1 208 208 208c52 0 99.5-19.1 136-50.6v13.2c0 3.2 1.3 6.2 3.5 8.5l121.4 121.4c4.7 4.7 12.3 4.7 17 0l22.6-22.6c4.7-4.7 4.7-12.3 0-17zM208 368c-88.4 0-160-71.6-160-160S119.6 48 208 48s160 71.6 160 160-71.6 160-160 160z"></path></svg></button></form></div><div class="Searchv-results"></div></div></div></div></div><div class="PromoBanner" style="background:linear-gradient(180deg, #000948 0%, #321B5E 100%)"><div class="PromoBanner-content u-wrapper PromoBanner-pre"><div class="PromoBanner-top"><figure class="PromoBanner-figure is-mobile"><img src="https://static.platzi.com/media/promos/platzi-day-logo.png" alt="Platzi"/><div class="PromoBanner-special" style="color:#FFFFFF"><strong>Platzi Expert a un precio especial</strong></div></figure><figure class="PromoBanner-figure is-desktop"><img src="https://static.platzi.com/media/promos/platzi-day-logo.png" alt="Platzi"/></figure><div class="PromoBanner-details" style="color:#FFFFFF"><div class="PromoBanner-details-saving"><div class="PromoBanner-details-saving-layout"><p>Acceso libre a todos los cursos de P ...
#
# </p></div></div></li><li><div class="Testimonies-testimony"><div class="Testimonies-testimony-avatar"><img loading="lazy" class="Testimonies-testimony-avatar-picture" src="https://static.platzi.com/media/testimony/aleyda-solis.jpg" alt="Aleyda Solis"/><img loading="lazy" class="Testimonies-testimony-avatar-country" src="https://static.platzi.com/media/flags/ES.png" alt="País de origen de Aleyda Solis"/></div><div class="Testimonies-testimony-info"><p class="Testimonies-testimony-info-name">Aleyda Solis</p><p class="Testimonies-testimony-info-profile">aleyda</p></div><div class="Testimonies-testimony-content"><p>Confío en Platzi porque sé que hay una dedicación para que el contenido que se le da a los estudiantes sea el mejor.</p></div></div></li><li><div class="Testimonies-testimony"><div class="Testimonies-testimony-avatar"><img loading="lazy" class="Testimonies-testimony-avatar-picture" src="https://static.platzi.com/media/testimony/IMG_8287.jpg" alt="Jonathan Alcantara"/><img loading="lazy" class="Testimonies-testimony-avatar-country" src="https://static.platzi.com/media/flags/ES.png" alt="País de origen de Jonathan Alcantara"/></div><div class="Testimonies-testimony-info"><p class="Testimonies-testimony-info-name">Jonathan Alcantara</p><p class="Testimonies-testimony-info-profile">jalcantara</p></div><div class="Testimonies-testimony-content"><p>Gracias a Platzi, en un plazo de 2 años y medios he pasado de no haber programado nunca a ser Tech. Lead de un equipo de 9 personas realizando un ERP para una gran empresa multinacional.</p></div></div></li></ul><div class="Testimonies-gallery-arrows"><button class="Testimonies-gallery-arrows-left" type="button" aria-label="previous"><svg aria-hidden="true" focusable="false" data-prefix="far" data-icon="angle-left" class="svg-inline--fa fa-angle-left fa-w-6 " role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 192 512"><path fill="currentColor" d="M4.2 247.5L151 99.5c4.7-4.7 12.3-4.7 17 0l19.8 19.8c4.7 4.7 4.7 12.3 0 17L69.3 256l118.5 119.7c4.7 4.7 4.7 12.3 0 17L168 412.5c-4.7 4.7-12.3 4.7-17 0L4.2 264.5c-4.7-4.7-4.7-12.3 0-17z"></path></svg></button><button class="Testimonies-gallery-arrows-right" type="button" aria-label="next"><svg aria-hidden="true" focusable="false" data-prefix="far" data-icon="angle-right" class="svg-inline--fa fa-angle-right fa-w-6 " role="img" xmlns="http://www.w3.org/2000/svg" viewBox="0 0 192 512"><path fill="currentColor" d="M187.8 264.5L41 412.5c-4.7 4.7-12.3 4.7-17 0L4.2 392.7c-4.7-4.7-4.7-12.3 0-17L122.7 256 4.2 136.3c-4.7-4.7-4.7-12.3 0-17L24 99.5c4.7-4.7 12.3-4.7 17 0l146.8 148c4.7 4.7 4.7 12.3 0 17z"></path></svg></button></div><div class="Testimonies-gallery-dots"><ul><li><button class="Testimonies-gallery-dots-button" aria-label="Ver el testimonio de Mariana Valencia"><img loading="lazy" src="https://static.platzi.com/media/testimony/mariana_tiny.jpg" alt="Mariana Valencia" class="dot-active"/></button></li><li><button class="Testimonies-gallery-dots-button" aria-label="Ver el testimonio de Mónica Castillo"><img loading="lazy" src="https://static.platzi.com/media/testimony/20150816_154615_1.jpg" alt="Mónica Castillo"/></button></li><li><button class="Testimonies-gallery-dots-button" aria-label="Ver el testimonio de Vicky O&#x27;Shee"><img loading="lazy" src="https://static.platzi.com/media/testimony/victoria-avatar.38668af96859.jpg" alt="Vicky O&#x27;Shee"/></button></li><li><button class="Testimonies-gallery-dots-button" aria-label="Ver el testimonio de Daniel Prol"><img loading="lazy" src="https://static.platzi.com/media/testimony/daniel-prol.jpg" alt="Daniel Prol"/></button></li><li><button class="Testimonies-gallery-dots-button" aria-label="Ver el testimonio de Josué Manuel Echandia"><img loading="lazy" src="https://static.platzi.com/media/testimony/josue.jpg" alt="Josué Manuel Echandia"/></button></li><li><button class="Testimonies-gallery-dots-button" aria-label="Ver el testimonio de Ana Lima"><img loading="lazy" src="https://static. ...
#           <script id="preloadedState">window.__PRELOADED_STATE__ = {"prizes":[{"year":"2015","data":[{"logo":"YC","text":"home-public.prizes.yc"}]},{"year":"2016","data":[{"logo":"endevor","text":"home-public.prizes.endevor"}]},{"year":"2017","data":[{"logo":"mintic","text":"home-public.prizes.mintic"}]},{"year":"2018","data":[{"logo":"entrepreneur","text":"home-public.prizes.entrepreneur"},{"logo":"bestStartup","text":"home-public.prizes.bestStartup"}]},{"year":"2019","data":[{"logo":"unity","text":"home-public.prizes.unity"},{"logo":"endevor","text":"home-public.prizes.endevorTwo"}]}],"header":{"enableSubscription":true,"menuItems":[{"name":"Cursos","url":"/cursos/"},{"name":"Blog","url":"/blog/"},{"name":"Foro","url":"/foro/"},{"name":"Agenda","url":"/agenda/"},{"name":"TV","url":"/live/"},{"name":"Planes","url":"/precios/"},{"name":"Contáctanos","url":"","type":"contact"}],"loggedMenu":[{"name":"Empleos","icon":"icon-suitecase_B","url":"/empleos/"},{"name":"Obtén 1 mes gratis","icon":"icon-gift_A","type":"referal","url":"/mi-suscripcion/referidos/"},{"name":"Mi Suscripción","icon":"icon-platzi","type":"my_subscription","url":"/mi-suscripcion/"}],"platziDayEnabled":false,"socials":[{"icon":"icon-twt","url":"https://twitter.com/platzi"},{"icon":"icon-youtube-play","url":"https://www.youtube.com/channel/UC55-mxUj5Nj3niXFReG44OQ"},{"icon":"icon-fcbk","url":"https://facebook.com/platzi"},{"icon":"icon-instagram","url":"https://www.instagram.com/platzi/"}],"official_companies":[{"logo":"https://static.platzi.com/static/images/footer/logo-ibm.png","name":"IBM","url":""},{"logo":"https://static.platzi.com/static/images/footer/logo-unity.png","name":"Unity","url":""}],"organization_id":1,"enableSearch":true,"logo":"https://static.platzi.com/static/images/footer/logo.png","live":{"active":false,"time":"","url":"","title":"","badge":""},"isLogged":false,"isHispanic":true,"canonical":"https://platzi.com","showBeneficiaryBanner":false,"country_name":"Colombia","ask_billing_data":false,"awards":[{"logo":"https://static.platzi.com/static/images/footer/yc.png","name":"Y Combinator","url":"https://platzi.com/blog/platzi-y-combinator/"},{"logo":"https://static.platzi.com/static/images/footer/asugsv.png","name":"ASU + GSV Summit","url":"https://platzi.com/blog/platzi-gana-premio-educacion/"}],"showInvitationModal":false,"headerNotification":{},"userInfo":{"paymentSuccessful":false,"points":0,"referalUrl":"","userType":"","isAuthenticated":false,"userId":0,"profileUrl":"","trialingCompensation":false,"plan":"","name":"","subscription_time":"","lastCourse":[],"pricePlan":"","publicName":"","role":"unlogged","username":"","country":"","nextBillingDate":"","isBundleUser":false,"emailNotValidated":false,"phoneNumber":"","learningPathsAllowed":1,"avatar":"https://static.platzi.com/static/website/v2/images/avatar_default.png","email":""},"locale":"es-CO","languages":[{"url":"https://platzi.com.br","lang_name":"Portugués","lang":"pt","flag":"https://static.platzi.com/static/images/flags/brazil.jpg"},{"url":"https://platzi.com","lang_name":"Español","lang":"es","flag":"https://static.platzi.com/static/images/flags/espana.jpg"},{"url":"https://courses.platzi.com","lang_name":"Inglés","lang":"en","flag":"https://static.platzi.com/static/images/flags/united-states.jpg"}],"promo_banner":{"previous_price":"","pre_banner_text":"Acceso libre a todos los cursos de Platzi por 48 horas ¡regístrate!","primary_color":"linear-gradient(180deg, #000948 0%, #321B5E 100%)","active":true,"pricing":"","primary_logo":"https://static.platzi.com/media/promos/platzi-day-logo.png","msi_banner":false,"lang":"es","url":"https://platzi.com/day/","is_platzi_day_registered":false,"end_date":"2021-06-04T15:00:00+00:00","status":"pre","font_color":"#FFFFFF","tertiary_color":"#0C031F","secondary_logo":"https://static.platzi.com/media/promos/platzi-day-logo.png","secondary_color":"#BF0BFF","show_counter":true,"saving":"","decorative_image":false},"categories":[{"color":"#29b8e8","na ...
#           <script id="initialProps" >window.initialProps = {}</script>
#           <script id="translations" >window.translations = {"messages":{"contactus_title":"¿Tienes dudas o quieres comunicarte con nosotros?","contactus_subtitle":"Elige el medio que más te convenga, te sugerimos ","write":"Escríbenos","dm":"Mensaje Directo","telephone":"Teléfono","continue_watching":"Continua viendo","all_courses":"Ver todos mis cursos","username":"¡Hola, {{user_name}}!","subscriptionTime":"Tienes {subscription_time} días de tu Plan","view_profile":"Ver mi Perfil","logout":"Cerrar sesión","login":"Iniciar sesión","live_in":"En Vivo","live":"live","menu":"Menú","view_plans":"Quiero saber más","view_plans2":"Quiero saber más","courses":"Cursos","more_results":"Más resultados","header.search.learningPaths":"Ruta de aprendizaje","no_results":"No tenemos resultados destacados","avanced_search":"Presiona ENTER para una busqueda avanzada","init_plan":"Iniciar mi plan","init_plan2":"Planes","switch_language":"Do you want to switch to Platzi in English?","switch_english":"Yes, switch to English","user_login":"Inicia sesión o crea tu cuenta","nextPage":"Siguiente","searchPlaceholder":"Buscar en Platzi","login_live_text":"Participa en sesiones en vivo y foros de Platzi","login_courses_text":"Accede a más de 120 cursos","login_opportunities":"Accede a mejores oportunidades laborales","login_or":"ó","mark_as_read":"Marcar todas como leídas","title":"Tus notificaciones","hide":"Ocultar","hide_description":"Ocultar esta notificación del historial","undo":"Deshacer","notification_hidden":"Se ocultó la notificatión.","notification_empty_title":"¡Aún no tienes notificaciones!","notification_emtpy_subtitle":"Participa, comparte y discute para empezar a recibir notificaciones","see_all":"Ver todas","notifications_disabled_title":"¡Tus notificaciones están desactivadas!","notification_not_available_title":"¡Lo sentimos!","notifications_not_available_subtitle":"El contenido al que intentas acceder no se encuentra disponible.","notifications_disabled_subtitle":"Para recibir nuevamente tus notificaciones debes activarlas en \u003cspan class=\"icon-cog\">\u003c/span>","required_courses":"Cursos Obrigatórios","awardsText":"Reconocidos y premiados por","CertifiersText":"Certificadores oficiales en tecnologías","fromLatam":"De LATAM con ","toTheWorld":"para el mundo","FooterShareLink":"Comparte este link y por cada registro con esta URL te damos un mes","FooterCopyLink":"ingrese un link","qualityEducation":"Transformamos la economía de nuestros países entrenando a la próxima generación de profesionales en tecnología.","FooterfollowUs":"Aprende en nuestras redes:","FooterChangeLang":"Cambiar idioma","SubscribeSectionTitle":"Entérate de todas las novedades en educación, negocios y tecnología","SubscribeSectionCTA":"Suscríbete","YourEmail":"Correo electrónico","EnterYourEmail":"Ingresa tu correo electrónico","LoginSocial-facebook-login":"Inicia sesión con Facebook","LoginSocial-twitter-login":"Inicia sesión con Twitter","login_email":"Tu email","login_password":"Tu contraseña","LoginWithEmail-login":"Inicia sesión","LoginWithEmail-lostpassword":"¿Olvidaste tu contraseña?","AccountFooter-title-register":"¿Aún no tienes cuenta en Platzi?","AccountFooter-register":"Regístrate","AccountFooter-login":"Inicia tu sesión","AccountFooter-title-login":"¿Ya tienes una cuenta?","RegisterButton-email":"Regístrate con tu Email","LoginSocial-twitter-register":"Regístrate con Twitter","LoginSocial-facebook-register":" Regístrate con Facebook","planExpert":"Plan Expert","planExpertText":"Desarrolla tus habilidades en programación, diseño, producción audiovisual, marketing y muchas más. Mide tu progreso y recibe certificados con tu nombre a finalizar cada curso.","user_points":"{{points}} pts","countdown_text":"Termina en","countdown_text_pre":"Comienza en: ","billing.title":"Ingresar datos de facturación","billing.subtitle":"Información obligatoria unicamente para tus facturas. Resolución 30 de 2019 título II Artículo 2 (la siguiente información no podrá s ...
#           <script async src="https://cdnjs.cloudflare.com/ajax/libs/lazysizes/5.2.0/lazysizes.min.js" async></script>
#           <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[8808,5045,5217,6570,6766,1465,3279,6727,4069,8683,7248,2622]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["app-commons-TrustedList","components-Schools-Schools-jsx","components-RecentLaunches-RecentLaunches-jsx","app-commons-LearningExperience","app-commons-Community","app-commons-Testimonies-Testimonies-jsx","components-B2B-B2B-jsx","components-Prizes-Prizes-jsx","components-NeverStop-NeverStop-jsx"]}</script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/6126.f3a59cc3313eef232d35.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/9669.d1e2f3b8fa78e2787a07.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/1620.36c1cb07cea190913e27.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/4006.3bb8e264445f5619b691.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/8001.32d84d2b8ef3c5503979.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/4373.0a0263fdbfefb104bb63.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/6486.f851b5b030dff11f4b10.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/3376.f8d3d1baaaac3c3921fc.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/6066.d48f9f4b3702eedade65.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/7199.06cf0c15ee00a8557c33.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/6838.d410234b67f3d29058a0.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/230.9941b5b943d31843f825.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/8571.bf99ef8cb7ba68ffe287.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/4559.aff5e553e3541fdaa62f.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/8538.a1c8c37e4d9ae6a63df7.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/1813.c245ca13508b04c768ff.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/5591.751546257a7a44267a98.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/1586.889a46b5da78cb23dd54.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/7305.c0c2cf8a219ebadebe0d.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/381.8497f60b8ec770d2b77c.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/9527.ab6047d475b021004c56.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/8786.8d4c09c540d61d6ab488.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/99.7cea736da192c33ecfc1.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/9224.43b63de854bb90d3ffa7.js"></script>
# <script async data-chunk="home-public" src="https://static.platzi.com/mf-landings/assets/home-public.7c3f851ac65ec2a6cbe3.js"></script>
# <script async data-chunk="app-commons-TrustedList" src="https://static.platzi.com/mf-landings/assets/app-commons-TrustedList.0657748bbe01e62e97be.js"></script>
# <script async data-chunk="components-Schools-Schools-jsx" src="https://static.platzi.com/mf-landings/assets/components-Schools-Schools-jsx.1a31c6ac242472f2c5bb.js"></script>
# <script async data-chunk="components-RecentLaunches-RecentLaunches-jsx" src="https://static.platzi.com/mf-landings/assets/components-RecentLaunches-RecentLaunches-jsx.76949b4d3588712f626c.js"></script>
# <script async data-chunk="app-commons-LearningExperience" src="https://static.platzi.com/mf-landings/assets/app-commons-LearningExperience.6d22d993297728bec2cd.js"></script>
# <script async data-chunk="app-commons-Community" src="https://static.platzi.com/mf-landings/assets/app-commons-Community.aa618d5a46915cc47b8b.js"></script>
# <script async data-chunk="app-commons-Testimonies-Testimonies-jsx" src="https://static.platzi.com/mf-landings/assets/1465.9a7a7111ea42f57fde8a.js"></script>
# <script async data-chunk="app-commons-Testimonies-Testimonies-jsx" src="https://static.platzi.com/mf-landings/assets/app-commons-Testimonies-Testimonies-jsx.af49a473b42564abb15d.js"></script>
# <script async data-chunk="components-B2B-B2B-jsx" src="https://static.platzi.com/mf-landings/assets/6727.af93a2e6f205350f8c60.js"></script>
# <script async data-chunk="components-B2B-B2B-jsx" src="https://static.platzi.com/mf-landings/assets/components-B2B-B2B-jsx.dae6387a87e56253af98.js"></script>
# <script async data-chunk="components-Prizes-Prizes-jsx" src="https://static.platzi.com/mf-landings/assets/components-Prizes-Prizes-jsx.bd1c9c8b404d0fca7249.js"></script>
# <script async data-chunk="components-NeverStop-NeverStop-jsx" src="https://static.platzi.com/mf-landings/assets/7248.68fa588de87b021cb0f8.js"></script>
# <script async data-chunk="components-NeverStop-NeverStop-jsx" src="https://static.platzi.com/mf-landings/assets/components-NeverStop-NeverStop-jsx.e6f7b120b81457fb46c3.js"></script>
#           <script async type="application/ld+json">
#             {
#                 "@context": "http://schema.org",
#                 "@type": "Organization",
#                 "name": "Platzi",
#                 "url": "https://platzi.com/",
#                 "description": "Aprende de expertos en programación, diseño, marketing, startups, video y web. Suscríbete hoy.",
#                 "foundingDate": "2013-01-01",
#                 "founders": [
#                     {
#                         "@type": "Person",
#                         "name": "John Freddy Vega"
#                     },
#                     {
#                         "@type": "Person",
#                         "name": "Christian Van Der Henst"
#                     }
#                 ],
#                 "sameAs": [
#                     "https://www.facebook.com/platzi/",
#                     "https://twitter.com/Platzi",
#                     "https://www.youtube.com/channel/UC55-mxUj5Nj3niXFReG44OQ",
#                     "https://www.linkedin.com/school/2822346"
#                 ]
#             }
#           </script>
#
#           <!-- GTM Second Stage (noscript) -->
#           <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MPT6TFW"
#           height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#           <!-- GTM Second Stage (noscript) -->
#         <script type="text/javascript">(function(){window['__CF$cv$params']={r:'659a0d1ecdd73714',m:'8a6bf8e14e88556a39c939f190d417578921ba9c-1622735155-1800-ASzamjMaL8VIqWg6Y0nKK8pSjmlSLK0Xf6xHb3say0pC/8RR/i1RraDyJc1vl8DLl49/cOthZZ+pl5ICoZYdtZlq0dGTgKukyvQHlUkhUB61/yBu8TlFbtrmYzTt212Ecw==',s:[0x0214c7ae67,0x195ecd28b9],}})();</script></body>
#       </html>

# %% [markdown]
# # Extracción de información del HTML

# %% [markdown]
# #### Libreria Beautifulsoup
# Permite analizar gramticamente o parsear el documento html para poder manipularlo programaticamente y podamos consultarlo, por tanto, el documento se convierte en un arbol de nodos, se realizan consultas con selectores css

# %%
import bs4
# Se especifica que debe ser de tipo html por que el metodo tambien sirve para
# documentos xml
soup = bs4.BeautifulSoup(response.text,'html.parser')

# Metodo obtener el titulo
print(soup.title.text)

# Metodo selector css
print(soup.select('meta[name=description]')[0]['content'])
# Out:
# Platzi: ‎Cursos Online Profesionales de Tecnología
# Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!

# %%
# Se selecciona la clase dentro de las etiquetas html
courses_links = soup.select('.SchoolsList-school') 
courses = [course['href'] for course in courses_links]

for course in courses:
    print(course)
# Out:
# /web/
# /escuela-javascript/
# /idioma-ingles/
# /marketing-digital/
# /startups/
# /publicidad/
# /periodismo-digital/
# /diseno-producto/
# /videojuegos/
# /negocios/
# /finanzas/
# /ecommerce/
# /matematicas/
# /azure/
# /datos/
# /diseno-grafico/
# /habilidades-blandas/
# /software/
# /produccion-video/

# %% [markdown]
# ## Page Object Pattern:
#
# Primero es indispensable entender que los queries se estan realizando con selectores de css, y que así a simple vista tienen un problema el cual es que si se modifica la web, las direcciones donde apunta el querie puede modificarse y romperse por completo el script, por tanto, es importante conocer que es el page object pattern.
#
# Es un patron que viene de las pruebas automatizadas, Consiste en esconder los queries especificos que se utilizan para manipular un documento HTML detras de un objeto que representa la pagina web. por tanto si eres explicito con estos queries y los añades en el codigo principal, se volverá fragil el codigo y será dificil arreglarlo.

# %% [markdown]
# ### Estructura: Configuración del proyecto.
#
# se crea un archivo config.yaml en donde se define la configuración y su estructura, en este caso se genera un mapa de mapas donde las propiedades de los mapas internos son las que vamos a utilizar.

# %% [markdown]
# ### Series con Pandas
# construcción de vectores unidimensionales asignandole indices con semantica.

# %%
import pandas as pd
series_test = pd.Series([1000,2000,3000])
series_test
# Out:
# 0    1000
# 1    2000
# 2    3000
# dtype: int64

# %%
series_test1 = pd.Series({
    2000: 48,
    3000: 38,
    4000: 28
})
series_test1
# Out:
# 2000    48
# 3000    38
# 4000    28
# dtype: int64

# %%
series_test2 = pd.Series([100,200,300],index=['a','b','c'])
series_test2
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %% [markdown]
# ### Dataframe
# La estructura es bidimensional, es una matriz, o una lista de listas.
# Es una tabla con filas y columnas etiquetadas, con los diccionarios las llaves se convierten en las llaves de acceso a las columnas.

# %%
frame_test = pd.DataFrame({1996:[2,3,4,5],
                          2000:[6,7,8,9],
                          2001:[41,23,45,5]})
frame_test
# Out:
#    1996  2000  2001
# 0     2     6    41
# 1     3     7    23
# 2     4     8    45
# 3     5     9     5

# %%
frame_test1 = pd.DataFrame([[2,3,4],[6,7,8],[41,23,45]], columns = [1996,2000,2001])
frame_test1
# Out:
#    1996  2000  2001
# 0     2     3     4
# 1     6     7     8
# 2    41    23    45

# %% [markdown]
# ## Indices y seleccion de datos
# para acceder como las llaves de los diccionarios, se puede pasar el nombre de la columna dentro de parentesis cuadrados.

# %%
df = pd.read_csv('eluniversal_2020_04_10_articles.csv',encoding='utf-8')
df
# Out:
#                                                   body  \
# 0    \n“No sabía si iba a sobrevivir”, dijo la cant...
# 1    \nEl presidente Andrés Manuel López Obrador in...
# 2    \nLa Secretaría de Salud confirmó tres nuevos ...
# 3    \nComo había anunciado ayer, Andrés Manuel Lóp...
# 4    \nAna Claudia Talancón anda activa promoviendo...
# ..                                                 ...
# 134  \nLa iglesia católica en San Luis Potosí afirm...
# 135  \n"¡Atención! Usted está en una zona prohibida...
# 136  \n\nReuters\n \nHart Island se ha usado histór...
# 137  \n¿No le parece increíble la cantidad de notic...
# 138  \nLos Clooney no han querido quedarse de brazo...
#
#                                                  title  \
# 0                                                  NaN
# 1    México acuerda con OPEP reducir en 100 mil bar...
# 2    Fallecen tres personas más por coronavirus en ...
# 3    AMLO dice que envió listado al CCE de los 15 g...
# 4    Ana Claudia Talancón promueve el sazón de su p...
# ..                                                 ...
# 134  Iglesia católica en SLP, con espacios para que...
# 135  En Italia, drones detectan a infractores de la...
# 136  Coronavirus: los enterramientos en una fosa co...
# 137                  Puras noticias falsas sobre la 4T
# 138  George y Amal Clooney donan 1 mdd para el comb...
#
#                                                    url
# 0    https://www.viveusa.mx/showbiz/pink-revela-sus...
# 1    https://www.eluniversal.com.mx/nacion/amlo-mex...
# 2    https://www.eluniversal.com.mx/estados/fallece...
# 3    https://www.eluniversal.com.mx/nacion/la-manan...
# 4    https://www.eluniversal.com.mx/espectaculos/fa...
# ..                                                 ...
# 134  https://sanluis.eluniversal.com.mx/sociedad/08...
# 135  https://www.eluniversal.com.mx/mundo/covid-19-...
# 136  https://www.eluniversal.com.mx/mundo/coronavir...
# 137  https://www.eluniversal.com.mx/opinion/arlequi...
# 138  https://www.eluniversal.com.mx/espectaculos/fa...
#
# [139 rows x 3 columns]

# %% [markdown]
# ## Numpy like

# %%
df.iloc[1:15] ## Selección de filas
# Out:
#                                                  body  \
# 1   \nEl presidente Andrés Manuel López Obrador in...
# 2   \nLa Secretaría de Salud confirmó tres nuevos ...
# 3   \nComo había anunciado ayer, Andrés Manuel Lóp...
# 4   \nAna Claudia Talancón anda activa promoviendo...
# 5   \nLuego de más de diez horas de una teleconfer...
# 6   \nLa noche de este jueves se lleva a cabo en H...
# 7   Javier citó a Mauricio sobre el Paseo de los C...
# 8   \nAutoridades de Protección Civil del municipi...
# 9   \nAún con la contingencia, el barrio de Santa ...
# 10  \n\nSiempre fue un tema recurrente en nuestras...
# 11  \nEn momentos en que el Consejo Coordinador Em...
# 12  \n\n\n\n    googletag.cmd.push(function() {\n ...
# 13  \n\nEs momento de que como sociedad mexicana c...
# 14  \nLa Secretaría de Salud informó que aunque el...
#
#                                                 title  \
# 1   México acuerda con OPEP reducir en 100 mil bar...
# 2   Fallecen tres personas más por coronavirus en ...
# 3   AMLO dice que envió listado al CCE de los 15 g...
# 4   Ana Claudia Talancón promueve el sazón de su p...
# 5   México propone recortar 100 mil barriles diari...
# 6   Ante audiencia de su agresor, joven saxofonist...
# 7                                                 NaN
# 8   Protección Civil en Soledad vigila que balnear...
# 9         Mantienen la fe en la Virgen de los Dolores
# 10                     La pobreza según Andrés Manuel
# 11  CCE pide diálogo abierto y respeto a posturas ...
# 12  Coronavirus: ¿Qué va a pasar con Jóvenes Const...
# 13                      No contamos con el presidente
# 14  Uso de plasma de personas curadas de Covid-19,...
#
#                                                   url
# 1   https://www.eluniversal.com.mx/nacion/amlo-mex...
# 2   https://www.eluniversal.com.mx/estados/fallece...
# 3   https://www.eluniversal.com.mx/nacion/la-manan...
# 4   https://www.eluniversal.com.mx/espectaculos/fa...
# 5   https://www.eluniversal.com.mx/cartera/mexico-...
# 6   https://www.eluniversal.com.mx/estados/ante-au...
# 7   https://www.elgrafico.mx/la-roja/hombre-se-pon...
# 8   https://sanluis.eluniversal.com.mx/municipios/...
# 9   https://www.eluniversalqueretaro.mx/portada/ma...
# 10  https://www.eluniversal.com.mx/opinion/ricardo...
# 11  https://www.eluniversal.com.mx/cartera/cce-pid...
# 12  http://www.unionguanajuato.mx/articulo/2020/03...
# 13  https://www.eluniversal.com.mx/opinion/carlos-...
# 14  https://www.eluniversal.com.mx/nacion/uso-de-p...

# %%
df.iloc[66]['title'] # Filtra la fila 66 pero se especifica la columna
# Out:
# 'Carmina Burana y películas desde tu ventana: qué hacer en cuarentena'

# %%
df.iloc[:5,0]
# Out:
# 0    \n“No sabía si iba a sobrevivir”, dijo la cant...
# 1    \nEl presidente Andrés Manuel López Obrador in...
# 2    \nLa Secretaría de Salud confirmó tres nuevos ...
# 3    \nComo había anunciado ayer, Andrés Manuel Lóp...
# 4    \nAna Claudia Talancón anda activa promoviendo...
# Name: body, dtype: object

# %%
df.loc[:,'body':'title']
# Out:
#                                                   body  \
# 0    \n“No sabía si iba a sobrevivir”, dijo la cant...
# 1    \nEl presidente Andrés Manuel López Obrador in...
# 2    \nLa Secretaría de Salud confirmó tres nuevos ...
# 3    \nComo había anunciado ayer, Andrés Manuel Lóp...
# 4    \nAna Claudia Talancón anda activa promoviendo...
# ..                                                 ...
# 134  \nLa iglesia católica en San Luis Potosí afirm...
# 135  \n"¡Atención! Usted está en una zona prohibida...
# 136  \n\nReuters\n \nHart Island se ha usado histór...
# 137  \n¿No le parece increíble la cantidad de notic...
# 138  \nLos Clooney no han querido quedarse de brazo...
#
#                                                  title
# 0                                                  NaN
# 1    México acuerda con OPEP reducir en 100 mil bar...
# 2    Fallecen tres personas más por coronavirus en ...
# 3    AMLO dice que envió listado al CCE de los 15 g...
# 4    Ana Claudia Talancón promueve el sazón de su p...
# ..                                                 ...
# 134  Iglesia católica en SLP, con espacios para que...
# 135  En Italia, drones detectan a infractores de la...
# 136  Coronavirus: los enterramientos en una fosa co...
# 137                  Puras noticias falsas sobre la 4T
# 138  George y Amal Clooney donan 1 mdd para el comb...
#
# [139 rows x 2 columns]

# %% [markdown]
# ## Data Wrangling
#
# Son las actividades mas importantes, el 80% del tiempo se utiliza como domado de datos. desde la ingenieria de datos se realiza como extracción transformación y carga de datos.

# %%
1 # Añadir el newspaper_uid

df['newspaper_uid'] = 'eluniversal'
df
# Out:
#                                                   body  \
# 0    \n“No sabía si iba a sobrevivir”, dijo la cant...
# 1    \nEl presidente Andrés Manuel López Obrador in...
# 2    \nLa Secretaría de Salud confirmó tres nuevos ...
# 3    \nComo había anunciado ayer, Andrés Manuel Lóp...
# 4    \nAna Claudia Talancón anda activa promoviendo...
# ..                                                 ...
# 134  \nLa iglesia católica en San Luis Potosí afirm...
# 135  \n"¡Atención! Usted está en una zona prohibida...
# 136  \n\nReuters\n \nHart Island se ha usado histór...
# 137  \n¿No le parece increíble la cantidad de notic...
# 138  \nLos Clooney no han querido quedarse de brazo...
#
#                                                  title  \
# 0                                                  NaN
# 1    México acuerda con OPEP reducir en 100 mil bar...
# 2    Fallecen tres personas más por coronavirus en ...
# 3    AMLO dice que envió listado al CCE de los 15 g...
# 4    Ana Claudia Talancón promueve el sazón de su p...
# ..                                                 ...
# 134  Iglesia católica en SLP, con espacios para que...
# 135  En Italia, drones detectan a infractores de la...
# 136  Coronavirus: los enterramientos en una fosa co...
# 137                  Puras noticias falsas sobre la 4T
# 138  George y Amal Clooney donan 1 mdd para el comb...
#
#                                                    url newspaper_uid
# 0    https://www.viveusa.mx/showbiz/pink-revela-sus...   eluniversal
# 1    https://www.eluniversal.com.mx/nacion/amlo-mex...   eluniversal
# 2    https://www.eluniversal.com.mx/estados/fallece...   eluniversal
# 3    https://www.eluniversal.com.mx/nacion/la-manan...   eluniversal
# 4    https://www.eluniversal.com.mx/espectaculos/fa...   eluniversal
# ..                                                 ...           ...
# 134  https://sanluis.eluniversal.com.mx/sociedad/08...   eluniversal
# 135  https://www.eluniversal.com.mx/mundo/covid-19-...   eluniversal
# 136  https://www.eluniversal.com.mx/mundo/coronavir...   eluniversal
# 137  https://www.eluniversal.com.mx/opinion/arlequi...   eluniversal
# 138  https://www.eluniversal.com.mx/espectaculos/fa...   eluniversal
#
# [139 rows x 4 columns]

# %%
# 2. obtener el host
from urllib.parse import urlparse

df['host'] = df['url'].apply(lambda x: urlparse(x).netloc) # apply genera transformaciones custom

df
# Out:
#                                                   body  \
# 0    \n“No sabía si iba a sobrevivir”, dijo la cant...
# 1    \nEl presidente Andrés Manuel López Obrador in...
# 2    \nLa Secretaría de Salud confirmó tres nuevos ...
# 3    \nComo había anunciado ayer, Andrés Manuel Lóp...
# 4    \nAna Claudia Talancón anda activa promoviendo...
# ..                                                 ...
# 134  \nLa iglesia católica en San Luis Potosí afirm...
# 135  \n"¡Atención! Usted está en una zona prohibida...
# 136  \n\nReuters\n \nHart Island se ha usado histór...
# 137  \n¿No le parece increíble la cantidad de notic...
# 138  \nLos Clooney no han querido quedarse de brazo...
#
#                                                  title  \
# 0                                                  NaN
# 1    México acuerda con OPEP reducir en 100 mil bar...
# 2    Fallecen tres personas más por coronavirus en ...
# 3    AMLO dice que envió listado al CCE de los 15 g...
# 4    Ana Claudia Talancón promueve el sazón de su p...
# ..                                                 ...
# 134  Iglesia católica en SLP, con espacios para que...
# 135  En Italia, drones detectan a infractores de la...
# 136  Coronavirus: los enterramientos en una fosa co...
# 137                  Puras noticias falsas sobre la 4T
# 138  George y Amal Clooney donan 1 mdd para el comb...
#
#                                                    url newspaper_uid  \
# 0    https://www.viveusa.mx/showbiz/pink-revela-sus...   eluniversal
# 1    https://www.eluniversal.com.mx/nacion/amlo-mex...   eluniversal
# 2    https://www.eluniversal.com.mx/estados/fallece...   eluniversal
# 3    https://www.eluniversal.com.mx/nacion/la-manan...   eluniversal
# 4    https://www.eluniversal.com.mx/espectaculos/fa...   eluniversal
# ..                                                 ...           ...
# 134  https://sanluis.eluniversal.com.mx/sociedad/08...   eluniversal
# 135  https://www.eluniversal.com.mx/mundo/covid-19-...   eluniversal
# 136  https://www.eluniversal.com.mx/mundo/coronavir...   eluniversal
# 137  https://www.eluniversal.com.mx/opinion/arlequi...   eluniversal
# 138  https://www.eluniversal.com.mx/espectaculos/fa...   eluniversal
#
#                            host
# 0                www.viveusa.mx
# 1        www.eluniversal.com.mx
# 2        www.eluniversal.com.mx
# 3        www.eluniversal.com.mx
# 4        www.eluniversal.com.mx
# ..                          ...
# 134  sanluis.eluniversal.com.mx
# 135      www.eluniversal.com.mx
# 136      www.eluniversal.com.mx
# 137      www.eluniversal.com.mx
# 138      www.eluniversal.com.mx
#
# [139 rows x 5 columns]

# %%
df['host'].value_counts()
# Out:
# www.eluniversal.com.mx         81
# www.viveusa.mx                 14
# de10.com.mx                     8
# www.elgrafico.mx                6
# www.eluniversalqueretaro.mx     5
# oaxaca.eluniversal.com.mx       4
# sanluis.eluniversal.com.mx      4
# www.unionjalisco.mx             3
# www.unionguanajuato.mx          3
# www.unionedomex.mx              3
# www.unionpuebla.mx              3
# www.unionyucatan.mx             2
# eluniversal.com.mx              1
# www.clubeluniversal.mx          1
# www.unioncdmx.mx                1
# Name: host, dtype: int64

# %% [markdown]
# ### Preparando la automatización.
# En el mundo del data enginiering es necesario automatizar el proceso de tratamiento de datos. se le aplica un scrip con el paso a paso de transformaciones que se van a realizar.

# %% [markdown]
# ## Datos Faltantes:
# pandas brinda diferentes estrategias 'tradeoffs' para solucionar este problema.
#
# Se puede eliminar el registro:
# - .isna()
# - .notna()
# - .dropna()
#
# Para reemplazar el registro.
# - .fillna() utiliza un valor sentinela
# - .ffill() utiliza el ultimo valor utilizado

# %%
filter = df['title'].isna()
df[filter]
# Out:
#                                                   body title  \
# 0    \n“No sabía si iba a sobrevivir”, dijo la cant...   NaN
# 7    Javier citó a Mauricio sobre el Paseo de los C...   NaN
# 15    0 % PULSO SOCIAL0 Aunque aún existen personas...   NaN
# 17   \nLas personas que padecen asma son uno de los...   NaN
# 21   \nEl Lincoln Center de Nueva York, uno de los ...   NaN
# 22    0 % PULSO SOCIAL0 Es común que los “niños est...   NaN
# 23   \nLa modelo y corista Mollie Gould no ha parad...   NaN
# 26   \n¿Volveremos a relacionarnos como antes de la...   NaN
# 30   Él no esperaba que el hombre al que le intenta...   NaN
# 45   \nEl exceso de alimentos procesados que consum...   NaN
# 46    0 % PULSO SOCIAL0 Luego de una semana sin tur...   NaN
# 53    0 % PULSO SOCIAL0 La epidemia del coronavirus...   NaN
# 55   Por si la pandemia del coronavirus Covid-19 no...   NaN
# 62   \nLa actriz Eiza González está pasando la cuar...   NaN
# 63   \nLa Oficina de Aduanas y Protección Fronteriz...   NaN
# 67   Cuatro personas fueron acribilladas la noche d...   NaN
# 69   \n Kylie Jenner, la menor del televisivo clan ...   NaN
# 73    0 % PULSO SOCIAL0 El estrés y la ansiedad son...   NaN
# 76   \nLa pandemia por coronavirus ha llevado al ci...   NaN
# 80   \n¿Por qué la COVID-19 se ensaña especialmente...   NaN
# 82    0 % PULSO SOCIAL0 Estos días de cuarentena po...   NaN
# 85   \nDwayne Johnson fue el actor mejor pagado del...   NaN
# 88   Al regresar de un funeral, Arturo fue ejecutad...   NaN
# 89   \nLinda Tripp, la amiga íntima de Monica Lewin...   NaN
# 96    0 % PULSO SOCIAL0 ¡Sonríe, qué nadie te quite...   NaN
# 105  \nMacKenzie Bezos ingresó de manera oficial a ...   NaN
# 108   3 % PULSO SOCIAL1 El 10 de abril de 1970 fue ...   NaN
# 111   Toggle navigation  SuscripcionesEl Universal ...   NaN
# 122  En días pasados se viralizó a través de Twitte...   NaN
#
#                                                    url newspaper_uid  \
# 0    https://www.viveusa.mx/showbiz/pink-revela-sus...   eluniversal
# 7    https://www.elgrafico.mx/la-roja/hombre-se-pon...   eluniversal
# 15   https://de10.com.mx/top-10/2018/01/11/las-10-m...   eluniversal
# 17   https://www.viveusa.mx/bienestar/tips-que-debe...   eluniversal
# 21   https://www.viveusa.mx/destinos/disfruta-conci...   eluniversal
# 22   https://de10.com.mx/top-10/el-antes-y-despues-...   eluniversal
# 23   https://www.viveusa.mx/showbiz/la-novia-de-lui...   eluniversal
# 26   https://www.viveusa.mx/noticias/volveran-los-b...   eluniversal
# 30   https://www.elgrafico.mx/la-roja/policia-engan...   eluniversal
# 45   https://www.viveusa.mx/bienestar/los-10-alimen...   eluniversal
# 46   https://de10.com.mx/vivir-bien/playas-de-acapu...   eluniversal
# 53   https://de10.com.mx/vivir-bien/10-consejos-par...   eluniversal
# 55   https://www.elgrafico.mx/viral/trompetas-del-a...   eluniversal
# 62   https://www.viveusa.mx/showbiz/eiza-gonzalez-p...   eluniversal
# 63   https://www.viveusa.mx/educacion/10-dudas-resu...   eluniversal
# 67   https://www.elgrafico.mx/la-roja/noche-de-expi...   eluniversal
# 69   https://www.viveusa.mx/showbiz/kylie-jenner-re...   eluniversal
# 73   https://de10.com.mx/vivir-bien/10-maneras-de-r...   eluniversal
# 76   https://www.viveusa.mx/destinos/las-veces-que-...   eluniversal
# 80   https://www.viveusa.mx/noticias/por-que-el-cor...   eluniversal
# 82   https://de10.com.mx/parejas/5-tratamientos-cas...   eluniversal
# 85   https://www.viveusa.mx/showbiz/carreras-que-la...   eluniversal
# 88   https://www.elgrafico.mx/la-roja/matan-joven-f...   eluniversal
# 89   https://www.viveusa.mx/showbiz/fallece-la-amig...   eluniversal
# 96   https://de10.com.mx/top-10/barbara-de-regil-la...   eluniversal
# 105  https://www.viveusa.mx/negocios/mackenzie-bezo...   eluniversal
# 108  https://de10.com.mx/top-10/10-de-abril-de-1970...   eluniversal
# 111  https://www.clubeluniversal.mx/content/suscrip...   eluniversal
# 122  https://www.elgrafico.mx/viral/mujer-comercian...   eluniversal
#
#                        host
# 0            www.viveusa.mx
# 7          www.elgrafico.mx
# 15              de10.com.mx
# 17           www.viveusa.mx
# 21           www.viveusa.mx
# 22              de10.com.mx
# 23           www.viveusa.mx
# 26           www.viveusa.mx
# 30         www.elgrafico.mx
# 45           www.viveusa.mx
# 46              de10.com.mx
# 53              de10.com.mx
# 55         www.elgrafico.mx
# 62           www.viveusa.mx
# 63           www.viveusa.mx
# 67         www.elgrafico.mx
# 69           www.viveusa.mx
# 73              de10.com.mx
# 76           www.viveusa.mx
# 80           www.viveusa.mx
# 82              de10.com.mx
# 85           www.viveusa.mx
# 88         www.elgrafico.mx
# 89           www.viveusa.mx
# 96              de10.com.mx
# 105          www.viveusa.mx
# 108             de10.com.mx
# 111  www.clubeluniversal.mx
# 122        www.elgrafico.mx

# %%
import re

(df[filter]['url'].str.extract(r'(?P<missing_title>[^/]+)$')
                      .applymap(lambda x: x.split('-'))
                      .applymap(lambda x: ' '.join(x)))


(df[filter]['url'].str.extract(r'(?P<missing_title>[^/]+)$')
                      .astype(str)
                      .applymap(lambda x: x.replace('-',' ')))

missing_titles = (df[filter]['url'].str.extract(r'(?P<missing_title>[^/]+)$')
                      .astype(str)
                      .applymap(lambda x: x.replace('-',' '))) # convierte en str y luego reemplaza los - con espacios

# %% [markdown]
# ### Limpieza de datos.

# %%
# 4. añadir uid
import hashlib

uids = (df.apply(lambda row: hashlib.md5(bytes(row['url'].encode())) , axis = 1)
        .apply(lambda hash_object: hash_object.hexdigest())
)


df['uid'] = uids
df.set_index('uid',inplace=True) # Aplica los indices ahí mismo

df
# Out:
#                                                                                body  \
# uid
# c535ba5517a66a00cf4f2d9a9126c5f4  \n“No sabía si iba a sobrevivir”, dijo la cant...
# bb17b5a8fc84838945991adb1c86eeca  \nEl presidente Andrés Manuel López Obrador in...
# 1e272ab81e2c3c796893b40570fd386b  \nLa Secretaría de Salud confirmó tres nuevos ...
# 078f077b88beab8becd4ea283d00d655  \nComo había anunciado ayer, Andrés Manuel Lóp...
# f10443973e64eb9945d76d3908508911  \nAna Claudia Talancón anda activa promoviendo...
# ...                                                                             ...
# 6a89c54ea88a3765c2a7639addede951  \nLa iglesia católica en San Luis Potosí afirm...
# 4d1081fc01d48c7dd92a0357a726a033  \n"¡Atención! Usted está en una zona prohibida...
# f4490eb370e888bf2513361ab2c9e3a6  \n\nReuters\n \nHart Island se ha usado histór...
# 1caafb8d89a01994b3d7235780786a02  \n¿No le parece increíble la cantidad de notic...
# 28225a04cfa35ef3c7fb348cb73377ca  \nLos Clooney no han querido quedarse de brazo...
#
#                                                                               title  \
# uid
# c535ba5517a66a00cf4f2d9a9126c5f4                                                NaN
# bb17b5a8fc84838945991adb1c86eeca  México acuerda con OPEP reducir en 100 mil bar...
# 1e272ab81e2c3c796893b40570fd386b  Fallecen tres personas más por coronavirus en ...
# 078f077b88beab8becd4ea283d00d655  AMLO dice que envió listado al CCE de los 15 g...
# f10443973e64eb9945d76d3908508911  Ana Claudia Talancón promueve el sazón de su p...
# ...                                                                             ...
# 6a89c54ea88a3765c2a7639addede951  Iglesia católica en SLP, con espacios para que...
# 4d1081fc01d48c7dd92a0357a726a033  En Italia, drones detectan a infractores de la...
# f4490eb370e888bf2513361ab2c9e3a6  Coronavirus: los enterramientos en una fosa co...
# 1caafb8d89a01994b3d7235780786a02                  Puras noticias falsas sobre la 4T
# 28225a04cfa35ef3c7fb348cb73377ca  George y Amal Clooney donan 1 mdd para el comb...
#
#                                                                                 url  \
# uid
# c535ba5517a66a00cf4f2d9a9126c5f4  https://www.viveusa.mx/showbiz/pink-revela-sus...
# bb17b5a8fc84838945991adb1c86eeca  https://www.eluniversal.com.mx/nacion/amlo-mex...
# 1e272ab81e2c3c796893b40570fd386b  https://www.eluniversal.com.mx/estados/fallece...
# 078f077b88beab8becd4ea283d00d655  https://www.eluniversal.com.mx/nacion/la-manan...
# f10443973e64eb9945d76d3908508911  https://www.eluniversal.com.mx/espectaculos/fa...
# ...                                                                             ...
# 6a89c54ea88a3765c2a7639addede951  https://sanluis.eluniversal.com.mx/sociedad/08...
# 4d1081fc01d48c7dd92a0357a726a033  https://www.eluniversal.com.mx/mundo/covid-19-...
# f4490eb370e888bf2513361ab2c9e3a6  https://www.eluniversal.com.mx/mundo/coronavir...
# 1caafb8d89a01994b3d7235780786a02  https://www.eluniversal.com.mx/opinion/arlequi...
# 28225a04cfa35ef3c7fb348cb73377ca  https://www.eluniversal.com.mx/espectaculos/fa...
#
#                                  newspaper_uid                        host
# uid
# c535ba5517a66a00cf4f2d9a9126c5f4   eluniversal              www.viveusa.mx
# bb17b5a8fc84838945991adb1c86eeca   eluniversal      www.eluniversal.com.mx
# 1e272ab81e2c3c796893b40570fd386b   eluniversal      www.eluniversal.com.mx
# 078f077b88beab8becd4ea283d00d655   eluniversal      www.eluniversal.com.mx
# f10443973e64eb9945d76d3908508911   eluniversal      www.eluniversal.com.mx
# ...                                        ...                         ...
# 6a89c54ea88a3765c2a7639addede951   eluniversal  sanluis.eluniversal.com.mx
# 4d1081fc01d48c7dd92a0357a726a033   eluniversal      www.eluniversal.com.mx
# f4490eb370e888bf2513361ab2c9e3a6   eluniversal      www.eluniversal.com.mx
# 1caafb8d89a01994b3d7235780786a02   eluniversal      www.eluniversal.com.mx
# 28225a04cfa35ef3c7fb348cb73377ca   eluniversal      www.eluniversal.com.mx
#
# [139 rows x 5 columns]

# %%
stripped_body = (
                    df.apply(lambda row: row['body'],axis = 1)
                    .apply(lambda body: list(body))
                    .apply(lambda letters: list(map(lambda letter: letter.replace('\n',''),letters)))
                    .apply(lambda letters: ''.join(letters))
)

stripped_body
# Out:
# uid
# c535ba5517a66a00cf4f2d9a9126c5f4    “No sabía si iba a sobrevivir”, dijo la cantan...
# bb17b5a8fc84838945991adb1c86eeca    El presidente Andrés Manuel López Obrador info...
# 1e272ab81e2c3c796893b40570fd386b    La Secretaría de Salud confirmó tres nuevos fa...
# 078f077b88beab8becd4ea283d00d655    Como había anunciado ayer, Andrés Manuel López...
# f10443973e64eb9945d76d3908508911    Ana Claudia Talancón anda activa promoviendo a...
#                                                           ...
# 6a89c54ea88a3765c2a7639addede951    La iglesia católica en San Luis Potosí afirma ...
# 4d1081fc01d48c7dd92a0357a726a033    "¡Atención! Usted está en una zona prohibida. ...
# f4490eb370e888bf2513361ab2c9e3a6    Reuters Hart Island se ha usado históricamente...
# 1caafb8d89a01994b3d7235780786a02    ¿No le parece increíble la cantidad de noticia...
# 28225a04cfa35ef3c7fb348cb73377ca    Los Clooney no han querido quedarse de brazos ...
# Length: 139, dtype: object

# %% [markdown]
# ## Introducción nltk.
# Tokenizar el titulo y el body, es decir, dividir en palabras

# %%
import nltk
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\GAMER\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\GAMER\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('spanish'))

def tokenize_column(df,column_name):
    return (df.dropna().apply(lambda row: nltk.word_tokenize(row[column_name]),axis=1)
           .apply(lambda tokens: list(filter(lambda token: token.isalpha(),  tokens)))
           .apply(lambda tokens: list(map(lambda token: token.lower(),token)))
           )
