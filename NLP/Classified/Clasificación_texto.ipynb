# %% [markdown]
# ## Clasificación de Texto.
#
# **Problemas a vencer**: La ambiguedad del lenguaje, es importante analizar el proceso de como desambiguar un texto, para evitar que varias formas de escribir o usar palabras cambia el contexto o significado.
#
# **El primer paso es identificar las categorias gramaticales**: Una categoria gramatical encierra a las palabras según su significado, existen sustantivos, adjetivos, adverbios, verbos, preposiciones, conjunciones y articulos.
#
# **Sustantivo o Nombre:** Es aquel tipo de palabra cuyo significado determina la realidad, esto es, los sustantivos nombran todas las cosas, personas objetos sensaciones, sentimientos ideas, etc.
#
# **Pronombre:** Es una palabra que sustituye a otros terminos que designan personas u objetos en momento determinado, como la, yo, tu, el, ellos, te, nos, mi, ti, este, ese, aquel, mio, tuyo... etc
#
# **Adjetivo:** Es una palabra que acompaña al nombre para determinarlo o calificarlo. Los adjetivos posesivos son los que acompañan al sustantivo y lo determinan de la siguiente forma: Mi casa, nuestro auto...
#
# ## Ambiguedades del Lenguage:
# #### Tipos:
# - **Por agrupamiento** Cómo se separan las oraciones con los signos de puntuación, un signo de puntuación en una oración cambia el significado de la oración.
# - **Funcional** Son dificiles de detectar y necesita bastante contexto, debido a que una sola oración puede significar dos cosas totalmente diferentes, según su espacio, tiempo y objetivo.
# - **Lexico**: Dependen de la categoría gramaticales, es decir una palabra puede ser interpretada como un sustantivo o un adjetivo y eso cambia el significado de la oración.
#
# **Punto Clave** ¿Cómo etiquetar adecuadamente una palabra? una respuesta corta, Dependiendo del contexto clasificar su categoria gramatical.

# %% [markdown]
# ### Etiquetado en NLTK

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\GAMER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\GAMER\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ### Etiquetado Ingles
# La libreria NLTK permite etiquetar de manera sencilla con algoritmos pre-entrenados, para el español es diferente

# %%
# Variable Texto resultado de una tokenización
text = word_tokenize('And now here I am enjoying today')
# Aplicar etiquetas gramaticales
nltk.pos_tag(text)
# Out:
# [('And', 'CC'),
#  ('now', 'RB'),
#  ('here', 'RB'),
#  ('I', 'PRP'),
#  ('am', 'VBP'),
#  ('enjoying', 'VBG'),
#  ('today', 'NN')]

# %%
# Revisar tipo de categorias gramaticales
nltk.download('tagsets')
for tag in ['CC','RB','PRP']:
    print(nltk.help.upenn_tagset(tag))
# Out:
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# None
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# None
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# None
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\GAMER\AppData\Roaming\nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!

# %%
# Ambiguedades: Palabras Homónimas
text = word_tokenize('They do not permit other people to get residence permit')
nltk.pos_tag(text)
# Out:
# [('They', 'PRP'),
#  ('do', 'VBP'),
#  ('not', 'RB'),
#  ('permit', 'VB'),
#  ('other', 'JJ'),
#  ('people', 'NNS'),
#  ('to', 'TO'),
#  ('get', 'VB'),
#  ('residence', 'NN'),
#  ('permit', 'NN')]

# %%
for tag in ['CC','RB','PRP']:
    print(nltk.help.upenn_tagset(tag))

# %% [markdown]
# ### Etiquetado Gramaticas Español

# %%
from nltk.corpus import cess_esp as cess
# Etiquetador basado en unigramas
from nltk import UnigramTagger as ut
# Etiquetador basado en bigramas
from nltk import BigramTagger as bt
from IPython.display import Image

# %%
# Entrenamiento del tagger por unigramas
cess_sents = cess.tagged_sents()
fraction = int(len(cess_sents)*90/100)

# Entrena el modelo con el 90% para etiquetar los tokens gramaticalmente
uni_tagger = ut(cess_sents[:fraction])

# Permite evaluar el modelo con el 10% de los datos
uni_tagger.evaluate(cess_sents[fraction:])
# Out:
# 0.8068832283915284

# %%
# Revisar su categoria gramatical
uni_tagger.tag("Yo soy una persona muy amable".split(" "))
# Out:
# [('Yo', 'pp1csn00'),
#  ('soy', 'vsip1s0'),
#  ('una', 'di0fs0'),
#  ('persona', 'ncfs000'),
#  ('muy', 'rg'),
#  ('amable', None)]

# %%
bi_tagger = bt(cess_sents[:fraction])
bi_tagger.evaluate(cess_sents[fraction:])
# Out:
# 0.10983113909559244

# %% [markdown]
# ### Conclusiones
# - Etiquetar por bigramas no es tan efectivo como etiquetar por unigramas, esto se debe a que no se identifica correctamente la categoría gramatical de cada token o palabra si se analiza en conjunto de dos palabras.
# - Cada modelo se debe entrenar y definir su precisión

# %% [markdown]
# ## Stanza (StanfordNLP)

# %%
# !pip install stanza
# Out:
# Collecting stanza
#   Downloading stanza-1.2.1-py3-none-any.whl (334 kB)
# Requirement already satisfied: protobuf in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from stanza) (3.14.0)
# Requirement already satisfied: tqdm in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from stanza) (4.61.0)
# Requirement already satisfied: numpy in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from stanza) (1.19.2)
# Collecting torch>=1.3.0
#   Downloading torch-1.9.0-cp38-cp38-win_amd64.whl (222.0 MB)
# Requirement already satisfied: requests in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from stanza) (2.25.1)
# Requirement already satisfied: typing-extensions in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from torch>=1.3.0->stanza) (3.7.4.3)
# Requirement already satisfied: six>=1.9 in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from protobuf->stanza) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from requests->stanza) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from requests->stanza) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from requests->stanza) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gamer\anaconda3\envs\dataanalyst\lib\site-packages (from requests->stanza) (2.10)
# Installing collected packages: torch, stanza
# Successfully installed stanza-1.2.1 torch-1.9.0

# %%
import stanza

# %%
stanza.download('es')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.2.1.json:   0%|   …
# 2021-06-30 19:31:30 INFO: Downloading default packages for language: es (Spanish)...
# Downloading http://nlp.stanford.edu/software/stanza/1.2.1/es/default.zip:   0%|          | 0.00/566M [00:00<?,…
# 2021-06-30 19:42:33 INFO: Finished downloading models and saved to C:\Users\GAMER\stanza_resources.

# %% [markdown]
# **Stanza** trabaja con flujos de procesos para el lenguaje natural, a continuación se define un Pipeline el cual tokeniza un texto y asigna etiquetas gramaticales que es lo mismo que etiquetar las partes del discurso.

# %%
nlp = stanza.Pipeline('es',precessors= 'tokenize,pos')
doc = nlp('Yo soy una persona muy amable')
# Out:
# 2021-07-01 22:11:10 INFO: Loading these models for language: es (Spanish):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | ancora  |
# | mwt       | ancora  |
# | pos       | ancora  |
# | lemma     | ancora  |
# | depparse  | ancora  |
# | ner       | conll02 |
# =======================
#
# 2021-07-01 22:11:10 INFO: Use device: cpu
# 2021-07-01 22:11:10 INFO: Loading: tokenize
# 2021-07-01 22:11:10 INFO: Loading: mwt
# 2021-07-01 22:11:10 INFO: Loading: pos
# 2021-07-01 22:11:11 INFO: Loading: lemma
# 2021-07-01 22:11:11 INFO: Loading: depparse
# 2021-07-01 22:11:11 INFO: Loading: ner
# 2021-07-01 22:11:13 INFO: Done loading processors!

# %%
for sentence in doc.sentences:
    for word in sentence.words:
        print(word.text, word.pos)
# Out:
# Yo PRON
# soy AUX
# una DET
# persona NOUN
# muy ADV
# amable ADJ

# %% [markdown]
# Los dos paquetes 'punkt': Es un tokenizador y el averaged_perceptron es el etiquetador por defecto que usa por defecto nltk cuando estamos en el idioma ingles.
#
# El etiquetador del perceptron promediado, esta relacionado con el funcionamiento de una red neuronal, antes de este modelo, solamente existian modelos de maxima entropia y estan muy relacionados con las regresiones logisticas.
#
# Con la salida de este modelo se evidenció una mejora considerable en el rendimiento así el APT se convirtio en estandar. aunque existen muchos etiquetadores de clasificación, sin embargo esta no deja de ser la base de todo el universo de etiquetadores.
#
# ![title](./modelos.PNG)
#
# # Modelo Markoviano Latente
# Esta basado en las cadenas de markov, y son la base que nos van a ayudar a entender los modelos markovianos de maxima entropia

# %% [markdown]
# Primero es importante entender que es una cadena de markov, una cadena de marcov esta basada en un conjunto finito de estados, es decir, podemos pensar en una situación a la cual se le puede asignar una serie de diferentes categorias, por ejemplo, el estado de un día, porque en la secuencia dia a dia se le puede asignar estados como frio, caluro, lluvioso. etc.
#
# Ahora, para definir el sistema es necesario identificar de ese día cuantos posibles estados puede tener (frio, caliente...) y luego se define una secuencia, es decir, día uno, día dos... y de ello se puede definir una secuencia que son los estados de esa secuencia.
#
# Ahora, el sistema de las cadenas de markov miden la probabilidad entre las secuencias, de que un estado en una parte de esa secuencia se de despues de otro estado en otra parte de esa secuencia.
#
# es decir, la probabilidad de que un día frio este seguido de un día caliente, la probabilidad de que un dia caliente este dado despues de un dia frio, cada uno de ellos se define como una transición, es decir la transición es el paso entre eventos y todas esas flechas que conectan entre ellos son calculos de la probabilidad.
#
# ![](.\cadena.PNG)
#
# Por ejemplo, en el evento donde se ve una secuencia de dias: Soleado, frio, frio, Soleado y frio, solo hay dos situacioes en las que un día soleado esta seguido de un día frio, ahora se calculan las probabilidades de todas estas transiciones y las dividimos entre todos los eventos posibles de transición.

# %% [markdown]
# Una cadena de Markov define probabilidades de transición entre los posibles estados que puede tener una transición, a esto se le define como matriz de transición.
# ![](.\matriz.PNG)

# %% [markdown]
# **Componente escencial en la cadena de markov** Distribución inicial de estados, es el vector que se nombra como la letra PI II(0) el cual tiene 3 componentes en este ejemplo, definen la probabilidad inicial de que un día sea frio o caliente o tibio, y lo que se realiza es una multiplicacion entre la matriz de transición por el vector inicial de estados y el resultado es el vector inicial de estados PI II(1)
#
# ![](.\vector.PNG)

# %% [markdown]
# **¿Cómo se calcula la probabilidad en un transición?** El calculo podría considerarse como frecuentista, se verifican por ejemplo, en el caso de calcular la probabilidad de que se de un día soleado seguido de un día frio, es calcular cuantas veces se presenta en el espacio muestral y dividirlo entre la totalidad de elementos dentro del espacio muestral
#
# A la final, un modelo markoviano latente es un sistema de probabilidades que evoluciona a medida que va avanzando en sus secuencias o estados.

# %% [markdown]
# ## Modelo Markoviano Latente
# A = Matriz de transición de estados - Es decir una matriz que confronta todos los estados para identificar la probabilidad de transición entre cada uno de ellos
#
# Pi = Vector de la distribución de estados - Si hoy la probabilidad de que llueva es de % y así... por cada uno de los estados, al multiplicarse con la matriz nos retorna la probabilidad de los estados pero para la siguiente secuencia o transición.
#
# $$
# \Pi^{(0)}A = \Pi^{(1)}
# $$

# %% [markdown]
# *Es importante definir el concepto de probabilidad condicional*
#
# $$
# P(j|i) = \frac{P(i,j)}{p(i)}
# $$
#
# **Ejemplo**: *Probabilidad de Transición estando en el estado 3 al día siguiente sea estado 2*
#
# $$
# P(2|3) = \frac{P(3,2)}{P(3)}
# $$
#
# La probabilidad de que un día este en estado 3 y al día siguiente sea estado 2 se calcula verificando la frecuencia en la que se presenta esta evento dentro del espacio muestral
#
# La probabilidad de dias iniciales son todos los días que anteceden un estado
#
# $$
# P(3,2) = \frac{1}{5}
# $$
# $$
# P(3) = \frac{1}{5}
# $$
# $$
# P(2|3) = 1
# $$
#
# Este resultado es el que se asigna a la matriz de probabilidades de transición.

# %% [markdown]
# **LOS ESTADOS DE MARKOV SE DEFINEN POR EL ESTADO INMEDIATAMENTE ANTERIOR** Por tanto la matriz de estas se debe multiplicar por el vector de estado inicial para encontral el vector de probabilidades de estados de la siguiente transición
#
# ![](.\operacion.PNG)

# %% [markdown]
# ## Extrapolar en NLP los modelos markovianos latentes
#
# **Pensemos en secuencias de palabras** de la siguiente forma, una secuencia de palabras es igual a una secuencia de etiquetas gramaticales
#
# A la secuencia gramaticas se le llama secuencia latente u oculta por que al principio no la conocemos.
#
# ![](.\palabras.PNG)

# %% [markdown]
# ## Entrenar un Modelo Markoviano Latente
#
# Descubrir esa secuencia de etiquetas, que le corresponde a la secuencia de palabras, los estados serían las categorias gramaticales.
#
# Las probabilidades se calculan con un corpus de palabras, es decir la probabilidad de dada una categoria gramatical, cual es la probabilidad de que le corresponda una cierta palabra. y se llaman:
#
# Probabilidades de emición: se puede calcular una por cada node de la cadena markoviana.
#
# ![](.\markov.PNG)

# %% [markdown]
# A: Matriz de transición
# Pi: Distribución de estados
# B: Probabilidades de emisión corresponden a *dadas las categorias cuales son las probabilidades de que les correspondan o sean asignadas a ciertas palabras*
#
# $$
#     arg max_{(t^n)}P(t^n|w^n)
# $$
#
# ![](.\argumentos.PNG)

# %% [markdown]
# En resumen el modelo de markov se encarga de encontrar, dada una secuencia de palabras, una secuencia de etiquetas que le corresponde con mayor probabilidad.
#
# Es importante tener en cuenta la regla de bayes:
# $$
# P(t|w) = \frac{P(w|t)P(t)}{p(w)}
# $$
#
# De esta manera el modelo tendrá que calcular la probabilidad de una secuencia de palabras dada una secuencia de etiquetas^bajo el teorema de bayes:
#
# $$
# P(t^n|w^n) = \frac{P(w^n|t^n)P(t^n)}{P(w^n)}
# $$
#
# Entendiendo el concepto de sin perdida de generalidad se puede despreciar el denominador, debido a que la comparación de resultados se mantendrá en un mismo orden y no se alterará el resultado final.
#
# $$
# \bar{t^n} = argmax_{t^n}P(t^n|w^n) = argmax_{t^n}P(w^n|t^n)P(t^n)
# $$

# %% [markdown]
# ### Hipotesis
# - Hip. de independiencia: Las probabilidades condicionales de que dadas unas etiquetas les correspondan unas palabras, se representan como el producto de cada probabilidad condicional de cada etiqueta correspondiente a una palabra. o de cada palabra con su etiqueta correspondiente. Las probabilidades de palabras a etiquetas solamente dependen de la misma posición
#
#
# $$
# P(w^n|t^n) = \prod_{i=1}^nP(w_i|t_i)
# $$
#
#
# - Hip. Markoviana: Permite identificar cual es el contexto que rodea a la secuencia de palabras, ya que identifica el momento en el que se asigna cada etiqueta a cada palabra, esto se resume en la probabilidad de secuencia de etiquetas que es lo mismo que un producto de probabilidades de que dada una etiqueta anterior le corresponda le corresponda una etiqueta en la posición actual, un producto entre todas las probabilidades según la cantidad de secuencias. Un estado depende de un estado inmediatamente anterior.
#
# $$
# P(t^n) = \prod_{i=1}^nP(t_i|t_{i-1})
# $$
#
# En resumen las probabilidades que calcula un modelo markoviano se originan gracias a la combinación de estas dos hipotesis:
#
# $$
# \bar{t^n} = argmax_{t^n}\prod_{i=1}^nP(w_i|t_i)P(t_i,t_{i-1})
# $$

# %% [markdown]
# ## Corpus de español:
#
# * AnCora | Github: https://github.com/UniversalDependencies/UD_Spanish-AnCora
#
# * usamos el conllu parser para leer el corpus: https://pypi.org/project/conllu/
#
# * Etiquetas Universal POS (Documentación): https://universaldependencies.org/u/pos/

# %%
# !git clone https://github.com/UniversalDependencies/UD_Spanish-AnCora.git
# Out:
# Cloning into 'UD_Spanish-AnCora'...

# %% [markdown]
# **parse_incr** Genera una lista de listas de tokens
# **.setialize** una tributo del formato conllu

# %%
from conllu import parse_incr

wordList = []
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

# for tokenlist in parse_incr(data_file):
#     print(tokenlist.serialize())

# %% [markdown]
# ## Entrenamiento del modelo - Calculo de conteos:
#
# * tags (tags) `tagCountDict`: $C(tag)$
# * emisiones (word|tag) `emissionProbDict`: $C(word|tag)$
# * transiciones (tag|prevtag) `transitionDict`: $C(tag|prevtag)$

# %%
tagCountDict = {}
emissionDict = {}
transitionDict = {}

tagtype = 'upos'
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

for tokenlist in parse_incr(data_file):
    prevtag = None
    for token in tokenlist:   
        
        # C(tag): Cuantas veces aparece una etiqueta en el corpus
        tag = token[tagtype]
        
        if tag in tagCountDict.keys():
            tagCountDict[tag] += 1
        else:
            tagCountDict[tag] = 1
        
        # C(word|tag) Calculo para las probabilidades de emisión. Contar cuantas veces aparece una etiqueta dado una palabra
        # En el corpus
        wordtag = token['form'].lower()+'|'+token[tagtype]
        if wordtag in emissionDict.keys():
            emissionDict[wordtag] += 1
        else:
            emissionDict[wordtag] = 1
            
        # C(tag|tag_previo) Conteo para Probabilidades de transición
        if prevtag is None:
            prevtag = tag
            continue
        transitiontags = tag+'|'+prevtag
        if transitiontags in transitionDict.keys():
            transitionDict[transitiontags] = transitionDict[transitiontags] + 1
        else:
            transitionDict[transitiontags] = 1
        prevtag = tag

# %% [markdown]
# ## Entrenamiento del modelo - calculo de probabilidades
#
#
# * **probabilidades de transición:** Se calcula contando las veces que yo observo esas etiquetas, la actual y la previa, dividida en las veces que yo observo la etiqueta anterior en el corpus, este resultado se define como la probabilidad de que se de una etiqueta dado que ya ocurrio una etiqueta previa.
#
# $$P(tag|prevtag) = \frac{C(prevtag, tag)}{C(prevtag)}$$
#
# * **probabilidades de emisión:** La probabilidad de que se de una palabra una vez se le asigno una etiqueta. se calcula con el numero de veces que yo veo la palabra con su etiqueta sobre las veces que veo la etiqueta
#  $$P(word|tag) = \frac{C(word|tag)}{C(tag)}$$

# %%
transitionProbDict = {}
emissionProbDict = {}

# transition Probabilities

for key in transitionDict.keys():
    tag,prevtag = key.split('|')
    if tagCountDict[prevtag] > 0:
        transitionProbDict[key] = transitionDict[key] / (tagCountDict[prevtag])
    else: 
        print(key)

# Emission Probabilities
for key in emissionDict.keys():
    word,tag = key.split('|')
    if emissionDict[key] > 0:
        emissionProbDict[key] = emissionDict[key] / tagCountDict[tag]
    else: 
        print(key)

# %%
sorted(emissionProbDict.items(),key=lambda x: x[1],reverse=True)
# Out:
# [('no|PART', 1.0),
#  ('sí|INTJ', 0.8),
#  ('y|CCONJ', 0.7771664374140302),
#  ('que|SCONJ', 0.6382042253521126),
#  ('del|_', 0.5839936608557845),
#  ('de|ADP', 0.4614572333685322),
#  (',|PUNCT', 0.45316979929913986),
#  ('el|DET', 0.3435285341290563),
#  ('que|PRON', 0.32481450948062657),
#  ('al|_', 0.2765451664025357),
#  ('.|PUNCT', 0.2642561325262823),
#  ('se|PRON', 0.2485572959604287),
#  ('la|DET', 0.23287330598035558),
#  ('no|ADV', 0.1848086124401914),
#  ("'|SYM", 0.18181818181818182),
#  ('es|AUX', 0.16538461538461538),
#  ('ha|AUX', 0.15384615384615385),
#  ('en|ADP', 0.15252845242285581),
#  ('a|ADP', 0.15205913410770855),
#  ('"|PUNCT', 0.14319847085058937),
#  ('como|SCONJ', 0.13380281690140844),
#  ('dos|NUM', 0.11657142857142858),
#  ('más|ADV', 0.1034688995215311),
#  ('ay|INTJ', 0.1),
#  ('no|INTJ', 0.1),
#  ('los|DET', 0.09958970533383066),
#  ('pero|CCONJ', 0.08321870701513068),
#  ('lo|PRON', 0.07914262159934048),
#  ('60%|SYM', 0.06818181818181818),
#  ('20%|SYM', 0.06818181818181818),
#  ('o|CCONJ', 0.06808803301237965),
#  ('un|DET', 0.06738779062538854),
#  ('las|DET', 0.06626880517219942),
#  ('si|SCONJ', 0.06426056338028169),
#  ('por|ADP', 0.05972075560248739),
#  ('fue|AUX', 0.05307692307692308),
#  ('porque|SCONJ', 0.0528169014084507),
#  ('con|ADP', 0.051977003402557787),
#  ('han|AUX', 0.04923076923076923),
#  ('ya|ADV', 0.04844497607655503),
#  ('tres|NUM', 0.048),
#  ('también|ADV', 0.045454545454545456),
#  ('4%|SYM', 0.045454545454545456),
#  ('70%|SYM', 0.045454545454545456),
#  ('50%|SYM', 0.045454545454545456),
#  ('89%|SYM', 0.045454545454545456),
#  ('25%|SYM', 0.045454545454545456),
#  ('18%|SYM', 0.045454545454545456),
#  ('una|DET', 0.045008081561606364),
#  ('-|PUNCT', 0.04380375915896782),
#  ('su|DET', 0.04351610095735422),
#  ('ciento|NUM', 0.04342857142857143),
#  ('para|ADP', 0.043059955414760064),
#  ('le|PRON', 0.04204451772464963),
#  ('ayer|ADV', 0.041866028708133975),
#  ('hoy|ADV', 0.04066985645933014),
#  ('cuando|SCONJ', 0.03873239436619718),
#  ('(|PUNCT', 0.03488372093023256),
#  (')|PUNCT', 0.034724434533290854),
#  ('aunque|SCONJ', 0.03345070422535211),
#  ('son|AUX', 0.03307692307692308),
#  ('ser|AUX', 0.031538461538461536),
#  ('cuatro|NUM', 0.029714285714285714),
#  ('sólo|ADV', 0.02930622009569378),
#  ('muy|ADV', 0.028708133971291867),
#  ('hay|AUX', 0.027692307692307693),
#  ('cinco|NUM', 0.027428571428571427),
#  ('puede|AUX', 0.026153846153846153),
#  ('está|AUX', 0.026153846153846153),
#  ('había|AUX', 0.026153846153846153),
#  ('ahora|ADV', 0.025717703349282296),
#  ('e|CCONJ', 0.024759284731774415),
#  ('sido|AUX', 0.024615384615384615),
#  ('así|ADV', 0.023923444976076555),
#  ('seis|NUM', 0.022857142857142857),
#  ('2%|SYM', 0.022727272727272728),
#  ('2,4%|SYM', 0.022727272727272728),
#  ('15,4%|SYM', 0.022727272727272728),
#  ('8,7%|SYM', 0.022727272727272728),
#  ('1,4%|SYM', 0.022727272727272728),
#  ('70,1%|SYM', 0.022727272727272728),
#  ('78,2%|SYM', 0.022727272727272728),
#  ('17,1%|SYM', 0.022727272727272728),
#  ('24,5%|SYM', 0.022727272727272728),
#  ('40%|SYM', 0.022727272727272728),
#  ('74%|SYM', 0.022727272727272728),
#  ('16%|SYM', 0.022727272727272728),
#  ('20,4%|SYM', 0.022727272727272728),
#  ('2,5%|SYM', 0.022727272727272728),
#  ('80%|SYM', 0.022727272727272728),
#  ('4,03%|SYM', 0.022727272727272728),
#  ('22,42%|SYM', 0.022727272727272728),
#  ('30%|SYM', 0.022727272727272728),
#  ('era|AUX', 0.022307692307692306),
#  ('nos|PRON', 0.021846661170651278),
#  ('después|ADV', 0.020933014354066987),
#  ('haber|AUX', 0.02076923076923077),
#  ('ni|CCONJ', 0.019944979367262722),
#  ('siempre|ADV', 0.017344497607655503),
#  ('sus|DET', 0.017282108665920677),
#  ('siete|NUM', 0.017142857142857144),
#  ('bien|ADV', 0.016148325358851676),
#  ('gobierno|PROPN', 0.016057312252964428),
#  ('mientras|SCONJ', 0.01584507042253521),
#  ('menos|ADV', 0.01555023923444976),
#  ('les|PRON', 0.015251442704039572),
#  ('según|SCONJ', 0.014964788732394365),
#  ('quien|PRON', 0.01483924154987634),
#  ('será|AUX', 0.014615384615384615),
#  ('además|ADV', 0.014354066985645933),
#  ('debe|AUX', 0.013846153846153847),
#  ('pueden|AUX', 0.013846153846153847),
#  ('30|NUM', 0.013714285714285714),
#  ('me|PRON', 0.013602638087386645),
#  ('poco|ADV', 0.013157894736842105),
#  ('antes|ADV', 0.013157894736842105),
#  ('uno|PRON', 0.012778235779060182),
#  ('dijo|VERB', 0.01277167824333408),
#  ('casi|ADV', 0.012559808612440191),
#  ('sino|CCONJ', 0.012379642365887207),
#  ('madrid|PROPN', 0.012351778656126482),
#  ('están|AUX', 0.012307692307692308),
#  ('primer|ADJ', 0.012143462298785653),
#  ('este|DET', 0.01206017655103817),
#  ('la|PRON', 0.011953833470733718),
#  ('tiene|VERB', 0.011875420120994847),
#  ('pasado|ADJ', 0.011861056198813894),
#  ('entre|ADP', 0.01149829872110759),
#  ('16|NUM', 0.011428571428571429),
#  ('15|NUM', 0.011428571428571429),
#  ('10|NUM', 0.011428571428571429),
#  ('todo|PRON', 0.011129431162407255),
#  ('va|AUX', 0.010769230769230769),
#  ('haya|AUX', 0.010769230769230769),
#  ('he|AUX', 0.010769230769230769),
#  ('aún|ADV', 0.01076555023923445),
#  ('donde|PRON', 0.010717230008244023),
#  ('esta|DET', 0.010568195946786025),
#  ('mientras|CCONJ', 0.01031636863823934),
#  ('él|PRON', 0.010305028854080791),
#  ('18|NUM', 0.010285714285714285),
#  ('quince|NUM', 0.010285714285714285),
#  ('2|NUM', 0.010285714285714285),
#  ('mucho|ADV', 0.010167464114832535),
#  ('fueron|AUX', 0.01),
#  ('sobre|ADP', 0.009973014196879033),
#  ('deben|AUX', 0.009230769230769232),
#  ('estar|AUX', 0.009230769230769232),
#  ('podría|AUX', 0.009230769230769232),
#  ('estamos|AUX', 0.009230769230769232),
#  ('habían|AUX', 0.009230769230769232),
#  ('hace|VERB', 0.009186645753977145),
#  ('17|NUM', 0.009142857142857144),
#  ('22|NUM', 0.009142857142857144),
#  ('ocho|NUM', 0.009142857142857144),
#  ('24|NUM', 0.009142857142857144),
#  ('nada|PRON', 0.009068425391591096),
#  ('eso|PRON', 0.009068425391591096),
#  ('primera|ADJ', 0.009036995199096301),
#  ('nunca|ADV', 0.008971291866028708),
#  ('desde|ADP', 0.008799718409010912),
#  (':|PUNCT', 0.008760751831793565),
#  ('españa|PROPN', 0.008646245059288538),
#  ('hacer|VERB', 0.00851445216222272),
#  ('sería|AUX', 0.008461538461538461),
#  ('tanto|ADV', 0.008373205741626795),
#  ('luego|ADV', 0.008373205741626795),
#  ('anoche|ADV', 0.008373205741626795),
#  ('sin|ADP', 0.008330400093863663),
#  ('nuevo|ADJ', 0.008189776899181022),
#  ('barcelona|PROPN', 0.008152173913043478),
#  ('25|NUM', 0.008),
#  ('ambos|NUM', 0.008),
#  ('2000|NUM', 0.008),
#  ('12|NUM', 0.008),
#  ('20|NUM', 0.008),
#  ('diez|NUM', 0.008),
#  ('hasta|ADP', 0.007978411357503226),
#  ('contra|ADP', 0.007978411357503226),
#  ('algo|PRON', 0.007831821929101401),
#  ('mañana|ADV', 0.00777511961722488),
#  ('tan|ADV', 0.00777511961722488),
#  ('incluso|ADV', 0.00777511961722488),
#  ('años|NOUN', 0.007190496040016673),
#  ('entonces|ADV', 0.007177033492822967),
#  ('adelante|ADV', 0.007177033492822967),
#  ('español|ADJ', 0.007060152499293985),
#  ('pues|SCONJ', 0.007042253521126761),
#  ('unos|PRON', 0.007007419620774938),
#  ('millones|NOUN', 0.006982075864943727),
#  ('estaba|AUX', 0.006923076923076923),
#  ('pueda|AUX', 0.006923076923076923),
#  ('podrán|AUX', 0.006923076923076923),
#  ('28|NUM', 0.006857142857142857),
#  ('ambas|NUM', 0.006857142857142857),
#  ('60|NUM', 0.006857142857142857),
#  ('100|NUM', 0.006857142857142857),
#  ('50|NUM', 0.006857142857142857),
#  ('2-1|NUM', 0.006857142857142857),
#  ('1999|NUM', 0.006857142857142857),
#  ('7|NUM', 0.006857142857142857),
#  ('31|NUM', 0.006857142857142857),
#  ('pnv|PROPN', 0.0066699604743083),
#  ('mayor|ADJ', 0.006495340299350466),
#  ('gran|ADJ', 0.006495340299350466),
#  ('presidente|NOUN', 0.006356815339724885),
#  ('política|ADJ', 0.006212934199378707),
#  ('los|PRON', 0.006183017312448475),
#  ('una|PRON', 0.006183017312448475),
#  ('real|PROPN', 0.006175889328063241),
#  ('hubo|AUX', 0.006153846153846154),
#  ('sea|AUX', 0.006153846153846154),
#  ('eran|AUX', 0.006153846153846154),
#  ('tampoco|ADV', 0.005980861244019139),
#  ('todavía|ADV', 0.005980861244019139),
#  ('general|ADJ', 0.005930528099406947),
#  ('aseguró|VERB', 0.005825677795205019),
#  ('qué|PRON', 0.005770816158285243),
#  ('partido|NOUN', 0.005731554814506044),
#  ('miles|NUM', 0.005714285714285714),
#  ('21|NUM', 0.005714285714285714),
#  ('nou|NUM', 0.005714285714285714),
#  ('27|NUM', 0.005714285714285714),
#  ('49|NUM', 0.005714285714285714),
#  ('3|NUM', 0.005714285714285714),
#  ('13|NUM', 0.005714285714285714),
#  ('2001|NUM', 0.005714285714285714),
#  ('11|NUM', 0.005714285714285714),
#  ('95|NUM', 0.005714285714285714),
#  ('23|NUM', 0.005714285714285714),
#  ('1-0|NUM', 0.005714285714285714),
#  ('josé|PROPN', 0.005681818181818182),
#  ('electoral|ADJ', 0.005648121999435188),
#  ('mejor|ADJ', 0.005648121999435188),
#  (';|PUNCT', 0.0055750238929595415),
#  ('ante|ADP', 0.005514490202980171),
#  ('estado|PROPN', 0.005434782608695652),
#  ('psoe|PROPN', 0.005434782608695652),
#  ('equipo|NOUN', 0.005418924551896623),
#  ('podía|AUX', 0.005384615384615384),
#  ('estado|AUX', 0.005384615384615384),
#  ('lejos|ADV', 0.005382775119617225),
#  ('cerca|ADV', 0.005382775119617225),
#  ('dentro|ADV', 0.005382775119617225),
#  ('nosotros|PRON', 0.0053586150041220115),
#  ('esto|PRON', 0.0053586150041220115),
#  ('nueva|ADJ', 0.005083309799491669),
#  ('nadie|PRON', 0.00494641384995878),
#  ('ellos|PRON', 0.00494641384995878),
#  ('según|ADP', 0.004927842309046111),
#  ('grandes|ADJ', 0.0048009036995199095),
#  ('país|NOUN', 0.004793664026677783),
#  ('delante|ADV', 0.004784688995215311),
#  ('frente|ADV', 0.004784688995215311),
#  ('liga|PROPN', 0.004693675889328063),
#  ('eta|PROPN', 0.004693675889328063),
#  ('pp|PROPN', 0.004693675889328063),
#  ('hemos|AUX', 0.004615384615384616),
#  ('habría|AUX', 0.004615384615384616),
#  ('siendo|AUX', 0.004615384615384616),
#  ('pudieron|AUX', 0.004615384615384616),
#  ('van|AUX', 0.004615384615384616),
#  ('deberán|AUX', 0.004615384615384616),
#  ('10.000|NUM', 0.004571428571428572),
#  ('1|NUM', 0.004571428571428572),
#  ('4|NUM', 0.004571428571428572),
#  ('medio|NUM', 0.004571428571428572),
#  ('once|NUM', 0.004571428571428572),
#  ('33|NUM', 0.004571428571428572),
#  ('6.000|NUM', 0.004571428571428572),
#  ('las|PRON', 0.004534212695795548),
#  ('ministro|NOUN', 0.004481033764068362),
#  ('copa|PROPN', 0.004446640316205534),
#  ('barak|PROPN', 0.004446640316205534),
#  ('?|PUNCT', 0.004300732717425932),
#  ('año|NOUN', 0.004272613588995415),
#  ('tuvo|VERB', 0.00425722608111136),
#  ('últimos|ADJ', 0.004236091499576391),
#  ('actual|ADJ', 0.004236091499576391),
#  ('próximo|ADJ', 0.004236091499576391),
#  ('socialista|ADJ', 0.004236091499576391),
#  ('tras|ADP', 0.004223864836325237),
#  ('partido|PROPN', 0.004199604743083004),
#  ('aquí|ADV', 0.004186602870813397),
#  ('actualmente|ADV', 0.004186602870813397),
#  ('especialmente|ADV', 0.004186602870813397),
#  ('asimismo|ADV', 0.004186602870813397),
#  ('te|PRON', 0.004122011541632316),
#  ('ella|PRON', 0.004122011541632316),
#  ('durante|ADP', 0.004106535257538425),
#  ('posible|ADJ', 0.003953685399604632),
#  ('ue|PROPN', 0.003952569169960474),
#  ('esa|DET', 0.003854283227651374),
#  ('vamos|AUX', 0.0038461538461538464),
#  ('debería|AUX', 0.0038461538461538464),
#  ('habrá|AUX', 0.0038461538461538464),
#  ('somos|AUX', 0.0038461538461538464),
#  ('¿|PUNCT', 0.003822873526600828),
#  ('añadió|VERB', 0.003809097019941743),
#  ('explicó|VERB', 0.003809097019941743),
#  ('hecho|VERB', 0.003809097019941743),
#  ('sigue|VERB', 0.003809097019941743),
#  ('parece|VERB', 0.003809097019941743),
#  ('sí|PRON', 0.003709810387469085),
#  ('otros|PRON', 0.003709810387469085),
#  ('yo|PRON', 0.003709810387469085),
#  ('quienes|PRON', 0.003709810387469085),
#  ('aznar|PROPN', 0.0037055335968379445),
#  ('europa|PROPN', 0.0037055335968379445),
#  ('francia|PROPN', 0.0037055335968379445),
#  ('rusia|PROPN', 0.0037055335968379445),
#  ('catalunya|PROPN', 0.0037055335968379445),
#  ('único|ADJ', 0.0036712792996328723),
#  ('junto|ADJ', 0.0036712792996328723),
#  ('vez|NOUN', 0.0036473530637765737),
#  ('bastante|ADV', 0.0035885167464114833),
#  ('apenas|ADV', 0.0035885167464114833),
#  ('prácticamente|ADV', 0.0035885167464114833),
#  ('conseguir|VERB', 0.003585032489356935),
#  ('tienen|VERB', 0.003585032489356935),
#  ('mercado|NOUN', 0.0035431429762401),
#  ('balaguer|PROPN', 0.003458498023715415),
#  ('líder|NOUN', 0.0034389328887036263),
#  ('60.000|NUM', 0.0034285714285714284),
#  ('46|NUM', 0.0034285714285714284),
#  ('93|NUM', 0.0034285714285714284),
#  ('300|NUM', 0.0034285714285714284),
#  ('1.000|NUM', 0.0034285714285714284),
#  ('400|NUM', 0.0034285714285714284),
#  ('3.000|NUM', 0.0034285714285714284),
#  ('26|NUM', 0.0034285714285714284),
#  ('32|NUM', 0.0034285714285714284),
#  ('19|NUM', 0.0034285714285714284),
#  ('2-2|NUM', 0.0034285714285714284),
#  ('nueve|NUM', 0.0034285714285714284),
#  ('500|NUM', 0.0034285714285714284),
#  ('3,5|NUM', 0.0034285714285714284),
#  ('6|NUM', 0.0034285714285714284),
#  ('3-1|NUM', 0.0034285714285714284),
#  ('9|NUM', 0.0034285714285714284),
#  ('5.000|NUM', 0.0034285714285714284),
#  ('segundo|ADJ', 0.003388873199661113),
#  ('última|ADJ', 0.003388873199661113),
#  ('segunda|ADJ', 0.003388873199661113),
#  ('francés|ADJ', 0.003388873199661113),
#  ('internacional|ADJ', 0.003388873199661113),
#  ('principales|ADJ', 0.003388873199661113),
#  ('últimas|ADJ', 0.003388873199661113),
#  ('vasco|ADJ', 0.003388873199661113),
#  ('hizo|VERB', 0.0033609679587721262),
#  ('otros|DET', 0.0033569563595673255),
#  ('muchos|PRON', 0.0032976092333058533),
#  ('ello|PRON', 0.0032976092333058533),
#  ('elecciones|NOUN', 0.0032305127136306793),
#  ('congreso|PROPN', 0.0032114624505928855),
#  ('ibarretxe|PROPN', 0.0032114624505928855),
#  ('indicó|VERB', 0.003136903428187318),
#  ('puso|VERB', 0.003136903428187318),
#  ('tenido|VERB', 0.003136903428187318),
#  ('día|NOUN', 0.003126302626094206),
#  ('anterior|ADJ', 0.0031064670996893535),
#  ('necesario|ADJ', 0.0031064670996893535),
#  ('primeros|ADJ', 0.0031064670996893535),
#  ('ex|ADJ', 0.0031064670996893535),
#  ('hayan|AUX', 0.003076923076923077),
#  ('sean|AUX', 0.003076923076923077),
#  ('poder|AUX', 0.003076923076923077),
#  ('deberá|AUX', 0.003076923076923077),
#  ('pudo|AUX', 0.003076923076923077),
#  ('serán|AUX', 0.003076923076923077),
#  ('estará|AUX', 0.003076923076923077),
#  ('días|NOUN', 0.0030220925385577324),
#  ('partidos|NOUN', 0.0030220925385577324),
#  ('ni|ADV', 0.0029904306220095694),
#  ('hasta|ADV', 0.0029904306220095694),
#  ('totalmente|ADV', 0.0029904306220095694),
#  ('encima|ADV', 0.0029904306220095694),
#  ('todos|DET', 0.0029839612085042896),
#  ('comisión|PROPN', 0.0029644268774703555),
#  ('consejo|PROPN', 0.0029644268774703555),
#  ('javier|PROPN', 0.0029644268774703555),
#  ('rodríguez|PROPN', 0.0029644268774703555),
#  ('parlamento|PROPN', 0.0029644268774703555),
#  ('pesetas|NOUN', 0.0029178824510212586),
#  ('horas|NOUN', 0.0029178824510212586),
#  ('tener|VERB', 0.0029128388976025093),
#  ('dice|VERB', 0.0029128388976025093),
#  ('poner|VERB', 0.0029128388976025093),
#  ('dio|VERB', 0.0029128388976025093),
#  ('cuando|PRON', 0.0028854080791426216),
#  ('poco|PRON', 0.0028854080791426216),
#  ('otra|PRON', 0.0028854080791426216),
#  ('alguien|PRON', 0.0028854080791426216),
#  ('cual|PRON', 0.0028854080791426216),
#  ('mí|PRON', 0.0028854080791426216),
#  ('cómo|PRON', 0.0028854080791426216),
#  ('ellas|PRON', 0.0028854080791426216),
#  ('político|ADJ', 0.002824060999717594),
#  ('debido|ADJ', 0.002824060999717594),
#  ('pública|ADJ', 0.002824060999717594),
#  ('fuerte|ADJ', 0.002824060999717594),
#  ('nuevas|ADJ', 0.002824060999717594),
#  ('popular|ADJ', 0.002824060999717594),
#  ('electorales|ADJ', 0.002824060999717594),
#  ('especial|ADJ', 0.002824060999717594),
#  ('último|ADJ', 0.002824060999717594),
#  ('mismo|ADJ', 0.002824060999717594),
#  ('israelí|ADJ', 0.002824060999717594),
#  ('meses|NOUN', 0.0028136723634847854),
#  ('momento|NOUN', 0.0028136723634847854),
#  ('tiempo|NOUN', 0.0028136723634847854),
#  ('parte|NOUN', 0.0028136723634847854),
#  ('caso|NOUN', 0.0028136723634847854),
#  ('nacional|PROPN', 0.002717391304347826),
#  ('interior|PROPN', 0.002717391304347826),
#  ('europea|PROPN', 0.002717391304347826),
#  ('jospin|PROPN', 0.002717391304347826),
#  ('arzalluz|PROPN', 0.002717391304347826),
#  ('clinton|PROPN', 0.002717391304347826),
#  ('otro|DET', 0.0026109660574412533),
#  ('final|NOUN', 0.0026052521884118384),
#  ('única|ADJ', 0.0025416548997458347),
#  ('española|ADJ', 0.0025416548997458347),
#  ('principal|ADJ', 0.0025416548997458347),
#  ('buen|ADJ', 0.0025416548997458347),
#  ('europea|ADJ', 0.0025416548997458347),
#  ('judicial|ADJ', 0.0025416548997458347),
#  ('puntos|NOUN', 0.0025010421008753647),
#  ('unos|DET', 0.002486634340420241),
#  ('otro|PRON', 0.00247320692497939),
#  ('todos|PRON', 0.00247320692497939),
#  ('un|PRON', 0.00247320692497939),
#  ('ninguno|PRON', 0.00247320692497939),
#  ('algunos|PRON', 0.00247320692497939),
#  ('juan|PROPN', 0.0024703557312252965),
#  ('junta|PROPN', 0.0024703557312252965),
#  ('pld|PROPN', 0.0024703557312252965),
#  ('carlos|PROPN', 0.0024703557312252965),
#  ('país|PROPN', 0.0024703557312252965),
#  ('vasco|PROPN', 0.0024703557312252965),
#  ('mohamed|PROPN', 0.0024703557312252965),
#  ('wahid|PROPN', 0.0024703557312252965),
#  ('nyse|PROPN', 0.0024703557312252965),
#  ('celta|PROPN', 0.0024703557312252965),
#  ('josep|PROPN', 0.0024703557312252965),
#  ('mundo|PROPN', 0.0024703557312252965),
#  ('dar|VERB', 0.002464709836432893),
#  ('llegar|VERB', 0.002464709836432893),
#  ('afirmó|VERB', 0.002464709836432893),
#  ('ganar|VERB', 0.002464709836432893),
#  ('hacen|VERB', 0.002464709836432893),
#  ('da|VERB', 0.002464709836432893),
#  ('estar|VERB', 0.002464709836432893),
#  ('anunció|VERB', 0.002464709836432893),
#  ('tendrá|VERB', 0.002464709836432893),
#  ('cuenta|VERB', 0.002464709836432893),
#  ('fin|NOUN', 0.0023968320133388914),
#  ('cuando|ADV', 0.0023923444976076554),
#  ('demasiado|ADV', 0.0023923444976076554),
#  ('recién|ADV', 0.0023923444976076554),
#  ('allí|ADV', 0.0023923444976076554),
#  ('mal|ADV', 0.0023923444976076554),
#  ('ahí|ADV', 0.0023923444976076554),
#  ('pronto|ADV', 0.0023923444976076554),
#  ('inmediatamente|ADV', 0.0023923444976076554),
#  ('fuera|ADV', 0.0023923444976076554),
#  ('debajo|ADV', 0.0023923444976076554),
#  ('mayoritariamente|ADV', 0.0023923444976076554),
#  ('jamás|ADV', 0.0023923444976076554),
#  ('detrás|ADV', 0.0023923444976076554),
#  ('oficialmente|ADV', 0.0023923444976076554),
#  ('alrededor|ADV', 0.0023923444976076554),
#  ('encontrarse|_', 0.002377179080824089),
#  ('adecuarse|_', 0.002377179080824089),
#  ('producirse|_', 0.002377179080824089),
#  ('enfrentarse|_', 0.002377179080824089),
#  ('situarse|_', 0.002377179080824089),
#  ('alejarse|_', 0.002377179080824089),
#  ('referirse|_', 0.002377179080824089),
#  ('cada|DET', 0.002362302623399229),
#  ('algunos|DET', 0.002362302623399229),
#  ('esté|AUX', 0.002307692307692308),
#  ('podrá|AUX', 0.002307692307692308),
#  ('debió|AUX', 0.002307692307692308),
#  ('podido|AUX', 0.002307692307692308),
#  ('fuera|AUX', 0.002307692307692308),
#  ('pudieran|AUX', 0.002307692307692308),
#  ('estaban|AUX', 0.002307692307692308),
#  ('hubiera|AUX', 0.002307692307692308),
#  ('pudiera|AUX', 0.002307692307692308),
#  ('estoy|AUX', 0.002307692307692308),
#  ('acuerdo|NOUN', 0.0022926219258024177),
#  ('vida|NOUN', 0.0022926219258024177),
#  ('mundo|NOUN', 0.0022926219258024177),
#  ('ley|NOUN', 0.0022926219258024177),
#  ('grupo|NOUN', 0.0022926219258024177),
#  ('29|NUM', 0.002285714285714286),
#  ('4.251.218|NUM', 0.002285714285714286),
#  ('2.133.297|NUM', 0.002285714285714286),
#  ('2.117.921|NUM', 0.002285714285714286),
#  ('cientos|NUM', 0.002285714285714286),
#  ('10:00|NUM', 0.002285714285714286),
#  ('78|NUM', 0.002285714285714286),
#  ('media|NUM', 0.002285714285714286),
#  ('35|NUM', 0.002285714285714286),
#  ('mil|NUM', 0.002285714285714286),
#  ('6.097,9|NUM', 0.002285714285714286),
#  ('5|NUM', 0.002285714285714286),
#  ('59|NUM', 0.002285714285714286),
#  ('47|NUM', 0.002285714285714286),
#  ('64|NUM', 0.002285714285714286),
#  ('veinte|NUM', 0.002285714285714286),
#  ('2.12:28|NUM', 0.002285714285714286),
#  ('2-0|NUM', 0.002285714285714286),
#  ('90|NUM', 0.002285714285714286),
#  ('trece|NUM', 0.002285714285714286),
#  ('80.000|NUM', 0.002285714285714286),
#  ('16.000|NUM', 0.002285714285714286),
#  ('3-0|NUM', 0.002285714285714286),
#  ('1998|NUM', 0.002285714285714286),
#  ('5-2|NUM', 0.002285714285714286),
#  ('0-1|NUM', 0.002285714285714286),
#  ('doce|NUM', 0.002285714285714286),
#  ('75|NUM', 0.002285714285714286),
#  ('2002|NUM', 0.002285714285714286),
#  ('2005|NUM', 0.002285714285714286),
#  ('45|NUM', 0.002285714285714286),
#  ('41|NUM', 0.002285714285714286),
#  ('2.000|NUM', 0.002285714285714286),
#  ('doble|NUM', 0.002285714285714286),
#  ('72|NUM', 0.002285714285714286),
#  ('14|NUM', 0.002285714285714286),
#  ('350|NUM', 0.002285714285714286),
#  ('1.200|NUM', 0.002285714285714286),
#  ('48.000|NUM', 0.002285714285714286),
#  ('total|ADJ', 0.0022592487997740753),
#  ('social|ADJ', 0.0022592487997740753),
#  ('cuarta|ADJ', 0.0022592487997740753),
#  ('central|ADJ', 0.0022592487997740753),
#  ('democráticos|ADJ', 0.0022592487997740753),
#  ('llegó|VERB', 0.002240645305848084),
#  ('está|VERB', 0.002240645305848084),
#  ('evitar|VERB', 0.002240645305848084),
#  ('ver|VERB', 0.002240645305848084),
#  ('encontrar|VERB', 0.002240645305848084),
#  ('sufrió|VERB', 0.002240645305848084),
#  ('atlético|PROPN', 0.002223320158102767),
#  ('maría|PROPN', 0.002223320158102767),
#  ('estados|PROPN', 0.002223320158102767),
#  ('mercado|PROPN', 0.002223320158102767),
#  ('unión|PROPN', 0.002223320158102767),
#  ('pascual|PROPN', 0.002223320158102767),
#  ('parís|PROPN', 0.002223320158102767),
#  ('administración|PROPN', 0.002223320158102767),
#  ('indonesia|PROPN', 0.002223320158102767),
#  ('cúper|PROPN', 0.002223320158102767),
#  ('situación|NOUN', 0.002188411838265944),
#  ('mujeres|NOUN', 0.002188411838265944),
#  ('cuyos|PRON', 0.002061005770816158),
#  ('cuales|PRON', 0.002061005770816158),
#  ('quiere|VERB', 0.002016580775263276),
#  ('lleva|VERB', 0.002016580775263276),
#  ('seguir|VERB', 0.002016580775263276),
#  ('buscar|VERB', 0.002016580775263276),
#  ('tenemos|VERB', 0.002016580775263276),
#  ('decir|VERB', 0.002016580775263276),
#  ('llevar|VERB', 0.002016580775263276),
#  ('permite|VERB', 0.002016580775263276),
#  ('pide|VERB', 0.002016580775263276),
#  ('reconoció|VERB', 0.002016580775263276),
#  ('otra|DET', 0.0019893074723361928),
#  ('estos|DET', 0.0019893074723361928),
#  ('campaña|NOUN', 0.001979991663192997),
#  ('personas|NOUN', 0.001979991663192997),
#  ('zona|NOUN', 0.001979991663192997),
#  ('empresas|NOUN', 0.001979991663192997),
#  ('violencia|NOUN', 0.001979991663192997),
#  ('políticas|ADJ', 0.001976842699802316),
#  ('nuevos|ADJ', 0.001976842699802316),
#  ('pasada|ADJ', 0.001976842699802316),
#  ('igual|ADJ', 0.001976842699802316),
#  ('alto|ADJ', 0.001976842699802316),
#  ('local|ADJ', 0.001976842699802316),
#  ('libre|ADJ', 0.001976842699802316),
#  ('vasca|ADJ', 0.001976842699802316),
#  ('cierto|ADJ', 0.001976842699802316),
#  ('locales|ADJ', 0.001976842699802316),
#  ('previsto|ADJ', 0.001976842699802316),
#  ('nacional|ADJ', 0.001976842699802316),
#  ('comercial|ADJ', 0.001976842699802316),
#  ('democrática|ADJ', 0.001976842699802316),
#  ('políticos|ADJ', 0.001976842699802316),
#  ('exteriores|PROPN', 0.001976284584980237),
#  ('francisco|PROPN', 0.001976284584980237),
#  ('camp|PROPN', 0.001976284584980237),
#  ('nueva|PROPN', 0.001976284584980237),
#  ('san|PROPN', 0.001976284584980237),
#  ('antonio|PROPN', 0.001976284584980237),
#  ('república|PROPN', 0.001976284584980237),
#  ('efe|PROPN', 0.001976284584980237),
#  ('iber-x|PROPN', 0.001976284584980237),
#  ('schumacher|PROPN', 0.001976284584980237),
#  ('honduras|PROPN', 0.001976284584980237),
#  ('asuntos|PROPN', 0.001976284584980237),
#  ('unidos|PROPN', 0.001976284584980237),
#  ('ministerio|PROPN', 0.001976284584980237),
#  ('deportivo|PROPN', 0.001976284584980237),
#  ('marruecos|PROPN', 0.001976284584980237),
#  ('italia|PROPN', 0.001976284584980237),
#  ('benegas|PROPN', 0.001976284584980237),
#  ('generalitat|PROPN', 0.001976284584980237),
#  ('pujol|PROPN', 0.001976284584980237),
#  ('jugadores|NOUN', 0.0018757815756565235),
#  ('posibilidad|NOUN', 0.0018757815756565235),
#  ('hora|NOUN', 0.0018757815756565235),
#  ('victoria|NOUN', 0.0018757815756565235),
#  ('calle|NOUN', 0.0018757815756565235),
#  ('ese|DET', 0.001864975755315181),
#  ('estas|DET', 0.001864975755315181),
#  ('claro|ADV', 0.0017942583732057417),
#  ('quizá|ADV', 0.0017942583732057417),
#  ('atrás|ADV', 0.0017942583732057417),
#  ('posteriormente|ADV', 0.0017942583732057417),
#  ('allá|ADV', 0.0017942583732057417),
#  ('recientemente|ADV', 0.0017942583732057417),
#  ('primero|ADV', 0.0017942583732057417),
#  ('sabe|VERB', 0.0017925162446784674),
#  ('tenía|VERB', 0.0017925162446784674),
#  ('ir|VERB', 0.0017925162446784674),
#  ('supone|VERB', 0.0017925162446784674),
#  ('encontraba|VERB', 0.0017925162446784674),
#  ('explica|VERB', 0.0017925162446784674),
#  ('jugar|VERB', 0.0017925162446784674),
#  ('consideró|VERB', 0.0017925162446784674),
#  ('mantener|VERB', 0.0017925162446784674),
#  ('entrar|VERB', 0.0017925162446784674),
#  ('manifestó|VERB', 0.0017925162446784674),
#  ('insistió|VERB', 0.0017925162446784674),
#  ('comicios|NOUN', 0.00177157148812005),
#  ('países|NOUN', 0.00177157148812005),
#  ('carrera|NOUN', 0.00177157148812005),
#  ('domingo|NOUN', 0.00177157148812005),
#  ('forma|NOUN', 0.00177157148812005),
#  ('lugar|NOUN', 0.00177157148812005),
#  ('minutos|NOUN', 0.00177157148812005),
#  ('ciudad|NOUN', 0.00177157148812005),
#  ('política|NOUN', 0.00177157148812005),
#  ('respecto|NOUN', 0.00177157148812005),
#  ('oposición|NOUN', 0.00177157148812005),
#  ('rey|NOUN', 0.00177157148812005),
#  ('todo|DET', 0.0017406440382941688),
#  ('dominicana|PROPN', 0.0017292490118577075),
#  ('fernández|PROPN', 0.0017292490118577075),
#  ('medina|PROPN', 0.0017292490118577075),
#  ('serviá|PROPN', 0.0017292490118577075),
#  ('gil|PROPN', 0.0017292490118577075),
#  ('spanair|PROPN', 0.0017292490118577075),
#  ('redondo|PROPN', 0.0017292490118577075),
#  ('euskadi|PROPN', 0.0017292490118577075),
#  ('sevilla|PROPN', 0.0017292490118577075),
#  ('ibarra|PROPN', 0.0017292490118577075),
#  ('millàs|PROPN', 0.0017292490118577075),
#  ('jordi|PROPN', 0.0017292490118577075),
#  ('puigbó|PROPN', 0.0017292490118577075),
#  ('solana|PROPN', 0.0017292490118577075),
#  ('pequeño|ADJ', 0.0016944365998305564),
#  ('capaz|ADJ', 0.0016944365998305564),
#  ('claro|ADJ', 0.0016944365998305564),
#  ('solo|ADJ', 0.0016944365998305564),
#  ('importante|ADJ', 0.0016944365998305564),
#  ('personal|ADJ', 0.0016944365998305564),
#  ('máximo|ADJ', 0.0016944365998305564),
#  ('imposible|ADJ', 0.0016944365998305564),
#  ('públicos|ADJ', 0.0016944365998305564),
#  ('primeras|ADJ', 0.0016944365998305564),
#  ('fiscal|ADJ', 0.0016944365998305564),
#  ('estadounidense|ADJ', 0.0016944365998305564),
#  ('presente|ADJ', 0.0016944365998305564),
#  ('actuales|ADJ', 0.0016944365998305564),
#  ('terrorista|ADJ', 0.0016944365998305564),
#  ('argentino|ADJ', 0.0016944365998305564),
#  ('datos|NOUN', 0.0016673614005835765),
#  ('lunes|NOUN', 0.0016673614005835765),
#  ('precio|NOUN', 0.0016673614005835765),
#  ('campo|NOUN', 0.0016673614005835765),
#  ('plan|NOUN', 0.0016673614005835765),
#  ('fútbol|NOUN', 0.0016673614005835765),
#  ('dónde|PRON', 0.0016488046166529267),
#  ('éste|PRON', 0.0016488046166529267),
#  ('unas|PRON', 0.0016488046166529267),
#  ('como|ADP', 0.0016426141030153702),
#  ('hacia|ADP', 0.0016426141030153702),
#  ('todas|DET', 0.0016163123212731567),
#  ('tirarlos|_', 0.001584786053882726),
#  ('pensarlo|_', 0.001584786053882726),
#  ('alzarse|_', 0.001584786053882726),
#  ('ponerse|_', 0.001584786053882726),
#  ('quedarse|_', 0.001584786053882726),
#  ('cargarse|_', 0.001584786053882726),
#  ('darle|_', 0.001584786053882726),
#  ('inscribirse|_', 0.001584786053882726),
#  ('mantenerse|_', 0.001584786053882726),
#  ('acercarse|_', 0.001584786053882726),
#  ('incorporarse|_', 0.001584786053882726),
#  ('conseguirlo|_', 0.001584786053882726),
#  ('sentirse|_', 0.001584786053882726),
#  ('convertirse|_', 0.001584786053882726),
#  ('dedicarse|_', 0.001584786053882726),
#  ('pronunciarse|_', 0.001584786053882726),
#  ('decidió|VERB', 0.001568451714093659),
#  ('celebrar|VERB', 0.001568451714093659),
#  ('convertido|VERB', 0.001568451714093659),
#  ('negó|VERB', 0.001568451714093659),
#  ('establece|VERB', 0.001568451714093659),
#  ('encuentra|VERB', 0.001568451714093659),
#  ('consiguió|VERB', 0.001568451714093659),
#  ('tengo|VERB', 0.001568451714093659),
#  ('afirma|VERB', 0.001568451714093659),
#  ('dado|VERB', 0.001568451714093659),
#  ('vencer|VERB', 0.001568451714093659),
#  ('votar|VERB', 0.001568451714093659),
#  ('destacó|VERB', 0.001568451714093659),
#  ('gusta|VERB', 0.001568451714093659),
#  ('mostró|VERB', 0.001568451714093659),
#  ('cree|VERB', 0.001568451714093659),
#  ('obtuvo|VERB', 0.001568451714093659),
#  ('hombres|NOUN', 0.001563151313047103),
#  ('jugador|NOUN', 0.001563151313047103),
#  ('ciudadanos|NOUN', 0.001563151313047103),
#  ('compañías|NOUN', 0.001563151313047103),
#  ('noche|NOUN', 0.001563151313047103),
#  ('técnico|NOUN', 0.001563151313047103),
#  ('podrían|AUX', 0.0015384615384615385),
#  ('habremos|AUX', 0.0015384615384615385),
#  ('debido|AUX', 0.0015384615384615385),
#  ('deberían|AUX', 0.0015384615384615385),
#  ('habido|AUX', 0.0015384615384615385),
#  ('iba|AUX', 0.0015384615384615385),
#  ('eres|AUX', 0.0015384615384615385),
#  ('puedan|AUX', 0.0015384615384615385),
#  ('hubieran|AUX', 0.0015384615384615385),
#  ('vaya|AUX', 0.0015384615384615385),
#  ('estarán|AUX', 0.0015384615384615385),
#  ('podamos|AUX', 0.0015384615384615385),
#  ('podemos|AUX', 0.0015384615384615385),
#  ('habrían|AUX', 0.0015384615384615385),
#  ('estaría|AUX', 0.0015384615384615385),
#  ('debemos|AUX', 0.0015384615384615385),
#  ('saber|AUX', 0.0015384615384615385),
#  ('podremos|AUX', 0.0015384615384615385),
#  ('estuvo|AUX', 0.0015384615384615385),
#  ('habíamos|AUX', 0.0015384615384615385),
#  ('vas|AUX', 0.0015384615384615385),
#  ('varios|DET', 0.0014919806042521448),
#  ('otras|DET', 0.0014919806042521448),
#  ('justicia|PROPN', 0.0014822134387351778),
#  ('medio|PROPN', 0.0014822134387351778),
#  ('garcía|PROPN', 0.0014822134387351778),
#  ('aíto|PROPN', 0.0014822134387351778),
#  ('jáuregui|PROPN', 0.0014822134387351778),
#  ('jce|PROPN', 0.0014822134387351778),
#  ('prd|PROPN', 0.0014822134387351778),
#  ('danilo|PROPN', 0.0014822134387351778),
#  ('turismo|PROPN', 0.0014822134387351778),
#  ('sociedad|PROPN', 0.0014822134387351778),
#  ('cruz|PROPN', 0.0014822134387351778),
#  ('espanyol|PROPN', 0.0014822134387351778),
#  ('ejecutivo|PROPN', 0.0014822134387351778),
#  ('valencia|PROPN', 0.0014822134387351778),
#  ('david|PROPN', 0.0014822134387351778),
#  ('huelva|PROPN', 0.0014822134387351778),
#  ('acnur|PROPN', 0.0014822134387351778),
#  ('timor|PROPN', 0.0014822134387351778),
#  ('likud|PROPN', 0.0014822134387351778),
#  ('shas|PROPN', 0.0014822134387351778),
#  ('gómez|PROPN', 0.0014822134387351778),
#  ('porta|PROPN', 0.0014822134387351778),
#  ('palau|PROPN', 0.0014822134387351778),
#  ('inter|PROPN', 0.0014822134387351778),
#  ('matutes|PROPN', 0.0014822134387351778),
#  ('vi|PROPN', 0.0014822134387351778),
#  ('ciu|PROPN', 0.0014822134387351778),
#  ('senegal|PROPN', 0.0014822134387351778),
#  ('junio|NOUN', 0.0014589412255106293),
#  ('proceso|NOUN', 0.0014589412255106293),
#  ('mayoría|NOUN', 0.0014589412255106293),
#  ('frente|NOUN', 0.0014589412255106293),
#  ('defensa|NOUN', 0.0014589412255106293),
#  ('punto|NOUN', 0.0014589412255106293),
#  ('jornada|NOUN', 0.0014589412255106293),
#  ('embargo|NOUN', 0.0014589412255106293),
#  ('pese|NOUN', 0.0014589412255106293),
#  ('sistema|NOUN', 0.0014589412255106293),
#  ('proyecto|NOUN', 0.0014589412255106293),
#  ('candidato|NOUN', 0.0014589412255106293),
#  ('número|NOUN', 0.0014589412255106293),
#  ('trabajo|NOUN', 0.0014589412255106293),
#  ('paz|NOUN', 0.0014589412255106293),
#  ('fuentes|NOUN', 0.0014589412255106293),
#  ('septiembre|NOUN', 0.0014589412255106293),
#  ('lehendakari|NOUN', 0.0014589412255106293),
#  ('civil|ADJ', 0.001412030499858797),
#  ('económica|ADJ', 0.001412030499858797),
#  ('militar|ADJ', 0.001412030499858797),
#  ('militares|ADJ', 0.001412030499858797),
#  ('bonito|ADJ', 0.001412030499858797),
#  ('buenos|ADJ', 0.001412030499858797),
#  ('primero|ADJ', 0.001412030499858797),
#  ('pequeños|ADJ', 0.001412030499858797),
#  ('buena|ADJ', 0.001412030499858797),
#  ('largo|ADJ', 0.001412030499858797),
#  ('cuarto|ADJ', 0.001412030499858797),
#  ('simple|ADJ', 0.001412030499858797),
#  ('realizado|ADJ', 0.001412030499858797),
#  ('generales|ADJ', 0.001412030499858797),
#  ('propio|ADJ', 0.001412030499858797),
#  ('ciego|ADJ', 0.001412030499858797),
#  ('final|ADJ', 0.001412030499858797),
#  ('económico|ADJ', 0.001412030499858797),
#  ('tradicional|ADJ', 0.001412030499858797),
#  ('próximos|ADJ', 0.001412030499858797),
#  ('difícil|ADJ', 0.001412030499858797),
#  ('catalán|ADJ', 0.001412030499858797),
#  ('tercera|ADJ', 0.001412030499858797),
#  ('económicas|ADJ', 0.001412030499858797),
#  ('independiente|ADJ', 0.001412030499858797),
#  ('españoles|ADJ', 0.001412030499858797),
#  ('mayores|ADJ', 0.001412030499858797),
#  ('laborista|ADJ', 0.001412030499858797),
#  ('hecho|ADJ', 0.001412030499858797),
#  ('catalana|ADJ', 0.001412030499858797),
#  ('gratuita|ADJ', 0.001412030499858797),
#  ('bajo|ADP', 0.0014079549454417458),
#  ('i|CCONJ', 0.001375515818431912),
#  ('mi|DET', 0.0013676488872311327),
#  ('viernes|NOUN', 0.0013547311379741558),
#  ('sociedad|NOUN', 0.0013547311379741558),
#  ('historia|NOUN', 0.0013547311379741558),
#  ('temporada|NOUN', 0.0013547311379741558),
#  ('tipo|NOUN', 0.0013547311379741558),
#  ('cambio|NOUN', 0.0013547311379741558),
#  ('clasificación|NOUN', 0.0013547311379741558),
#  ('derecho|NOUN', 0.0013547311379741558),
#  ('secretario|NOUN', 0.0013547311379741558),
#  ('capital|NOUN', 0.0013547311379741558),
#  ('tarde|NOUN', 0.0013547311379741558),
#  ('precios|NOUN', 0.0013547311379741558),
#  ('medios|NOUN', 0.0013547311379741558),
#  ('sector|NOUN', 0.0013547311379741558),
#  ('goles|NOUN', 0.0013547311379741558),
#  ('hablar|VERB', 0.0013443871835088505),
#  ('considera|VERB', 0.0013443871835088505),
#  ('existe|VERB', 0.0013443871835088505),
#  ('tomar|VERB', 0.0013443871835088505),
#  ('agregó|VERB', 0.0013443871835088505),
#  ('necesita|VERB', 0.0013443871835088505),
#  ('atender|VERB', 0.0013443871835088505),
#  ('pensar|VERB', 0.0013443871835088505),
#  ('recordó|VERB', 0.0013443871835088505),
#  ('parecía|VERB', 0.0013443871835088505),
#  ('va|VERB', 0.0013443871835088505),
#  ('conseguido|VERB', 0.0013443871835088505),
#  ('pasó|VERB', 0.0013443871835088505),
#  ('pasar|VERB', 0.0013443871835088505),
#  ('murió|VERB', 0.0013443871835088505),
#  ('pasado|VERB', 0.0013443871835088505),
#  ('dejar|VERB', 0.0013443871835088505),
#  ('producido|VERB', 0.0013443871835088505),
#  ('aumentar|VERB', 0.0013443871835088505),
#  ('ganado|VERB', 0.0013443871835088505),
#  ('están|VERB', 0.0013443871835088505),
#  ('logró|VERB', 0.0013443871835088505),
#  ('afrontar|VERB', 0.0013443871835088505),
#  ('señaló|VERB', 0.0013443871835088505),
#  ('produzca|VERB', 0.0013443871835088505),
#  ('presenta|VERB', 0.0013443871835088505),
#  ('democracia|NOUN', 0.0012505210504376823),
#  ('portavoz|NOUN', 0.0012505210504376823),
#  ('casa|NOUN', 0.0012505210504376823),
#  ('equipos|NOUN', 0.0012505210504376823),
#  ('gol|NOUN', 0.0012505210504376823),
#  ('partir|NOUN', 0.0012505210504376823),
#  ('padre|NOUN', 0.0012505210504376823),
#  ('fondos|NOUN', 0.0012505210504376823),
#  ('reunión|NOUN', 0.0012505210504376823),
#  ('través|NOUN', 0.0012505210504376823),
#  ('1999|NOUN', 0.0012505210504376823),
#  ('mes|NOUN', 0.0012505210504376823),
#  ('reforma|NOUN', 0.0012505210504376823),
#  ('semana|NOUN', 0.0012505210504376823),
#  ('socialistas|NOUN', 0.0012505210504376823),
#  ('candidatura|NOUN', 0.0012505210504376823),
#  ('plomo|NOUN', 0.0012505210504376823),
#  ('muchos|DET', 0.0012433171702101206),
#  ('toda|DET', 0.0012433171702101206),
#  ('demás|PRON', 0.001236603462489695),
#  ('su|PRON', 0.001236603462489695),
#  ('muchas|PRON', 0.001236603462489695),
#  ('otras|PRON', 0.001236603462489695),
#  ('cuya|PRON', 0.001236603462489695),
#  ('varios|PRON', 0.001236603462489695),
#  ('quién|PRON', 0.001236603462489695),
#  ('cuyo|PRON', 0.001236603462489695),
#  ('cuyas|PRON', 0.001236603462489695),
#  ('estos|PRON', 0.001236603462489695),
#  ('sus|PRON', 0.001236603462489695),
#  ('luis|PROPN', 0.0012351778656126482),
#  ('organización|PROPN', 0.0012351778656126482),
#  ('pueblo|PROPN', 0.0012351778656126482),
#  ('cne|PROPN', 0.0012351778656126482),
#  ('gutiérrez|PROPN', 0.0012351778656126482),
#  ('ambiente|PROPN', 0.0012351778656126482),
#  ('york|PROPN', 0.0012351778656126482),
#  ('per|PROPN', 0.0012351778656126482),
#  ('corcuera|PROPN', 0.0012351778656126482),
#  ('grupo|PROPN', 0.0012351778656126482),
#  ('prsc|PROPN', 0.0012351778656126482),
#  ('internet|PROPN', 0.0012351778656126482),
#  ('perú|PROPN', 0.0012351778656126482),
#  ('bruselas|PROPN', 0.0012351778656126482),
#  ('carmen|PROPN', 0.0012351778656126482),
#  ('paul|PROPN', 0.0012351778656126482),
#  ('reynard/honda|PROPN', 0.0012351778656126482),
#  ('chechenia|PROPN', 0.0012351778656126482),
#  ('oro|PROPN', 0.0012351778656126482),
#  ('oreja|PROPN', 0.0012351778656126482),
#  ('osa|PROPN', 0.0012351778656126482),
#  ('málaga|PROPN', 0.0012351778656126482),
#  ('turbo|PROPN', 0.0012351778656126482),
#  ('ferrari|PROPN', 0.0012351778656126482),
#  ('pedro|PROPN', 0.0012351778656126482),
#  ('eeuu|PROPN', 0.0012351778656126482),
#  ('doñana|PROPN', 0.0012351778656126482),
#  ('banco|PROPN', 0.0012351778656126482),
#  ('inglaterra|PROPN', 0.0012351778656126482),
#  ('flores|PROPN', 0.0012351778656126482),
#  ('alemania|PROPN', 0.0012351778656126482),
#  ('georgia|PROPN', 0.0012351778656126482),
#  ('proposición|PROPN', 0.0012351778656126482),
#  ('agencia|PROPN', 0.0012351778656126482),
#  ('barça|PROPN', 0.0012351778656126482),
#  ('ceuta|PROPN', 0.0012351778656126482),
#  ('catalana|PROPN', 0.0012351778656126482),
#  ('joan|PROPN', 0.0012351778656126482),
#  ('mar|PROPN', 0.0012351778656126482),
#  ('confianza|PROPN', 0.0012351778656126482),
#  ('carrefour|PROPN', 0.0012351778656126482),
#  ('clot|PROPN', 0.0012351778656126482),
#  ('supuestamente|ADV', 0.0011961722488038277),
#  ('mientras|ADV', 0.0011961722488038277),
#  ('acaso|ADV', 0.0011961722488038277),
#  ('tarde|ADV', 0.0011961722488038277),
#  ('igual|ADV', 0.0011961722488038277),
#  ('excesivamente|ADV', 0.0011961722488038277),
#  ('justo|ADV', 0.0011961722488038277),
#  ('probablemente|ADV', 0.0011961722488038277),
#  ('solamente|ADV', 0.0011961722488038277),
#  ('formalmente|ADV', 0.0011961722488038277),
#  ('claramente|ADV', 0.0011961722488038277),
#  ('parcialmente|ADV', 0.0011961722488038277),
#  ('constantemente|ADV', 0.0011961722488038277),
#  ('próximamente|ADV', 0.0011961722488038277),
#  ('cuanto|ADV', 0.0011961722488038277),
#  ('definitivamente|ADV', 0.0011961722488038277),
#  ('justamente|ADV', 0.0011961722488038277),
#  ('extraordinariamente|ADV', 0.0011961722488038277),
#  ('precisamente|ADV', 0.0011961722488038277),
#  ('igualmente|ADV', 0.0011961722488038277),
#  ('curiosamente|ADV', 0.0011961722488038277),
#  ('directamente|ADV', 0.0011961722488038277),
#  ('simplemente|ADV', 0.0011961722488038277),
#  ('poder|NOUN', 0.0011463109629012088),
#  ('triunfo|NOUN', 0.0011463109629012088),
#  ('miembros|NOUN', 0.0011463109629012088),
#  ('enero|NOUN', 0.0011463109629012088),
#  ('juego|NOUN', 0.0011463109629012088),
#  ('cuenta|NOUN', 0.0011463109629012088),
#  ('fuerza|NOUN', 0.0011463109629012088),
#  ('hecho|NOUN', 0.0011463109629012088),
#  ('gracias|NOUN', 0.0011463109629012088),
#  ('fondo|NOUN', 0.0011463109629012088),
#  ('decisión|NOUN', 0.0011463109629012088),
#  ('director|NOUN', 0.0011463109629012088),
#  ('metros|NOUN', 0.0011463109629012088),
#  ('campeón|NOUN', 0.0011463109629012088),
#  ('fusión|NOUN', 0.0011463109629012088),
#  ('estado|NOUN', 0.0011463109629012088),
#  ('voto|NOUN', 0.0011463109629012088),
#  ('catorce|NUM', 0.001142857142857143),
#  ('2-3|NUM', 0.001142857142857143),
#  ('11.000|NUM', 0.001142857142857143),
#  ('un|NUM', 0.001142857142857143),
#  ('1.420|NUM', 0.001142857142857143),
#  ('diecisiete|NUM', 0.001142857142857143),
#  ('cincuenta|NUM', 0.001142857142857143),
#  ('1200|NUM', 0.001142857142857143),
#  ('cuarenta|NUM', 0.001142857142857143),
#  ('923|NUM', 0.001142857142857143),
#  ('12:00|NUM', 0.001142857142857143),
#  ('16:00|NUM', 0.001142857142857143),
#  ...]

# %%
import numpy as np
np.save('transitionHMM.npy', transitionProbDict)
np.save('emissionHMM.npy', emissionProbDict)

# %% [markdown]
# **Conclusión** Con esto ya se entrena un modelo Marcoviano Latente, con la matriz de transición y de emisión y por tanto, se puede calcular todas las probabilidades según la regla de bayes.
#
# En grandes rasgos, esto permite determinar, dada una secuencia de palabras cual es la secuencia de etiquetas mas probables que le corresponda, esto bajo un algoritmo de selección que se llama algoritmo de viterbi.

# %% [markdown]
# ## Etiquetado con HMM
#
# 1. **Entrenamiento**: El modelo aprende las probabilidades de emisión y transición
# 2. **Decodificación**: El modelo calcula la secuencia de etiquetas mas probable con el algoritmo de viterbi.
#
# ![](.\funcion.PNG)
#
# ## Pipeline del HMM
#
# ![](.\pipeline.PNG)

# %% [markdown]
# ## Probabilidades de Viterbi:
#
# Es un algoritmo que se encarga de asignar una probabilidad de una combinación de cada secuencia de etiquetas gramaticales que pueden pertenecer a una secuencia de palabras, esto se convierte en un espacio de probabilidades, en la cual se selecciona la secuencia con probabilidad mayor para esa secuencia de palabras.
#
# ![](.\secuencia.PNG)
#
# Se puede apreciar una secuencia de palabras a las cuales se les asigna una secuencia de combinaciones de posibles etiquetas a las cuales pueda pertenecer cada una. Y a estos caminos son a los que se les asigna un numero probabilistico que identifica cual es el mas adecuado para la secuencia de palabras.
#
# ![](.\proviter.PNG)
#
# Se calcula la probabilidad para cada uno de los nodos, esta operación se denota con la letra griega Nu y es igual a el producto de la probabilidad inicial de encontrar esa etiqueta en la primera parte de la secuencia con la probabilidad condicional (emisión) de que dada esa etiqueta (PROP para el ejemplo) se presente la palabra a evaluar de la secuencia o sea esa palabra (CASTILLO para el ejemplo).
#
# ![](.\segundo.PNG)

# %% [markdown]
# En el siguiente paso, el algoritmo para calcular la probabilidad en la siguiente palabra de la secuencia, considera todos los posibles caminos que pasan por el nodo para así determinar el camino con mayor probabilidad.
#
# - A la probabilidad obtenida en la secuencia anterior se le multiplica la probabilidad de transacición, es decir, la probabilidad de que se de una categoria DET dado que ya se dio una categoria PROP.
# - Tambien se le multiplica la probabilidad de emisión, es decir la probabilidad de que se de una palabra el, dado que se presento una categoria DET.
# - El resultado de los dos caminos se compara y se elige el que presenta mayor probabilidad.
#
# $$
# \nu_t(j) = max\{\nu_{t-1}(i)*C_{ij}*P(palabra|j)\}
# $$

# %% [markdown]
# ## Carga del modelo HMM previamente entrenado

# %%
transitionProbdict = np.load('transitionHMM.npy',allow_pickle='TRUE').item() 
emissionProbdict = np.load('emissionHMM.npy',allow_pickle='TRUE').item()

# %% [markdown]
# ### Identificar las categorias gramaticales
# Para dar continuidad con el algoritmo de viterbi se debe enumerar con una llave unica a las categorias gramaticales, pero para ello se deben hallar los valores unicos de categorias gramaticales

# %%
# Identificar las categorias gramaticales 'upos' unicas en el corpus
stateSet = set([w.split('|')[1] for w in list(emissionProbdict.keys())])
stateSet
# Out:
# {'ADJ',
#  'ADP',
#  'ADV',
#  'AUX',
#  'CCONJ',
#  'DET',
#  'INTJ',
#  'NOUN',
#  'NUM',
#  'PART',
#  'PRON',
#  'PROPN',
#  'PUNCT',
#  'SCONJ',
#  'SYM',
#  'VERB',
#  '_'}

# %% [markdown]
# ### Enumeración Categorias
# Esto permite relacionar las categorias gramaticales con la columna de la matriz de viterbi

# %%
# Enumerar las categorias gramaticales con numeros para asignar a
# las columnas de la matriz, es decir un indice entero que lo relaciona
# con la columna en la matriz de probabilidades de viterbi

tagStateDict = {}
for i,state in enumerate(stateSet):
    tagStateDict[state] = i
tagStateDict
# Out:
# {'PROPN': 0,
#  'NUM': 1,
#  'PRON': 2,
#  'DET': 3,
#  'INTJ': 4,
#  'PART': 5,
#  'CCONJ': 6,
#  '_': 7,
#  'ADV': 8,
#  'SYM': 9,
#  'PUNCT': 10,
#  'VERB': 11,
#  'SCONJ': 12,
#  'AUX': 13,
#  'ADP': 14,
#  'NOUN': 15,
#  'ADJ': 16}

# %% [markdown]
# ### Distribución Inicial de Estados Latentes
# Estado inicial es la primera palabra que se puede hallar en un corpus, se debe leer el corpus para identificarlo. la probabilidad es:
#
# $$
# \rho_i^{0} = \frac{C(initCategories)}{totalCategories}
# $$

# %%
from conllu import parse_incr

wordList = []
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")
# Conocer la longitud del corpus
count = 0
initTagStateProb = {} #\rho_i^(o)

# Ciclo para recorrer las listas de tokens
for tokenlist in parse_incr(data_file):
    # Contador de cuantas listas hay
    count += 1
    # Extrae el tag de la primera palabra de la lista
    tag = tokenlist[0]['upos']
    
    # Asigna ese tag al diccionario para contar cuantas veces aparece de
    # Primeras en cada lista
    if tag in initTagStateProb.keys():
        initTagStateProb[tag] += 1
    else:
        initTagStateProb[tag] = 1

# Se toma ese conteo y se divide cada uno por el total de palabras iniciales
for key in initTagStateProb.keys():
    initTagStateProb[key] /= count

initTagStateProb
# Out:
# {'DET': 0.3633615477629988,
#  'PROPN': 0.1124546553808948,
#  'ADP': 0.15538089480048367,
#  'PRON': 0.034461910519951636,
#  'SCONJ': 0.02418379685610641,
#  'ADV': 0.06287787182587666,
#  'PUNCT': 0.07799274486094317,
#  'VERB': 0.04353083434099154,
#  'ADJ': 0.010882708585247884,
#  'CCONJ': 0.03325272067714631,
#  'NOUN': 0.02720677146311971,
#  '_': 0.009068923821039904,
#  'INTJ': 0.0006045949214026602,
#  'AUX': 0.022370012091898428,
#  'NUM': 0.01995163240628779,
#  'SYM': 0.0006045949214026602,
#  'PART': 0.0018137847642079807}

# %%
# Verificar el total de probabilidad
np.array([initTagStateProb[k] for k in initTagStateProb.keys()]).sum()
# Out:
# 1.0

# %% [markdown]
# Dada una secuencia de palabras $\{p_1, p_2, \dots, p_n \}$, y un conjunto de categorias gramaticales dadas por la convención `upos`, se considera la matriz de probabilidades de Viterbi así:
#
# $$
# \begin{array}{c c}
# \begin{array}{c c c c}
# \text{ADJ} \\
# \text{ADV}\\
# \text{PRON} \\
# \vdots \\
# {}
# \end{array}
# &
# \left[
# \begin{array}{c c c c}
# \nu_1(\text{ADJ}) & \nu_2(\text{ADJ}) & \dots  & \nu_n(\text{ADJ})\\
# \nu_1(\text{ADV}) & \nu_2(\text{ADV}) & \dots  & \nu_n(\text{ADV})\\
# \nu_1(\text{PRON}) & \nu_2(\text{PRON}) & \dots  & \nu_n(\text{PRON})\\
# \vdots & \vdots & \dots & \vdots \\ \hdashline
# p_1 & p_2 & \dots & p_n
# \end{array}
# \right]
# \end{array}
# $$
#
# Donde las probabilidades de la primera columna (para una categoria $i$) están dadas por:
#
# $$
# \nu_1(i) = \underbrace{\rho_i^{(0)}}_{\text{probabilidad inicial}} \times \underbrace{P(p_1 \vert i)}_{\text{emisión}}
# $$
#
# luego, para la segunda columna (dada una categoria $j$) serán:
#
# $$
# \nu_2(j) = \max_i \{ \nu_1(i) \times \underbrace{P(j \vert i)}_{\text{transición}} \times \underbrace{P(p_2 \vert j)}_{\text{emisión}} \}
# $$
#
# así, en general las probabilidades para la columna $t$ estarán dadas por:
#
# $$
# \nu_{t}(j) = \max_i \{ \overbrace{\nu_{t-1}(i)}^{\text{estado anterior}} \times \underbrace{P(j \vert i)}_{\text{transición}} \times \underbrace{P(p_t \vert j)}_{\text{emisión}} \}
# $$

# %% [markdown]
# ### Construcción de la Matriz de viterbi
# Inicialmente para la implementación del algoritmo de viterbi se debe confirmar la tokenización del texto

# %%
from nltk import word_tokenize

def Viterbi_tags(secuencia, transitionProbdict= transitionProbdict,emissionProbdict= emissionProbdict, 
                   tagStateDict= tagStateDict, initTagStateProb= initTagStateProb):
    """
    Secuencia: Secuencia de palabras
    transitionProbdict: Matriz de probabilidad de transición de que dada una etiqueta previa se de una etiqueta siguiente
    emissionProbdict: Probabilidades de emisión de que dada una etiqueta se de cierta palabra
    tagStateDict: Enumerar con indices las categorias gramaticales que se asignaran dentro de la matriz
    initTagStateProb: Estados iniciales de probabilidad. de que una categoria gramatical este a inicio del corpus. 
    """
    #Tokenizar el texto
    seq = word_tokenize(secuencia)
    # Crear la matriz vacia
    viterbiProb = np.zeros((17,len(seq)))
    
    #Inicialización de la primera columna:
    for key in tagStateDict.keys():
        tag_row = tagStateDict[key]
        word_tag = seq[0].lower()+'|'+key
        if word_tag in emissionProbdict.keys():
            # Llenado primera columna
            viterbiProb[tag_row,0] = initTagStateProb[key]*emissionProbdict[word_tag]
            
    # Computo siguientes columnas un sancochooooo
    for col in range(1,len(seq)):
        for key in tagStateDict.keys():
            tag_row = tagStateDict[key]
            word_tag = seq[col].lower()+'|'+key
            if word_tag in emissionProbdict.keys():
                possible_probs = []
                for key2 in tagStateDict.keys():
                    tag_row2 = tagStateDict[key2]
                    tag_prevtag = key+'|'+key2
                    if tag_prevtag in transitionProbdict.keys():
                        if viterbiProb[tag_row2 , col-1] > 0:
                            possible_probs.append(viterbiProb[tag_row2,col-1]*transitionProbdict[tag_prevtag]*emissionProbdict[word_tag])
                    
                viterbiProb[tag_row,col] = max(possible_probs)     
    
    # Construcción de la secuencia de etiquetas
    res = []
    for i,p in enumerate(seq):
        for tag in tagStateDict.keys():
            if tagStateDict[tag] == np.argmax(viterbiProb[:,i]):
                res.append((p,tag))
    
    
    return res


Viterbi_tags('Buenos días que necesita mi hijo para adquirir un crédito por primera vez')
# Out:
# [('Buenos', 'PROPN'),
#  ('días', 'NOUN'),
#  ('que', 'PRON'),
#  ('necesita', 'VERB'),
#  ('mi', 'DET'),
#  ('hijo', 'NOUN'),
#  ('para', 'ADP'),
#  ('adquirir', 'VERB'),
#  ('un', 'DET'),
#  ('crédito', 'NOUN'),
#  ('por', 'ADP'),
#  ('primera', 'ADJ'),
#  ('vez', 'NOUN')]

# %% [markdown]
# ## Entrenamiento Directo de HMM con NLTK
#
# * clase en python (NLTK) de HMM: https://www.nltk.org/_modules/nltk/tag/hmm.html

# %%
import nltk
nltk.download('treebank')
from nltk.corpus import treebank
train_data = treebank.tagged_sents()[:3900]
# Out:
# [nltk_data] Downloading package treebank to
# [nltk_data]     C:\Users\GAMER\AppData\Roaming\nltk_data...
# [nltk_data]   Package treebank is already up-to-date!

# %%
from nltk.tag import hmm
tagger = hmm.HiddenMarkovModelTrainer().train_supervised(train_data)

# %%
tagger.tag('Pierre Vinken will get old'.split())
# Out:
# [('Pierre', 'NNP'),
#  ('Vinken', 'NNP'),
#  ('will', 'MD'),
#  ('get', 'VB'),
#  ('old', 'JJ')]

# %%
# Accuracy
tagger.evaluate(train_data)
# Out:
# 0.9815403947224078

# %% [markdown]
# ## Ejercicio Ancora
#
# **Objetivo:** Entrena un HMM usando la clase `hmm.HiddenMarkovModelTrainer()` sobre el dataset `UD_Spanish_AnCora`.
#
# 1. **Pre-procesamiento:** En el ejemplo anterior usamos el dataset en ingles `treebank`, el cual viene con una estructura diferente a la de `AnCora`, en esta parte escribe código para transformar la estructura de `AnCora` de manera que quede igual al `treebank` que usamos así:
#
# $$\left[ \left[ (\text{'El'}, \text{'DET'}), (\dots), \dots\right], \left[\dots \right] \right]$$

# %%
import nltk
from nltk.tag import hmm
from conllu import parse_incr
from sklearn.model_selection import train_test_split

lista = []
word_tag = []
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

# Menos eficiente
for tokenlist in parse_incr(data_file):
    for token in tokenlist:
        token2add = token['form'],token['upos']
        lista.append(token2add)
        word_tag.append(lista)
# Out:
# ('El', 'DET')
# ('gobernante', 'NOUN')
# (',', 'PUNCT')
# ('con', 'ADP')
# ('ganada', 'ADJ')
# ('fama', 'NOUN')
# ('desde', 'ADP')
# ('que', 'SCONJ')
# ('llegó', 'VERB')
# ('hace', 'VERB')
# ('16', 'NUM')
# ('meses', 'NOUN')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('poder', 'NOUN')
# ('de', 'ADP')
# ('explotar', 'VERB')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('máximo', 'NOUN')
# ('su', 'DET')
# ('oratoria', 'NOUN')
# ('y', 'CCONJ')
# ('acusado', 'ADJ')
# ('por', 'ADP')
# ('sus', 'DET')
# ('detractores', 'NOUN')
# ('de', 'ADP')
# ('incontinencia', 'NOUN')
# ('verbal', 'ADJ')
# (',', 'PUNCT')
# ('enmudeció', 'VERB')
# ('desde', 'ADP')
# ('el', 'DET')
# ('momento', 'NOUN')
# ('en', 'ADP')
# ('el', 'DET')
# ('que', 'PRON')
# ('el', 'DET')
# ('Tribunal', 'PROPN')
# ('Supremo', 'PROPN')
# ('de', 'ADP')
# ('Justicia', 'PROPN')
# ('(', 'PUNCT')
# ('TSJ', 'PROPN')
# (')', 'PUNCT')
# ('decidió', 'VERB')
# ('suspender', 'VERB')
# ('temporalmente', 'ADV')
# ('los', 'DET')
# ('comicios', 'NOUN')
# ('múltiples', 'ADJ')
# ('ante', 'ADP')
# ('la', 'DET')
# ('imposibilidad', 'NOUN')
# ('"', 'PUNCT')
# ('técnica', 'ADJ')
# ('"', 'PUNCT')
# ('de', 'ADP')
# ('celebrarlos', '_')
# ('celebrar', 'VERB')
# ('los', 'PRON')
# ('el', 'DET')
# ('28', 'NUM')
# ('de', 'ADP')
# ('mayo', 'NOUN')
# ('.', 'PUNCT')
# ('Chávez', 'PROPN')
# ('se', 'PRON')
# ('despidió', 'VERB')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('mundanal', 'ADJ')
# ('ruido', 'NOUN')
# ('el', 'DET')
# ('pasado', 'NOUN')
# ('jueves', 'NOUN')
# ('con', 'ADP')
# ('su', 'DET')
# ('más', 'ADV')
# ('breve', 'ADJ')
# ('discurso', 'NOUN')
# ('por', 'ADP')
# ('televisión', 'NOUN')
# (',', 'PUNCT')
# ('tildado', 'ADJ')
# ('de', 'ADP')
# ('"', 'PUNCT')
# ('institucional', 'ADJ')
# ('"', 'PUNCT')
# ('por', 'ADP')
# ('los', 'DET')
# ('observadores', 'NOUN')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('el', 'DET')
# ('que', 'PRON')
# ('aceptó', 'VERB')
# ('el', 'DET')
# ('aplazamiento', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('comicios', 'NOUN')
# ('y', 'CCONJ')
# ('valoró', 'VERB')
# ('la', 'DET')
# ('"', 'PUNCT')
# ('pedagógica', 'ADJ')
# ('"', 'PUNCT')
# ('medida', 'NOUN')
# ('como', 'ADP')
# ('un', 'DET')
# ('triunfo', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('democracia', 'NOUN')
# ('venezolana', 'ADJ')
# ('.', 'PUNCT')
# ('Desde', 'ADP')
# ('entonces', 'ADV')
# ('entró', 'VERB')
# ('en', 'ADP')
# ('silencio', 'NOUN')
# ('absoluto', 'ADJ')
# ('.', 'PUNCT')
# ('Nadie', 'PRON')
# ('sabe', 'VERB')
# ('cuál', 'PRON')
# ('es', 'AUX')
# ('la', 'DET')
# ('nueva', 'ADJ')
# ('fecha', 'NOUN')
# ('que', 'PRON')
# ('propone', 'VERB')
# ('para', 'ADP')
# ('las', 'DET')
# ('votaciones', 'NOUN')
# (',', 'PUNCT')
# ('ni', 'CCONJ')
# ('si', 'SCONJ')
# ('las', 'PRON')
# ('quiere', 'VERB')
# ('juntas', 'ADJ')
# ('o', 'CCONJ')
# ('separadas', 'ADJ')
# (',', 'PUNCT')
# ('ni', 'CCONJ')
# ('cuando', 'PRON')
# ('va', 'AUX')
# ('a', 'ADP')
# ('reanudar', 'VERB')
# ('la', 'DET')
# ('campaña', 'NOUN')
# ('.', 'PUNCT')
# ('Por', 'ADP')
# ('su', 'DET')
# ('boca', 'NOUN')
# ('suelen', 'VERB')
# ('hablar', 'VERB')
# ('de', 'ADP')
# ('vez', 'NOUN')
# ('en', 'ADP')
# ('cuando', 'ADV')
# ('tanto', 'ADV')
# ('el', 'DET')
# ('ministro', 'NOUN')
# ('de', 'ADP')
# ('Relaciones', 'PROPN')
# ('Exteriores', 'PROPN')
# (',', 'PUNCT')
# ('José', 'PROPN')
# ('Vicente', 'PROPN')
# ('Rangel', 'PROPN')
# (',', 'PUNCT')
# ('verdadero', 'ADJ')
# ('"', 'PUNCT')
# ('portavoz', 'NOUN')
# ('"', 'PUNCT')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Gobierno', 'PROPN')
# (',', 'PUNCT')
# ('como', 'SCONJ')
# ('el', 'DET')
# ('presidente', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('Comisión', 'PROPN')
# ('Legislativa', 'PROPN')
# ('Nacional', 'PROPN')
# ('(', 'PUNCT')
# ('CLN', 'PROPN')
# (')', 'PUNCT')
# (',', 'PUNCT')
# ('o', 'CCONJ')
# ('Congresillo', 'PROPN')
# (',', 'PUNCT')
# ('Luis', 'PROPN')
# ('Miquilena', 'PROPN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('es', 'AUX')
# ('quien', 'PRON')
# ('aparentemente', 'ADV')
# ('tiene', 'VERB')
# ('todos', 'DET')
# ('los', 'DET')
# ('resortes', 'NOUN')
# ('en', 'ADP')
# ('el', 'DET')
# ('nuevo', 'ADJ')
# ('escenario', 'NOUN')
# ('electoral', 'ADJ')
# ('.', 'PUNCT')
# ('Por', 'ADP')
# ('la', 'DET')
# ('Cancillería', 'PROPN')
# ('se', 'PRON')
# ('sabe', 'VERB')
# ('que', 'SCONJ')
# ('la', 'DET')
# ('gira', 'NOUN')
# ('presidencial', 'ADJ')
# ('prevista', 'ADJ')
# ('entre', 'ADP')
# ('el', 'DET')
# ('16', 'NUM')
# ('y', 'CCONJ')
# ('el', 'DET')
# ('25', 'NUM')
# ('de', 'ADP')
# ('junio', 'NOUN')
# ('por', 'ADP')
# ('varios', 'DET')
# ('países', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('Organización', 'PROPN')
# ('de', 'ADP')
# ('Países', 'PROPN')
# ('Exportadores', 'PROPN')
# ('de', 'ADP')
# ('Petróleo', 'PROPN')
# ('(', 'PUNCT')
# ('OPEP', 'PROPN')
# (')', 'PUNCT')
# (',', 'PUNCT')
# ('con', 'ADP')
# ('el', 'DET')
# ('fin', 'NOUN')
# ('de', 'ADP')
# ('afinar', 'VERB')
# ('detalles', 'NOUN')
# ('de', 'ADP')
# ('cara', 'NOUN')
# ('a', 'ADP')
# ('la', 'DET')
# ('II', 'PROPN')
# ('Cumbre', 'PROPN')
# ('de', 'ADP')
# ('ese', 'DET')
# ('cartel', 'NOUN')
# ('petrolero', 'ADJ')
# ('en', 'ADP')
# ('Caracas', 'PROPN')
# (',', 'PUNCT')
# ('está', 'VERB')
# ('en', 'ADP')
# ('el', 'DET')
# ('alero', 'NOUN')
# ('hasta', 'ADP')
# ('que', 'SCONJ')
# ('se', 'PRON')
# ('fijen', 'VERB')
# ('los', 'DET')
# ('comicios', 'NOUN')
# ('.', 'PUNCT')
# ('Miquilena', 'PROPN')
# (',', 'PUNCT')
# ('mientras', 'CCONJ')
# ('tanto', 'NOUN')
# (',', 'PUNCT')
# ('se', 'PRON')
# ('ha', 'AUX')
# ('convertido', 'VERB')
# ('una', 'DET')
# ('vez', 'NOUN')
# ('más', 'ADV')
# ('desde', 'ADP')
# ('que', 'SCONJ')
# ('Chávez', 'PROPN')
# ('ocupa', 'VERB')
# ('la', 'DET')
# ('Presidencia', 'PROPN')
# ('en', 'ADP')
# ('el', 'DET')
# ('"', 'PUNCT')
# ('comodín', 'NOUN')
# ('"', 'PUNCT')
# ('de', 'ADP')
# ('la', 'DET')
# ('partida', 'NOUN')
# (',', 'PUNCT')
# ('pues', 'SCONJ')
# ('marcará', 'VERB')
# ('la', 'DET')
# ('pauta', 'NOUN')
# ('sobre', 'ADP')
# ('el', 'DET')
# ('inmediato', 'ADJ')
# ('futuro', 'NOUN')
# ('político', 'ADJ')
# ('.', 'PUNCT')
# ('Si', 'SCONJ')
# ('el', 'DET')
# ('TSJ', 'PROPN')
# ('no', 'ADV')
# ('lo', 'PRON')
# ('remedia', 'VERB')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('admitir', 'VERB')
# ('un', 'DET')
# ('recurso', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('Defensoría', 'PROPN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Pueblo', 'PROPN')
# ('para', 'ADP')
# ('evitar', 'VERB')
# ('que', 'SCONJ')
# ('el', 'DET')
# ('Congresillo', 'PROPN')
# ('designe', 'VERB')
# ('"', 'PUNCT')
# ('a', 'ADP')
# ('dedo', 'NOUN')
# ('"', 'PUNCT')
# ('mañana', 'ADV')
# (',', 'PUNCT')
# ('viernes', 'NOUN')
# (',', 'PUNCT')
# ('a', 'ADP')
# ('la', 'DET')
# ('nueva', 'ADJ')
# ('directiva', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Consejo', 'PROPN')
# ('Nacional', 'PROPN')
# ('Electoral', 'PROPN')
# ('(', 'PUNCT')
# ('CNE', 'PROPN')
# (')', 'PUNCT')
# (',', 'PUNCT')
# ('Miquilena', 'PROPN')
# ('nombrará', 'VERB')
# ('a', 'ADP')
# ('su', 'DET')
# ('criterio', 'NOUN')
# ('a', 'ADP')
# ('las', 'DET')
# ('autoridades', 'NOUN')
# ('de', 'ADP')
# ('ese', 'DET')
# ('organismo', 'NOUN')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('CNE', 'PROPN')
# ('fue', 'AUX')
# ('acusado', 'VERB')
# ('hace', 'VERB')
# ('unos', 'DET')
# ('días', 'NOUN')
# ('por', 'ADP')
# ('la', 'DET')
# ('generalidad', 'NOUN')
# ('de', 'ADP')
# ('las', 'DET')
# ('fuerzas', 'NOUN')
# ('políticas', 'ADJ')
# ('venezolanas', 'ADJ')
# ('de', 'ADP')
# ('ser', 'AUX')
# ('el', 'DET')
# ('verdadero', 'ADJ')
# ('y', 'CCONJ')
# ('nico', 'ADJ')
# ('causante', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('aplazamiento', 'NOUN')
# ('de', 'ADP')
# ('las', 'DET')
# ('votaciones', 'NOUN')
# ('debido', 'ADJ')
# ('a', 'ADP')
# ('la', 'DET')
# ('"', 'PUNCT')
# ('incompetencia', 'NOUN')
# ('"', 'PUNCT')
# ('de', 'ADP')
# ('sus', 'DET')
# ('cinco', 'NUM')
# ('miembros', 'NOUN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('complicaron', 'VERB')
# ('las', 'DET')
# ('ya', 'ADV')
# ('de', 'ADP')
# ('por', 'ADP')
# ('sí', 'NOUN')
# ('complejas', 'ADJ')
# ('elecciones', 'NOUN')
# ('múltiples', 'ADJ')
# ('con', 'ADP')
# ('continuas', 'ADJ')
# ('rectificaciones', 'NOUN')
# ('en', 'ADP')
# ('las', 'DET')
# ('bases', 'NOUN')
# ('de', 'ADP')
# ('datos', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('proceso', 'NOUN')
# ('automatizado', 'ADJ')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('anterior', 'ADJ')
# ('CNE', 'PROPN')
# (',', 'PUNCT')
# ('elegido', 'ADJ')
# ('también', 'ADV')
# ('por', 'ADP')
# ('Miquilena', 'PROPN')
# (',', 'PUNCT')
# ('dimitió', 'VERB')
# ('en', 'ADP')
# ('pleno', 'ADJ')
# ('el', 'DET')
# ('pasado', 'NOUN')
# ('lunes', 'NOUN')
# ('tras', 'ADP')
# ('soportar', 'VERB')
# ('una', 'DET')
# ('lluvia', 'NOUN')
# ('de', 'ADP')
# ('críticas', 'NOUN')
# ('por', 'ADP')
# ('su', 'DET')
# ('"', 'PUNCT')
# ('falta', 'NOUN')
# ('de', 'ADP')
# ('experiencia', 'NOUN')
# ('"', 'PUNCT')
# ('y', 'CCONJ')
# ('a', 'ADP')
# ('sus', 'DET')
# ('cinco', 'NUM')
# ('miembros', 'NOUN')
# ('se', 'PRON')
# ('les', 'PRON')
# ('ha', 'AUX')
# ('prohibido', 'VERB')
# ('la', 'DET')
# ('salida', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('país', 'NOUN')
# (',', 'PUNCT')
# ('mientras', 'SCONJ')
# ('son', 'AUX')
# ('investigados', 'VERB')
# ('judicialmente', 'ADV')
# ('por', 'ADP')
# ('su', 'DET')
# ('comportamiento', 'NOUN')
# ('.', 'PUNCT')
# ('Ahora', 'ADV')
# (',', 'PUNCT')
# ('el', 'DET')
# ('Congresillo', 'PROPN')
# ('quiere', 'VERB')
# ('guardar', 'VERB')
# ('las', 'DET')
# ('formas', 'NOUN')
# ('y', 'CCONJ')
# ('consultar', 'VERB')
# ('a', 'ADP')
# ('la', 'DET')
# ('"', 'PUNCT')
# ('sociedad', 'NOUN')
# ('civil', 'ADJ')
# ('"', 'PUNCT')
# ('(', 'PUNCT')
# ('Iglesia', 'PROPN')
# (',', 'PUNCT')
# ('partidos', 'NOUN')
# (',', 'PUNCT')
# ('empresarios', 'NOUN')
# (',', 'PUNCT')
# ('sindicatos', 'NOUN')
# (')', 'PUNCT')
# ('cuál', 'PRON')
# ('sería', 'AUX')
# ('la', 'DET')
# ('composición', 'NOUN')
# ('idónea', 'ADJ')
# ('y', 'CCONJ')
# ('equilibrada', 'ADJ')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('CNE', 'PROPN')
# (',', 'PUNCT')
# ('supuestamente', 'ADV')
# ('garante', 'ADJ')
# ('de', 'ADP')
# ('la', 'DET')
# ('imparcialidad', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('comicios', 'NOUN')
# (',', 'PUNCT')
# ('con', 'ADP')
# ('el', 'DET')
# ('fin', 'NOUN')
# ('de', 'ADP')
# ('dar', 'VERB')
# ('un', 'DET')
# ('tinte', 'NOUN')
# ('democrático', 'ADJ')
# ('a', 'ADP')
# ('lo', 'PRON')
# ('que', 'PRON')
# ('será', 'AUX')
# ('una', 'DET')
# ('designación', 'NOUN')
# ('.', 'PUNCT')
# ('Elías', 'PROPN')
# ('Jaua', 'PROPN')
# (',', 'PUNCT')
# ('miembro', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Congresillo', 'PROPN')
# (',', 'PUNCT')
# ('considera', 'VERB')
# ('que', 'SCONJ')
# ('los', 'DET')
# ('nuevos', 'ADJ')
# ('miembros', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('CNE', 'PROPN')
# ('deben', 'AUX')
# ('tener', 'VERB')
# ('experiencia', 'NOUN')
# ('para', 'ADP')
# ('"', 'PUNCT')
# ('dirigir', 'VERB')
# ('procesos', 'NOUN')
# ('complejos', 'ADJ')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('deben', 'AUX')
# ('ser', 'AUX')
# ('personas', 'NOUN')
# ('con', 'ADP')
# ('independencia', 'NOUN')
# ('y', 'CCONJ')
# ('equilibrio', 'NOUN')
# (',', 'PUNCT')
# ('respetabilidad', 'NOUN')
# ('y', 'CCONJ')
# ('reconocida', 'ADJ')
# ('solvencia', 'NOUN')
# ('moral', 'ADJ')
# (',', 'PUNCT')
# ('algo', 'PRON')
# ('que', 'PRON')
# ('fue', 'AUX')
# ('puesto', 'VERB')
# ('en', 'ADP')
# ('entredicho', 'NOUN')
# ('con', 'ADP')
# ('la', 'DET')
# ('anterior', 'ADJ')
# ('directiva', 'NOUN')
# ('.', 'PUNCT')
# ('Mientras', 'ADV')
# (',', 'PUNCT')
# ('el', 'DET')
# ('ministro', 'NOUN')
# ('de', 'ADP')
# ('Defensa', 'PROPN')
# (',', 'PUNCT')
# ('general', 'NOUN')
# ('Eliécer', 'PROPN')
# ('Hurtado', 'PROPN')
# (',', 'PUNCT')
# ('se', 'PRON')
# ('vio', 'VERB')
# ('obligado', 'ADJ')
# ('a', 'ADP')
# ('salir', 'VERB')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('paso', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('ya', 'ADV')
# ('casi', 'ADV')
# ('normales', 'ADJ')
# ('y', 'CCONJ')
# ('permanentes', 'ADJ')
# ('rumores', 'NOUN')
# ('de', 'ADP')
# ('golpe', 'NOUN')
# ('de', 'ADP')
# ('Estado', 'PROPN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('negó', 'VERB')
# ('que', 'SCONJ')
# ('haya', 'AUX')
# ('división', 'NOUN')
# ('en', 'ADP')
# ('las', 'DET')
# ('filas', 'NOUN')
# ('castrenses', 'ADJ')
# ('y', 'CCONJ')
# ('mucho', 'ADV')
# ('menos', 'ADV')
# ('que', 'SCONJ')
# ('esté', 'AUX')
# ('en', 'ADP')
# ('marcha', 'NOUN')
# ('una', 'DET')
# ('conspiración', 'NOUN')
# ('contra', 'ADP')
# ('Chávez', 'PROPN')
# ('.', 'PUNCT')
# ('"', 'PUNCT')
# ('El', 'DET')
# ('pueblo', 'NOUN')
# ('puede', 'AUX')
# ('estar', 'AUX')
# ('seguro', 'ADJ')
# ('de', 'ADP')
# ('que', 'SCONJ')
# ('aquí', 'ADV')
# ('no', 'ADV')
# ('existe', 'VERB')
# ('nada', 'PRON')
# ('de', 'ADP')
# ('conspiración', 'NOUN')
# (',', 'PUNCT')
# ('ni', 'CCONJ')
# ('está', 'AUX')
# ('preso', 'ADJ')
# ('nadie', 'PRON')
# ('por', 'ADP')
# ('esos', 'DET')
# ('motivos', 'NOUN')
# ('tampoco', 'ADV')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('declaró', 'VERB')
# ('Hurtado', 'PROPN')
# ('en', 'ADP')
# ('una', 'DET')
# ('rueda', 'NOUN')
# ('de', 'ADP')
# ('prensa', 'NOUN')
# ('.', 'PUNCT')
# ('Añadió', 'VERB')
# ('que', 'SCONJ')
# ('desconoce', 'VERB')
# ('la', 'DET')
# ('procedencia', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('rumores', 'NOUN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('estarían', 'AUX')
# ('motivados', 'ADJ')
# ('por', 'ADP')
# ('una', 'DET')
# ('supuesta', 'ADJ')
# ('división', 'NOUN')
# ('en', 'ADP')
# ('la', 'DET')
# ('milicia', 'NOUN')
# ('entre', 'ADP')
# ('los', 'DET')
# ('partidarios', 'NOUN')
# ('de', 'ADP')
# ('Chávez', 'PROPN')
# ('y', 'CCONJ')
# ('los', 'DET')
# ('seguidores', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('aspirante', 'NOUN')
# ('presidencial', 'ADJ')
# ('y', 'CCONJ')
# ('también', 'ADV')
# ('militar', 'NOUN')
# ('retirado', 'ADJ')
# (',', 'PUNCT')
# ('Francisco', 'PROPN')
# ('Arias', 'PROPN')
# ('Cárdenas', 'PROPN')
# (',', 'PUNCT')
# ('quien', 'PRON')
# ('sí', 'INTJ')
# ('se', 'PRON')
# ('ha', 'AUX')
# ('explayado', 'VERB')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('dar', 'VERB')
# ('sus', 'DET')
# ('opiniones', 'NOUN')
# ('sobre', 'ADP')
# ('la', 'DET')
# ('"', 'PUNCT')
# ('payasada', 'NOUN')
# ('"', 'PUNCT')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('aplazamiento', 'NOUN')
# ('electoral', 'ADJ')
# ('La', 'DET')
# ('amnistía', 'NOUN')
# ('favorece', 'VERB')
# ('a', 'ADP')
# ('los', 'DET')
# ('catorce', 'NUM')
# ('coroneles', 'NOUN')
# ('detenidos', 'ADJ')
# ('y', 'CCONJ')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('más', 'ADV')
# ('de', 'ADP')
# ('un', 'DET')
# ('centenar', 'NOUN')
# ('de', 'ADP')
# ('oficiales', 'NOUN')
# ('de', 'ADP')
# ('menor', 'ADJ')
# ('rango', 'NOUN')
# ('procesados', 'ADJ')
# ('por', 'ADP')
# ('participar', 'VERB')
# ('en', 'ADP')
# ('la', 'DET')
# ('asonada', 'NOUN')
# ('golpista', 'ADJ')
# ('contra', 'ADP')
# ('Mahuad', 'PROPN')
# ('que', 'PRON')
# ('facilitó', 'VERB')
# ('la', 'DET')
# ('sucesión', 'NOUN')
# ('en', 'ADP')
# ('la', 'DET')
# ('presidencia', 'NOUN')
# ('de', 'ADP')
# ('Gustavo', 'PROPN')
# ('Noboa', 'PROPN')
# ('.', 'PUNCT')
# ('Solicitada', 'ADJ')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('Congreso', 'PROPN')
# ('por', 'ADP')
# ('el', 'DET')
# ('propio', 'DET')
# ('jefe', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Estado', 'PROPN')
# (',', 'PUNCT')
# ('el', 'DET')
# ('recurso', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('amnistía', 'NOUN')
# ('ha', 'AUX')
# ('sido', 'AUX')
# ('exigida', 'VERB')
# ('por', 'ADP')
# ('todos', 'DET')
# ('los', 'DET')
# ('frentes', 'NOUN')
# ('sociales', 'ADJ')
# ('que', 'PRON')
# ('han', 'AUX')
# ('anunciado', 'VERB')
# ('su', 'DET')
# ('incondicional', 'ADJ')
# ('apoyo', 'NOUN')
# ('a', 'ADP')
# ('los', 'DET')
# ('militares', 'NOUN')
# ('rebeldes', 'ADJ')
# ('.', 'PUNCT')
# ('Noboa', 'PROPN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('fue', 'AUX')
# ('vicepresidente', 'NOUN')
# ('en', 'ADP')
# ('el', 'DET')
# ('gobierno', 'NOUN')
# ('de', 'ADP')
# ('Mahuad', 'PROPN')
# ('y', 'CCONJ')
# ('le', 'PRON')
# ('sucedió', 'VERB')
# ('en', 'ADP')
# ('el', 'DET')
# ('cargo', 'NOUN')
# ('tras', 'ADP')
# ('su', 'DET')
# ('caída', 'NOUN')
# (',', 'PUNCT')
# ('considera', 'VERB')
# ('que', 'SCONJ')
# ('la', 'DET')
# ('amnistía', 'NOUN')
# ('permitirá', 'VERB')
# ('la', 'DET')
# ('pacificación', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('nación', 'NOUN')
# ('y', 'CCONJ')
# ('la', 'DET')
# ('creación', 'NOUN')
# ('de', 'ADP')
# ('un', 'DET')
# ('ambiente', 'NOUN')
# ('propicio', 'ADJ')
# ('para', 'ADP')
# ('el', 'DET')
# ('diálogo', 'NOUN')
# ('y', 'CCONJ')
# ('la', 'DET')
# ('concertación', 'NOUN')
# ('.', 'PUNCT')
# ('Y', 'CCONJ')
# ('es', 'AUX')
# ('que', 'SCONJ')
# ('los', 'DET')
# ('coroneles', 'NOUN')
# ('rebeldes', 'ADJ')
# ('gozan', 'VERB')
# ('de', 'ADP')
# ('una', 'DET')
# ('amplia', 'ADJ')
# ('simpatía', 'NOUN')
# ('entre', 'ADP')
# ('la', 'DET')
# ('población', 'NOUN')
# (',', 'PUNCT')
# ('pues', 'SCONJ')
# (',', 'PUNCT')
# ('según', 'ADP')
# ('las', 'DET')
# ('encuestas', 'NOUN')
# (',', 'PUNCT')
# ('la', 'DET')
# ('mayoría', 'NOUN')
# ('considera', 'VERB')
# ('positivo', 'ADJ')
# ('el', 'DET')
# ('que', 'SCONJ')
# ('hayan', 'AUX')
# ('apoyado', 'VERB')
# ('a', 'ADP')
# ('los', 'DET')
# ('movimientos', 'NOUN')
# ('sociales', 'ADJ')
# ('que', 'PRON')
# ('exigían', 'VERB')
# ('la', 'DET')
# ('salida', 'NOUN')
# ('de', 'ADP')
# ('Mahuad', 'PROPN')
# (',', 'PUNCT')
# ('acusado', 'ADJ')
# ('de', 'ADP')
# ('haber', 'AUX')
# ('ahondado', 'VERB')
# ('la', 'DET')
# ('crisis', 'NOUN')
# ('económica', 'ADJ')
# ('que', 'PRON')
# ('afecta', 'VERB')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('país', 'NOUN')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('cabecilla', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('movimiento', 'NOUN')
# ('militar', 'ADJ')
# ('fue', 'AUX')
# ('el', 'DET')
# ('coronel', 'NOUN')
# ('Lucio', 'PROPN')
# ('Gutiérrez', 'PROPN')
# (',', 'PUNCT')
# ('quien', 'PRON')
# ('apoyó', 'VERB')
# ('a', 'ADP')
# ('los', 'DET')
# ('miles', 'NUM')
# ('de', 'ADP')
# ('indígenas', 'NOUN')
# ('que', 'PRON')
# ('ocuparon', 'VERB')
# ('el', 'DET')
# ('21', 'NUM')
# ('de', 'ADP')
# ('enero', 'NOUN')
# ('el', 'DET')
# ('Palacio', 'PROPN')
# ('Legislativo', 'PROPN')
# ('y', 'CCONJ')
# ('luego', 'ADV')
# ('marcharon', 'VERB')
# ('hacia', 'ADP')
# ('el', 'DET')
# ('centro', 'NOUN')
# ('de', 'ADP')
# ('Quito', 'PROPN')
# ('para', 'ADP')
# ('tomar', 'VERB')
# ('posesión', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('Casa', 'PROPN')
# ('Presidencial', 'PROPN')
# ('.', 'PUNCT')
# ('Gutiérrez', 'PROPN')
# ('no', 'ADV')
# ('se', 'PRON')
# ('arrepiente', 'VERB')
# ('de', 'ADP')
# ('haber', 'AUX')
# ('participado', 'VERB')
# ('en', 'ADP')
# ('la', 'DET')
# ('insurrección', 'NOUN')
# ('contra', 'ADP')
# ('Mahuad', 'PROPN')
# ('y', 'CCONJ')
# ('está', 'AUX')
# ('seguro', 'ADJ')
# ('que', 'SCONJ')
# ('la', 'DET')
# ('actitud', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('oficiales', 'NOUN')
# ('se', 'PRON')
# ('debió', 'VERB')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('elevado', 'ADJ')
# ('grado', 'NOUN')
# ('de', 'ADP')
# ('corrupción', 'NOUN')
# ('que', 'PRON')
# ('dice', 'VERB')
# ('hubo', 'AUX')
# ('durante', 'ADP')
# ('la', 'DET')
# ('anterior', 'ADJ')
# ('administración', 'NOUN')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('coronel', 'NOUN')
# ('quiere', 'VERB')
# ('concluir', 'VERB')
# ('su', 'DET')
# ('brillante', 'ADJ')
# ('carrera', 'NOUN')
# ('militar', 'ADJ')
# (',', 'PUNCT')
# ('aunque', 'SCONJ')
# ('aún', 'ADV')
# ('debe', 'AUX')
# ('esperar', 'VERB')
# ('las', 'DET')
# ('posibles', 'ADJ')
# ('sanciones', 'NOUN')
# ('disciplinarias', 'ADJ')
# ('que', 'PRON')
# ('le', 'PRON')
# ('podría', 'AUX')
# ('imponer', 'VERB')
# ('el', 'DET')
# ('mando', 'NOUN')
# ('militar', 'ADJ')
# ('.', 'PUNCT')
# ('La', 'DET')
# ('amnistía', 'NOUN')
# (',', 'PUNCT')
# ('según', 'ADP')
# ('opiniones', 'NOUN')
# ('de', 'ADP')
# ('diputados', 'NOUN')
# (',', 'PUNCT')
# ('no', 'ADV')
# ('impide', 'VERB')
# ('que', 'SCONJ')
# ('las', 'DET')
# ('autoridades', 'NOUN')
# ('militares', 'ADJ')
# ('impongan', 'VERB')
# ('sanciones', 'NOUN')
# ('disciplinarias', 'ADJ')
# ('a', 'ADP')
# ('los', 'DET')
# ('oficiales', 'NOUN')
# ('involucrados', 'ADJ')
# (',', 'PUNCT')
# ('pues', 'SCONJ')
# ('el', 'DET')
# ('recurso', 'NOUN')
# ('político', 'ADJ')
# ('sólo', 'ADV')
# ('establece', 'VERB')
# ('la', 'DET')
# ('suspensión', 'NOUN')
# ('de', 'ADP')
# ('procesos', 'NOUN')
# ('penales', 'ADJ')
# ('civiles', 'ADJ')
# ('y', 'CCONJ')
# ('los', 'DET')
# ('seguidos', 'ADJ')
# ('en', 'ADP')
# ('la', 'DET')
# ('Corte', 'PROPN')
# ('de', 'ADP')
# ('Justicia', 'PROPN')
# ('Militar', 'PROPN')
# ('.', 'PUNCT')
# ('Los', 'DET')
# ('frentes', 'NOUN')
# ('populares', 'ADJ')
# ('no', 'ADV')
# ('están', 'AUX')
# ('dispuestos', 'ADJ')
# ('a', 'ADP')
# ('que', 'SCONJ')
# ('las', 'DET')
# ('Fuerzas', 'PROPN')
# ('Armadas', 'PROPN')
# ('impongan', 'VERB')
# ('sanciones', 'NOUN')
# ('y', 'CCONJ')
# ('si', 'SCONJ')
# (',', 'PUNCT')
# ('acaso', 'ADV')
# (',', 'PUNCT')
# ('las', 'PRON')
# ('aplican', 'VERB')
# (',', 'PUNCT')
# ('convocarán', 'VERB')
# ('a', 'ADP')
# ('protestas', 'NOUN')
# ('contra', 'ADP')
# ('los', 'DET')
# ('mandos', 'NOUN')
# ('militares', 'ADJ')
# (',', 'PUNCT')
# ('según', 'SCONJ')
# ('lo', 'PRON')
# ('aseguró', 'VERB')
# ('el', 'DET')
# ('dirigente', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('Coordinadora', 'PROPN')
# ('de', 'ADP')
# ('Movimientos', 'PROPN')
# ('Sociales', 'PROPN')
# (',', 'PUNCT')
# ('Napoleón', 'PROPN')
# ('Saltos', 'PROPN')
# ('.', 'PUNCT')
# ('"', 'PUNCT')
# ('Vamos', 'AUX')
# ('a', 'ADP')
# ('estar', 'AUX')
# ('vigilantes', 'NOUN')
# ('de', 'ADP')
# ('que', 'SCONJ')
# ('se', 'PRON')
# ('cumpla', 'VERB')
# ('la', 'DET')
# ('Constitución', 'PROPN')
# ('y', 'CCONJ')
# ('que', 'SCONJ')
# ('la', 'DET')
# ('amnistía', 'NOUN')
# ('sea', 'AUX')
# ('total', 'ADJ')
# (',', 'PUNCT')
# ('es', 'CCONJ')
# ('que', 'SCONJ')
# ('luego', 'ADV')
# ('no', 'ADV')
# ('se', 'PRON')
# ('tomen', 'VERB')
# ('retaliaciones', 'NOUN')
# ('o', 'CCONJ')
# ('venganzas', 'NOUN')
# ('contra', 'ADP')
# ('los', 'DET')
# ('militares', 'NOUN')
# ('a', 'ADP')
# ('pretexto', 'NOUN')
# ('de', 'ADP')
# ('una', 'DET')
# ('sanción', 'NOUN')
# ('disciplinaria', 'ADJ')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('indicó', 'VERB')
# ('el', 'DET')
# ('dirigente', 'NOUN')
# ('.', 'PUNCT')
# ('Agregó', 'VERB')
# ('que', 'SCONJ')
# ('si', 'SCONJ')
# ('los', 'DET')
# ('mandos', 'NOUN')
# ('militares', 'ADJ')
# ('no', 'ADV')
# ('acatan', 'VERB')
# ('a', 'ADP')
# ('plenitud', 'NOUN')
# ('la', 'DET')
# ('amnistía', 'NOUN')
# (',', 'PUNCT')
# ('"', 'PUNCT')
# ('que', 'PRON')
# ('es', 'AUX')
# ('una', 'DET')
# ('posición', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('mayoría', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('población', 'NOUN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('e', 'CCONJ')
# ('imponen', 'VERB')
# ('sanciones', 'NOUN')
# ('disciplinarias', 'ADJ')
# ('que', 'PRON')
# ('podrían', 'AUX')
# ('llegar', 'VERB')
# ('hasta', 'ADP')
# ('la', 'DET')
# ('separación', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('rebeldes', 'NOUN')
# ('de', 'ADP')
# ('las', 'DET')
# ('filas', 'NOUN')
# ('castrenses', 'ADJ')
# (',', 'PUNCT')
# ('los', 'DET')
# ('grupos', 'NOUN')
# ('sociales', 'ADJ')
# ('retomarán', 'VERB')
# ('las', 'DET')
# ('movilizaciones', 'NOUN')
# ('y', 'CCONJ')
# ('se', 'PRON')
# ('podría', 'AUX')
# ('llegar', 'VERB')
# ('"', 'PUNCT')
# ('a', 'ADP')
# ('una', 'DET')
# ('convulsión', 'NOUN')
# ('mayor', 'ADJ')
# ('"', 'PUNCT')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('presidente', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Legislativo', 'PROPN')
# (',', 'PUNCT')
# ('Juan', 'PROPN')
# ('José', 'PROPN')
# ('Pons', 'PROPN')
# (',', 'PUNCT')
# ('coincidió', 'VERB')
# ('en', 'ADP')
# ('que', 'SCONJ')
# ('la', 'DET')
# ('amnistía', 'NOUN')
# ('tiene', 'VERB')
# ('por', 'ADP')
# ('objetivo', 'NOUN')
# ('"', 'PUNCT')
# ('pacificar', 'VERB')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('país', 'NOUN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('devolver', 'VERB')
# ('la', 'DET')
# ('tranquilidad', 'NOUN')
# ('que', 'PRON')
# ('la', 'DET')
# ('nación', 'NOUN')
# ('necesita', 'VERB')
# ('para', 'ADP')
# ('atender', 'VERB')
# ('otros', 'DET')
# ('problemas', 'NOUN')
# ('urgentes', 'ADJ')
# ('como', 'ADP')
# ('la', 'DET')
# ('crisis', 'NOUN')
# ('económica', 'ADJ')
# (',', 'PUNCT')
# ('la', 'DET')
# ('pobreza', 'NOUN')
# ('.', 'PUNCT')
# ('La', 'DET')
# ('aprobación', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('amnistía', 'NOUN')
# ('"', 'PUNCT')
# ('es', 'AUX')
# ('una', 'DET')
# ('muestra', 'NOUN')
# ('de', 'ADP')
# ('responsabilidad', 'NOUN')
# ('cívica', 'ADJ')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Congreso', 'PROPN')
# ('ecuatoriano', 'ADJ')
# (',', 'PUNCT')
# ('con', 'ADP')
# ('el', 'DET')
# ('fin', 'NOUN')
# ('de', 'ADP')
# ('"', 'PUNCT')
# ('olvidarnos', '_')
# ('olvidar', 'VERB')
# ('nos', 'PRON')
# ('de', 'ADP')
# ('los', 'DET')
# ('hechos', 'NOUN')
# ('pasados', 'ADJ')
# ('para', 'ADP')
# ('construir', 'VERB')
# ('una', 'DET')
# ('nueva', 'ADJ')
# ('historia', 'NOUN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('afirmó', 'VERB')
# ('Pons', 'PROPN')
# ('Hace', 'VERB')
# ('un', 'DET')
# ('par', 'NOUN')
# ('de', 'ADP')
# ('días', 'NOUN')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('una', 'DET')
# ('nica', 'ADJ')
# ('acera', 'NOUN')
# ('vi', 'VERB')
# ('cinco', 'NUM')
# ('contenedores', 'NOUN')
# ('juntos', 'ADJ')
# (':', 'PUNCT')
# ('un', 'DET')
# ('contenedor', 'NOUN')
# ('metálico', 'ADJ')
# ('verde', 'ADJ')
# ('(', 'PUNCT')
# ('para', 'ADP')
# ('reciclar', 'VERB')
# ('vidrio', 'NOUN')
# (')', 'PUNCT')
# (';', 'PUNCT')
# ('un', 'DET')
# ('contenedor', 'NOUN')
# ('metálico', 'ADJ')
# ('amarillo', 'ADJ')
# ('(', 'PUNCT')
# ('para', 'ADP')
# ('reciclar', 'VERB')
# ('papeles', 'NOUN')
# (':', 'PUNCT')
# ('¡', 'PUNCT')
# ('pero', 'CCONJ')
# ('no', 'ADV')
# ('cartones', 'NOUN')
# ('!', 'PUNCT')
# (',', 'PUNCT')
# ('aclaraba', 'VERB')
# (')', 'PUNCT')
# (';', 'PUNCT')
# ('otro', 'DET')
# ('contenedor', 'NOUN')
# ('verde', 'ADJ')
# ('(', 'PUNCT')
# ('pero', 'CCONJ')
# ('de', 'ADP')
# ('plástico', 'NOUN')
# (':', 'PUNCT')
# ('para', 'ADP')
# ('la', 'DET')
# ('basura', 'NOUN')
# ('normal', 'ADJ')
# (')', 'PUNCT')
# (';', 'PUNCT')
# ('otro', 'DET')
# ('contenedor', 'NOUN')
# ('amarillo', 'ADJ')
# ('(', 'PUNCT')
# ('más', 'ADV')
# ('pequeño', 'ADJ')
# (',', 'PUNCT')
# ('acoplado', 'ADJ')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('papel', 'NOUN')
# (',', 'PUNCT')
# ('para', 'ADP')
# ('reciclar', 'VERB')
# ('pilas', 'NOUN')
# ('normales', 'ADJ')
# (')', 'PUNCT')
# (';', 'PUNCT')
# ('y', 'CCONJ')
# ('otro', 'PRON')
# ('más', 'ADV')
# ('pequeño', 'ADJ')
# ('aún', 'ADV')
# ('(', 'PUNCT')
# ('colocado', 'ADJ')
# ('sobre', 'ADP')
# ('el', 'DET')
# ('anterior', 'ADJ')
# ('para', 'ADP')
# ('las', 'DET')
# ('pilas', 'NOUN')
# ('botón', 'ADJ')
# (')', 'PUNCT')
# ('.', 'PUNCT')
# ('Reciclaje', 'NOUN')
# (',', 'PUNCT')
# ('ahorro', 'NOUN')
# (',', 'PUNCT')
# ('aprovechamiento', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('residuos', 'NOUN')
# ('y', 'CCONJ')
# ('lucha', 'NOUN')
# ('contra', 'ADP')
# ('el', 'DET')
# ('despilfarro', 'NOUN')
# ('energético', 'ADJ')
# ('de', 'ADP')
# ('los', 'DET')
# ('países', 'NOUN')
# ('ricos', 'ADJ')
# ('.', 'PUNCT')
# ('Imbuido', 'ADJ')
# ('de', 'ADP')
# ('ese', 'DET')
# ('espíritu', 'NOUN')
# (',', 'PUNCT')
# ('un', 'DET')
# ('escritor', 'NOUN')
# ('inglés', 'ADJ')
# ('-', 'PUNCT')
# ('excepcional', 'ADJ')
# ('y', 'CCONJ')
# ('sarcástico', 'ADJ')
# ('-', 'PUNCT')
# ('proponía', 'VERB')
# ('hace', 'VERB')
# ('poco', 'ADV')
# ('que', 'SCONJ')
# ('no', 'ADV')
# ('se', 'PRON')
# ('tirase', 'VERB')
# ('el', 'DET')
# ('agua', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('bolsa', 'NOUN')
# ('de', 'ADP')
# ('agua', 'NOUN')
# ('caliente', 'ADJ')
# ('.', 'PUNCT')
# ('Tirarla', '_')
# ('Tirar', 'VERB')
# ('la', 'PRON')
# (',', 'PUNCT')
# ('decía', 'VERB')
# (',', 'PUNCT')
# ('es', 'AUX')
# ('un', 'DET')
# ('despilfarro', 'NOUN')
# (';', 'PUNCT')
# ('lo', 'PRON')
# ('que', 'SCONJ')
# ('hay', 'AUX')
# ('que', 'SCONJ')
# ('hacer', 'VERB')
# ('es', 'AUX')
# ('reciclarla', '_')
# ('reciclar', 'VERB')
# ('la', 'PRON')
# (',', 'PUNCT')
# ('guardarla', '_')
# ('guardar', 'VERB')
# ('la', 'PRON')
# ('y', 'CCONJ')
# ('volverla', '_')
# ('volver', 'VERB')
# ('la', 'PRON')
# ('a', 'ADP')
# ('calentar', 'VERB')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('día', 'NOUN')
# ('siguiente', 'ADJ')
# ('.', 'PUNCT')
# ('Sí', 'INTJ')
# (',', 'PUNCT')
# ('señor', 'NOUN')
# ('.', 'PUNCT')
# ('Y', 'CCONJ')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('la', 'DET')
# ('mesa', 'NOUN')
# (',', 'PUNCT')
# ('se', 'PRON')
# ('acabó', 'VERB')
# ('eso', 'PRON')
# ('de', 'ADP')
# ('usar', 'VERB')
# ('los', 'DET')
# ('palillos', 'NOUN')
# ('una', 'DET')
# ('sola', 'ADJ')
# ('vez', 'NOUN')
# ('y', 'CCONJ')
# ('tirarlos', '_')
# ('tirar', 'VERB')
# ('los', 'PRON')
# ('.', 'PUNCT')
# ('Hay', 'AUX')
# ('que', 'SCONJ')
# ('recogerlos', '_')
# ('recoger', 'VERB')
# ('los', 'PRON')
# ('una', 'DET')
# ('vez', 'NOUN')
# ('usados', 'ADJ')
# (',', 'PUNCT')
# ('fregar', 'VERB')
# ('los', 'DET')
# ('restos', 'NOUN')
# ('de', 'ADP')
# ('comida', 'NOUN')
# ('que', 'PRON')
# ('hayan', 'AUX')
# ('quedado', 'VERB')
# ('adheridos', 'ADJ')
# ('y', 'CCONJ')
# ('ponerlos', '_')
# ('poner', 'VERB')
# ('los', 'PRON')
# ('a', 'ADP')
# ('secar', 'VERB')
# ('.', 'PUNCT')
# ('De', 'ADP')
# ('esta', 'DET')
# ('manera', 'NOUN')
# ('cada', 'DET')
# ('uno', 'PRON')
# ('de', 'ADP')
# ('nosotros', 'PRON')
# ('evitará', 'VERB')
# ('que', 'SCONJ')
# ('hectáreas', 'NOUN')
# ('y', 'CCONJ')
# ('hectáreas', 'NOUN')
# ('de', 'ADP')
# ('bosque', 'NOUN')
# ('sean', 'AUX')
# ('diezmadas', 'VERB')
# ('cada', 'DET')
# ('día', 'NOUN')
# ('para', 'ADP')
# ('fabricar', 'VERB')
# ('esos', 'DET')
# ('palillos', 'NOUN')
# ('pequeñoburgueses', 'ADJ')
# ('con', 'ADP')
# ('que', 'PRON')
# ('hurgamos', 'VERB')
# ('entre', 'ADP')
# ('las', 'DET')
# ('caries', 'NOUN')
# ('.', 'PUNCT')
# ('Y', 'CCONJ')
# (',', 'PUNCT')
# ('ya', 'ADV')
# ('que', 'SCONJ')
# ('en', 'ADP')
# ('eso', 'PRON')
# ('estamos', 'AUX')
# (',', 'PUNCT')
# ('otro', 'DET')
# ('consejo', 'NOUN')
# (':', 'PUNCT')
# ('los', 'DET')
# ('dientes', 'NOUN')
# ('cariados', 'ADJ')
# ('que', 'PRON')
# ('nos', 'PRON')
# ('arranque', 'VERB')
# ('el', 'DET')
# ('dentista', 'NOUN')
# (',', 'PUNCT')
# ('nada', 'NOUN')
# ('de', 'ADP')
# ('tirarlos', '_')
# ('tirar', 'VERB')
# ('los', 'PRON')
# ('.', 'PUNCT')
# ('Convenientemente', 'ADV')
# ('ensartados', 'ADJ')
# ('en', 'ADP')
# ('un', 'DET')
# ('hilo', 'NOUN')
# ('de', 'ADP')
# ('nylon', 'NOUN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('alternados', 'ADJ')
# ('con', 'ADP')
# ('los', 'DET')
# ('huesos', 'NOUN')
# ('de', 'ADP')
# ('las', 'DET')
# ('aceitunas', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('aperitivo', 'NOUN')
# ('(', 'PUNCT')
# ('que', 'PRON')
# ('habremos', 'AUX')
# ('guardado', 'VERB')
# (',', 'PUNCT')
# ('evidentemente', 'ADV')
# (':', 'PUNCT')
# ('¡', 'PUNCT')
# ('aquí', 'ADV')
# ('no', 'ADV')
# ('se', 'PRON')
# ('tira', 'VERB')
# ('nada', 'PRON')
# ('!', 'PUNCT')
# (')', 'PUNCT')
# ('conseguiremos', 'VERB')
# ('un', 'DET')
# ('bonito', 'ADJ')
# ('collar', 'NOUN')
# ('recycled', 'ADJ')
# ('ecological', 'ADJ')
# ('para', 'ADP')
# ('regalar', 'VERB')
# ('por', 'ADP')
# ('ejemplo', 'NOUN')
# ('a', 'ADP')
# ('la', 'DET')
# ('asistenta', 'NOUN')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('error', 'NOUN')
# ('fue', 'AUX')
# ('haberlo', '_')
# ('haber', 'AUX')
# ('lo', 'PRON')
# ('comprado', 'VERB')
# ('en', 'ADP')
# ('rebajas', 'NOUN')
# ('.', 'PUNCT')
# ('Al', '_')
# ('A', 'ADP')
# ('el', 'DET')
# ('terminar', 'VERB')
# ('la', 'DET')
# ('Navidad', 'PROPN')
# ('pasada', 'ADJ')
# (',', 'PUNCT')
# ('una', 'DET')
# ('tienda', 'NOUN')
# ('de', 'ADP')
# ('belenes', 'NOUN')
# ('ofreció', 'VERB')
# ('nacimientos', 'NOUN')
# ('a', 'ADP')
# ('precio', 'NOUN')
# ('de', 'ADP')
# ('quema', 'NOUN')
# ('.', 'PUNCT')
# ('Y', 'CCONJ')
# ('nos', 'PRON')
# ('quemamos', 'VERB')
# ('.', 'PUNCT')
# ('Hemos', 'AUX')
# ('debido', 'AUX')
# ('pensarlo', '_')
# ('pensar', 'VERB')
# ('lo', 'PRON')
# ('.', 'PUNCT')
# ('Resultaban', 'VERB')
# ('demasiado', 'ADV')
# ('baratos', 'ADJ')
# ('para', 'ADP')
# ('ser', 'AUX')
# ('buenos', 'ADJ')
# ('.', 'PUNCT')
# ('Por', 'ADP')
# ('eso', 'PRON')
# (',', 'PUNCT')
# ('cuando', 'SCONJ')
# ('destapamos', 'VERB')
# ('la', 'DET')
# ('caja', 'NOUN')
# ('hace', 'VERB')
# ('algunos', 'DET')
# ('días', 'NOUN')
# (',', 'PUNCT')
# ('descubrimos', 'VERB')
# ('que', 'SCONJ')
# ('los', 'DET')
# ('tres', 'NUM')
# ('reyes', 'NOUN')
# ('eran', 'AUX')
# ('blancos', 'ADJ')
# ('y', 'CCONJ')
# ('que', 'SCONJ')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('vez', 'NOUN')
# ('de', 'ADP')
# ('un', 'DET')
# ('Niño', 'PROPN')
# ('Jesús', 'PROPN')
# (',', 'PUNCT')
# ('había', 'AUX')
# ('dos', 'NUM')
# ('.', 'PUNCT')
# ('Eran', 'AUX')
# ('idénticos', 'ADJ')
# ('.', 'PUNCT')
# ('La', 'DET')
# ('nica', 'ADJ')
# ('diferencia', 'NOUN')
# ('estaba', 'AUX')
# ('en', 'ADP')
# ('el', 'DET')
# ('color', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('pañal', 'NOUN')
# (':', 'PUNCT')
# ('el', 'DET')
# ('uno', 'PRON')
# ('era', 'AUX')
# ('blanco', 'ADJ')
# ('y', 'CCONJ')
# ('el', 'DET')
# ('otro', 'PRON')
# ('rojizo', 'ADJ')
# ('.', 'PUNCT')
# ('La', 'DET')
# ('ausencia', 'NOUN')
# ('de', 'ADP')
# ('Baltasar', 'PROPN')
# ('era', 'AUX')
# ('explicable', 'ADJ')
# ('pero', 'CCONJ')
# ('alarmante', 'ADJ')
# (':', 'PUNCT')
# ('significaba', 'VERB')
# ('que', 'SCONJ')
# ('la', 'DET')
# ('ola', 'NOUN')
# ('racista', 'ADJ')
# ('acababa', 'VERB')
# ('de', 'ADP')
# ('llegar', 'VERB')
# ('hasta', 'ADP')
# ('los', 'DET')
# ('belenes', 'NOUN')
# ('.', 'PUNCT')
# ('Pero', 'CCONJ')
# ('la', 'DET')
# ('existencia', 'NOUN')
# ('de', 'ADP')
# ('dos', 'NUM')
# ('recién', 'ADV')
# ('nacidos', 'ADJ')
# ('en', 'ADP')
# ('la', 'DET')
# ('misma', 'DET')
# ('caja', 'NOUN')
# ('sólo', 'ADV')
# ('podía', 'AUX')
# ('deberse', '_')
# ('deber', 'VERB')
# ('se', 'PRON')
# ('a', 'ADP')
# ('un', 'DET')
# ('descuido', 'NOUN')
# ('de', 'ADP')
# ('fábrica', 'NOUN')
# ('.', 'PUNCT')
# ('De', 'ADP')
# ('allí', 'ADV')
# ('las', 'DET')
# ('rebajas', 'NOUN')
# ('.', 'PUNCT')
# ('-', 'PUNCT')
# ('Ya', 'ADV')
# ('sé', 'VERB')
# ('qué', 'PRON')
# ('ocurre', 'VERB')
# ('-', 'PUNCT')
# ('explicó', 'VERB')
# ('una', 'PRON')
# ('de', 'ADP')
# ('mis', 'DET')
# ('hijas', 'NOUN')
# ('-', 'PUNCT')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('partido', 'NOUN')
# ('tumultuoso', 'ADJ')
# ('y', 'CCONJ')
# ('enrabietado', 'ADJ')
# (',', 'PUNCT')
# ('bastante', 'ADV')
# ('cochambrosete', 'ADJ')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('hizo', 'VERB')
# ('anoche', 'ADV')
# ('el', 'DET')
# ('Madrid', 'PROPN')
# ('me', 'PRON')
# ('recordó', 'VERB')
# ('con', 'ADP')
# ('frecuencia', 'NOUN')
# ('los', 'DET')
# ('arrebatos', 'NOUN')
# ('cinematográficos', 'ADJ')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Ejército', 'PROPN')
# ('de', 'ADP')
# ('Pancho', 'PROPN')
# ('Villa', 'PROPN')
# (',', 'PUNCT')
# ('esa', 'DET')
# ('ética', 'NOUN')
# ('populachera', 'ADJ')
# ('y', 'CCONJ')
# ('emocionante', 'ADJ')
# ('de', 'ADP')
# ('todas', 'DET')
# ('las', 'DET')
# ('revoluciones', 'NOUN')
# ('nobles', 'ADJ')
# ('y', 'CCONJ')
# ('desarrapadas', 'ADJ')
# ('.', 'PUNCT')
# ('Es', 'AUX')
# ('evidente', 'ADJ')
# ('que', 'SCONJ')
# ('el', 'DET')
# ('Madrid', 'PROPN')
# ('de', 'ADP')
# ('los', 'DET')
# ('últimos', 'ADJ')
# ('meses', 'NOUN')
# ('no', 'ADV')
# ('tiene', 'VERB')
# ('estilo', 'NOUN')
# (',', 'PUNCT')
# ('no', 'ADV')
# ('tiene', 'VERB')
# ('estética', 'NOUN')
# (',', 'PUNCT')
# ('no', 'ADV')
# ('tiene', 'VERB')
# ('dinero', 'NOUN')
# (',', 'PUNCT')
# ('no', 'ADV')
# ('tiene', 'VERB')
# ('brújula', 'NOUN')
# ('y', 'CCONJ')
# (',', 'PUNCT')
# ('por', 'ADP')
# ('no', 'ADV')
# ('tener', 'VERB')
# (',', 'PUNCT')
# ('no', 'ADV')
# ('tiene', 'VERB')
# ('ni', 'ADV')
# ('césped', 'NOUN')
# (',', 'PUNCT')
# ('pero', 'CCONJ')
# ('se', 'PRON')
# ('ve', 'VERB')
# ('que', 'SCONJ')
# ('todavía', 'ADV')
# ('es', 'AUX')
# ('capaz', 'ADJ')
# (',', 'PUNCT')
# ('sobre', 'ADP')
# ('el', 'DET')
# ('césped', 'NOUN')
# ('ajeno', 'ADJ')
# (',', 'PUNCT')
# ('de', 'ADP')
# ('pegar', 'VERB')
# ('bocados', 'NOUN')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('sábado', 'NOUN')
# ('pasado', 'ADJ')
# (',', 'PUNCT')
# ('sobre', 'ADP')
# ('la', 'DET')
# ('hierba', 'NOUN')
# ('blaugrana', 'ADJ')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Nou', 'NUM')
# ('Camp', 'PROPN')
# (',', 'PUNCT')
# ('esta', 'DET')
# ('yegua', 'NOUN')
# ('viejorra', 'ADJ')
# ('y', 'CCONJ')
# ('pendedera', 'ADJ')
# ('que', 'PRON')
# ('es', 'AUX')
# ('ahora', 'ADV')
# ('el', 'DET')
# ('Real', 'PROPN')
# ('Madrid', 'PROPN')
# ('se', 'PRON')
# ('llevó', 'VERB')
# ('un', 'DET')
# ('puñado', 'NOUN')
# ('de', 'ADP')
# ('zurriagazos', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('que', 'PRON')
# ('dejan', 'VERB')
# ('mataduras', 'NOUN')
# ('hasta', 'ADP')
# ('el', 'DET')
# ('día', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('extremaunción', 'NOUN')
# ('.', 'PUNCT')
# ('Pero', 'CCONJ')
# ('anoche', 'ADV')
# (',', 'PUNCT')
# ('sobre', 'ADP')
# ('el', 'DET')
# ('césped', 'NOUN')
# ('rojiblanco', 'ADJ')
# (',', 'PUNCT')
# ('la', 'DET')
# ('burraca', 'NOUN')
# ('maleada', 'ADJ')
# ('y', 'CCONJ')
# ('retorcida', 'ADJ')
# ('en', 'ADP')
# ('que', 'PRON')
# ('se', 'PRON')
# ('ha', 'AUX')
# ('convertido', 'VERB')
# ('el', 'DET')
# ('Madrid', 'PROPN')
# ('tuvo', 'VERB')
# ('el', 'DET')
# ('coraje', 'NOUN')
# ('y', 'CCONJ')
# ('la', 'DET')
# ('vergüenza', 'NOUN')
# ('necesaria', 'ADJ')
# ('para', 'ADP')
# ('alzarse', '_')
# ('alzar', 'VERB')
# ('se', 'PRON')
# ('contra', 'ADP')
# ('su', 'DET')
# ('decrepitud', 'NOUN')
# (',', 'PUNCT')
# ('su', 'DET')
# ('desnorte', 'NOUN')
# ('y', 'CCONJ')
# ('su', 'DET')
# ('mal', 'ADV')
# ('fario', 'NOUN')
# ('con', 'ADP')
# ('las', 'DET')
# ('armas', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('desheredados', 'NOUN')
# (':', 'PUNCT')
# ('muchas', 'DET')
# ('glándulas', 'NOUN')
# (',', 'PUNCT')
# ('mucho', 'DET')
# ('nervio', 'NOUN')
# (',', 'PUNCT')
# ('mucha', 'DET')
# ('embestida', 'NOUN')
# ('y', 'CCONJ')
# ('el', 'DET')
# ('arsenal', 'NOUN')
# ('de', 'ADP')
# ('músculos', 'NOUN')
# (',', 'PUNCT')
# ('fulgores', 'NOUN')
# ('y', 'CCONJ')
# ('tosquedades', 'NOUN')
# ('que', 'PRON')
# ('la', 'DET')
# ('desgracia', 'NOUN')
# ('y', 'CCONJ')
# ('la', 'DET')
# ('desesperación', 'NOUN')
# ('pone', 'VERB')
# ('en', 'ADP')
# ('mano', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('combatientes', 'NOUN')
# ('campesinos', 'ADJ')
# ('.', 'PUNCT')
# ('Anoche', 'ADV')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('el', 'DET')
# ('Calderón', 'PROPN')
# (',', 'PUNCT')
# ('el', 'DET')
# ('Real', 'PROPN')
# ('Madrid', 'PROPN')
# ('parecía', 'VERB')
# ('recién', 'ADV')
# ('llegado', 'ADJ')
# ('de', 'ADP')
# ('Chiapas', 'PROPN')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('Madrid', 'PROPN')
# ('se', 'PRON')
# ('encontró', 'VERB')
# ('con', 'ADP')
# ('un', 'DET')
# ('adversario', 'NOUN')
# ('acalambrado', 'ADJ')
# ('y', 'CCONJ')
# ('descoyuntado', 'ADJ')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('frente', 'NOUN')
# ('a', 'ADP')
# ('un', 'DET')
# ('Atlético', 'PROPN')
# ('así', 'ADV')
# ('el', 'DET')
# ('Madrid', 'PROPN')
# ('de', 'ADP')
# ('los', 'DET')
# ('buenos', 'ADJ')
# ('tiempos', 'NOUN')
# (',', 'PUNCT')
# ('aquel', 'DET')
# ('Madrid', 'PROPN')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('que', 'PRON')
# ('quisimos', 'VERB')
# ('tanto', 'ADV')
# (',', 'PUNCT')
# ('habría', 'AUX')
# ('hecho', 'VERB')
# ('virguerías', 'NOUN')
# (',', 'PUNCT')
# ('habría', 'AUX')
# ('desplegado', 'VERB')
# ('una', 'DET')
# ('lección', 'NOUN')
# ('de', 'ADP')
# ('poderío', 'NOUN')
# ('y', 'CCONJ')
# ('clase', 'NOUN')
# (',', 'PUNCT')
# ('se', 'PRON')
# ('habría', 'AUX')
# ('puesto', 'VERB')
# ('antipático', 'ADJ')
# ('como', 'SCONJ')
# ('sólo', 'ADV')
# ('un', 'DET')
# ('señor', 'NOUN')
# ('puede', 'AUX')
# ('ponerse', '_')
# ('poner', 'VERB')
# ('se', 'PRON')
# ('.', 'PUNCT')
# ('Pero', 'CCONJ')
# ('el', 'DET')
# ('Real', 'PROPN')
# ('Madrid', 'PROPN')
# ('de', 'ADP')
# ('anoche', 'ADV')
# ('era', 'AUX')
# ('tan', 'ADV')
# ('terrenal', 'ADJ')
# (',', 'PUNCT')
# ('tan', 'ADV')
# ('rural', 'ADJ')
# ('incluso', 'ADV')
# (',', 'PUNCT')
# ('que', 'SCONJ')
# ('despertaba', 'VERB')
# ('ese', 'DET')
# ('sucedáneo', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('piedad', 'NOUN')
# ('que', 'PRON')
# ('llamamos', 'VERB')
# ('simpatía', 'NOUN')
# ('.', 'PUNCT')
# ('Hasta', 'ADV')
# ('Butragueño', 'PROPN')
# (',', 'PUNCT')
# ('mientras', 'SCONJ')
# ('estuvo', 'VERB')
# ('en', 'ADP')
# ('el', 'DET')
# ('campo', 'NOUN')
# (',', 'PUNCT')
# ('parecía', 'VERB')
# ('estar', 'AUX')
# ('haciendo', 'VERB')
# ('novillos', 'NOUN')
# ('de', 'ADP')
# ('ese', 'DET')
# ('pamplinoso', 'ADJ')
# ('nirvana', 'NOUN')
# (',', 'PUNCT')
# ('lleno', 'ADJ')
# ('de', 'ADP')
# ('ascetismo', 'NOUN')
# ('y', 'CCONJ')
# ('resignación', 'NOUN')
# ('en', 'ADP')
# ('el', 'DET')
# ('que', 'PRON')
# ('lleva', 'VERB')
# ('sumido', 'ADJ')
# ('tanto', 'ADV')
# ('tiempo', 'NOUN')
# ('.', 'PUNCT')
# ('Anoche', 'ADV')
# ('todo', 'DET')
# ('el', 'DET')
# ('Madrid', 'PROPN')
# ('parecía', 'VERB')
# ('haberse', '_')
# ('haber', 'AUX')
# ('se', 'PRON')
# ('olvidado', 'VERB')
# ('de', 'ADP')
# ('que', 'SCONJ')
# ('es', 'AUX')
# ('el', 'DET')
# ('Madrid', 'PROPN')
# (',', 'PUNCT')
# ('parecía', 'VERB')
# ('a', 'ADP')
# ('salvo', 'NOUN')
# ('no', 'PART')
# ('sólo', 'ADV')
# ('de', 'ADP')
# ('sus', 'DET')
# ('calamidades', 'NOUN')
# (',', 'PUNCT')
# ('sino', 'CCONJ')
# ('también', 'NOUN')
# ('de', 'ADP')
# ('su', 'DET')
# ('historia', 'NOUN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('se', 'PRON')
# ('portó', 'VERB')
# ('como', 'SCONJ')
# ('un', 'DET')
# ('hombre', 'NOUN')
# ('.', 'PUNCT')
# ('Por', 'ADP')
# ('supuesto', 'NOUN')
# (',', 'PUNCT')
# ('el', 'DET')
# ('Real', 'PROPN')
# ('Madrid', 'PROPN')
# ('puede', 'AUX')
# ('hacer', 'VERB')
# ('otra', 'DET')
# ('vez', 'NOUN')
# ('el', 'DET')
# ('ridículo', 'NOUN')
# ('el', 'DET')
# ('domingo', 'NOUN')
# ('que', 'PRON')
# ('viene', 'VERB')
# (',', 'PUNCT')
# ('porque', 'SCONJ')
# ('este', 'DET')
# ('Real', 'PROPN')
# ('Madrid', 'PROPN')
# ('no', 'ADV')
# ('es', 'AUX')
# ('de', 'ADP')
# ('fiar', 'VERB')
# (',', 'PUNCT')
# ('pero', 'CCONJ')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('menos', 'ADV')
# ('anoche', 'ADV')
# ('fue', 'AUX')
# ('capaz', 'ADJ')
# ('de', 'ADP')
# ('exhibir', 'VERB')
# ('el', 'DET')
# ('cuajo', 'NOUN')
# ('bravío', 'ADJ')
# ('y', 'CCONJ')
# ('la', 'DET')
# ('estética', 'NOUN')
# ('compulsiva', 'ADJ')
# ('de', 'ADP')
# ('los', 'DET')
# ('insurgentes', 'NOUN')
# ('.', 'PUNCT')
# ('La', 'DET')
# ('concejala', 'NOUN')
# ('de', 'ADP')
# ('Medio', 'PROPN')
# ('Ambiente', 'PROPN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Ayuntamiento', 'PROPN')
# ('de', 'ADP')
# ('Madrid', 'PROPN')
# (',', 'PUNCT')
# ('doña', 'NOUN')
# ('Esperanza', 'PROPN')
# ('Aguirre', 'PROPN')
# (',', 'PUNCT')
# ('es', 'AUX')
# ('una', 'DET')
# ('desgraciada', 'NOUN')
# ('.', 'PUNCT')
# ('Claro', 'ADV')
# ('que', 'SCONJ')
# ('cuando', 'SCONJ')
# ('Felipe', 'PROPN')
# ('González', 'PROPN')
# ('(', 'PUNCT')
# ('que', 'PRON')
# ('a', 'ADP')
# ('lo', 'PRON')
# ('que', 'SCONJ')
# ('parece', 'NOUN')
# ('no', 'ADV')
# ('ha', 'AUX')
# ('perdido', 'VERB')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('todo', 'PRON')
# ('el', 'DET')
# ('carisma', 'NOUN')
# ('aquel', 'DET')
# ('que', 'PRON')
# ('tuvo', 'VERB')
# (')', 'PUNCT')
# ('lanza', 'VERB')
# ('piropos', 'NOUN')
# ('a', 'ADP')
# ('Aznar', 'PROPN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('le', 'PRON')
# ('seduce', 'VERB')
# ('con', 'ADP')
# ('cenas', 'NOUN')
# ('y', 'CCONJ')
# ('discursos', 'NOUN')
# ('y', 'CCONJ')
# ('lo', 'PRON')
# ('califica', 'VERB')
# ('de', 'ADP')
# ('clara', 'ADJ')
# ('alternativa', 'NOUN')
# ('(', 'PUNCT')
# ('acaso', 'ADV')
# ('también', 'ADV')
# ('en', 'ADP')
# ('el', 'DET')
# ('clásico', 'ADJ')
# ('sentido', 'NOUN')
# ('de', 'ADP')
# ('claro', 'ADJ')
# ('/', 'PUNCT')
# ('ilustre', 'ADJ')
# (')', 'PUNCT')
# ('está', 'AUX')
# ('ocurriendo', 'VERB')
# ('algo', 'PRON')
# ('desolador', 'ADJ')
# ('y', 'CCONJ')
# ('terrible', 'ADJ')
# (',', 'PUNCT')
# ('igual', 'ADJ')
# ('que', 'SCONJ')
# ('si', 'SCONJ')
# (',', 'PUNCT')
# ('llegado', 'ADJ')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('Gobierno', 'PROPN')
# (',', 'PUNCT')
# ('José', 'PROPN')
# ('María', 'PROPN')
# ('Aznar', 'PROPN')
# ('se', 'PRON')
# ('volcase', 'VERB')
# ('en', 'ADP')
# ('mieles', 'NOUN')
# ('dialécticas', 'ADJ')
# ('con', 'ADP')
# ('González', 'PROPN')
# ('.', 'PUNCT')
# ('Pero', 'CCONJ')
# ('en', 'ADP')
# ('el', 'DET')
# ('Madrid', 'PROPN')
# ('ya', 'ADV')
# ('sucedió', 'VERB')
# ('la', 'DET')
# ('temporada', 'NOUN')
# ('pasada', 'ADJ')
# ('no', 'ADV')
# ('le', 'PRON')
# ('conceden', 'VERB')
# ('demasiada', 'DET')
# ('importancia', 'NOUN')
# ('a', 'ADP')
# ('esos', 'DET')
# ('detalles', 'NOUN')
# (':', 'PUNCT')
# ('quien', 'PRON')
# ('va', 'VERB')
# ('primero', 'ADJ')
# ('en', 'ADP')
# ('solitario', 'ADJ')
# ('no', 'ADV')
# ('necesita', 'VERB')
# ('-', 'PUNCT')
# ('basket', 'NOUN')
# ('average', 'NOUN')
# ('-', 'PUNCT')
# (',', 'PUNCT')
# ('piensan', 'VERB')
# ('.', 'PUNCT')
# ('-', 'PUNCT')
# ('Quizá', 'ADV')
# ('lo', 'PRON')
# ('lamentemos', 'VERB')
# ('más', 'ADV')
# ('tarde', 'ADV')
# ('-', 'PUNCT')
# (',', 'PUNCT')
# ('reconocía', 'VERB')
# ('Chechu', 'PROPN')
# ('Biriukov', 'PROPN')
# ('...', 'PUNCT')
# ('De', 'ADP')
# ('antemano', 'NOUN')
# ('estaba', 'AUX')
# ('muy', 'ADV')
# ('claro', 'ADJ')
# ('que', 'SCONJ')
# ('el', 'DET')
# ('Barcelona', 'PROPN')
# ('tenía', 'VERB')
# ('mucho', 'ADV')
# ('más', 'ADV')
# ('margen', 'NOUN')
# ('para', 'ADP')
# ('mejorar', 'VERB')
# ('.', 'PUNCT')
# ('En', 'ADP')
# ('defensa', 'NOUN')
# (',', 'PUNCT')
# ('denegando', 'VERB')
# ('el', 'DET')
# ('balón', 'NOUN')
# ('a', 'ADP')
# ('los', 'DET')
# ('hombres', 'NOUN')
# ('altos', 'ADJ')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Madrid', 'PROPN')
# (',', 'PUNCT')
# ('cosa', 'NOUN')
# ('que', 'PRON')
# ('tres', 'NUM')
# ('días', 'NOUN')
# ('antes', 'ADV')
# ('no', 'ADV')
# ('había', 'AUX')
# ('conseguido', 'VERB')
# ('nunca', 'ADV')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('eso', 'PRON')
# ('que', 'SCONJ')
# ('los', 'DET')
# ('blancos', 'NOUN')
# ('encestaban', 'VERB')
# ('poco', 'PRON')
# ('desde', 'ADP')
# ('lejos', 'ADV')
# ('y', 'CCONJ')
# ('debería', 'AUX')
# ('haber', 'AUX')
# ('sido', 'AUX')
# ('posible', 'ADJ')
# ('-', 'PUNCT')
# ('flotar', 'VERB')
# ('-', 'PUNCT')
# ('con', 'ADP')
# ('más', 'ADV')
# ('eficacia', 'NOUN')
# ('sobre', 'ADP')
# ('la', 'DET')
# ('pareja', 'NOUN')
# ('Sabonis-Arlauckas', 'PROPN')
# ('.', 'PUNCT')
# ('En', 'ADP')
# ('ataque', 'NOUN')
# (',', 'PUNCT')
# ('consiguiendo', 'VERB')
# ('a', 'ADP')
# ('la', 'DET')
# ('vez', 'NOUN')
# ('que', 'SCONJ')
# ('todos', 'DET')
# ('los', 'DET')
# ('hombres', 'NOUN')
# ('mirasen', 'VERB')
# ('a', 'ADP')
# ('la', 'DET')
# ('canasta', 'NOUN')
# (',', 'PUNCT')
# ('que', 'SCONJ')
# ('no', 'ADV')
# ('sólo', 'ADV')
# ('Fred', 'PROPN')
# ('Roberts', 'PROPN')
# ('encestase', 'VERB')
# ('sus', 'DET')
# ('suspensiones', 'NOUN')
# ('y', 'CCONJ')
# ('triples', 'NOUN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('que', 'SCONJ')
# ('se', 'PRON')
# ('crease', 'VERB')
# ('algo', 'PRON')
# ('parecido', 'ADJ')
# ('a', 'ADP')
# ('un', 'DET')
# ('ataque', 'NOUN')
# ('interior', 'ADJ')
# ('para', 'ADP')
# ('equilibrar', 'VERB')
# ('las', 'DET')
# ('cosas', 'NOUN')
# ('contra', 'ADP')
# ('Sabas', 'PROPN')
# ('y', 'CCONJ')
# ('hacerle', '_')
# ('hacer', 'VERB')
# ('le', 'PRON')
# ('cometer', 'VERB')
# ('faltas', 'NOUN')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('Madrid', 'PROPN')
# ('temía', 'VERB')
# ('que', 'SCONJ')
# ('su', 'DET')
# ('eficaz', 'ADJ')
# ('defensa', 'NOUN')
# (',', 'PUNCT')
# ('con', 'ADP')
# ('un', 'DET')
# ('-', 'PUNCT')
# ('líbero', 'NOUN')
# ('-', 'PUNCT')
# ('como', 'SCONJ')
# ('García', 'PROPN')
# ('Coll', 'PROPN')
# ('metido', 'ADJ')
# ('en', 'ADP')
# ('la', 'DET')
# ('zona', 'NOUN')
# ('a', 'ADP')
# ('robar', 'VERB')
# ('balones', 'NOUN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('fue', 'AUX')
# ('posible', 'ADJ')
# ('tres', 'NUM')
# ('días', 'NOUN')
# ('antes', 'ADV')
# (',', 'PUNCT')
# ('ya', 'ADV')
# ('no', 'ADV')
# ('sería', 'AUX')
# ('tan', 'ADV')
# ('fácil', 'ADJ')
# ('ante', 'ADP')
# ('unos', 'DET')
# ('-', 'PUNCT')
# ('pequeños', 'ADJ')
# ('-', 'PUNCT')
# ('barcelonistas', 'NOUN')
# ('bien', 'ADV')
# ('aleccionados', 'ADJ')
# ('y', 'CCONJ')
# ('que', 'PRON')
# ('buscarían', 'VERB')
# ('el', 'DET')
# ('tiro', 'NOUN')
# ('en', 'ADP')
# ('vez', 'NOUN')
# ('de', 'ADP')
# ('quedarse', '_')
# ('quedar', 'VERB')
# ('se', 'PRON')
# ('incomprensiblemente', 'ADV')
# ('paralizados', 'ADJ')
# ('.', 'PUNCT')
# ('De', 'ADP')
# ('ahí', 'ADV')
# ('que', 'SCONJ')
# ('Clifford', 'PROPN')
# ('Luyk', 'PROPN')
# ('presentase', 'VERB')
# ('alineaciones', 'NOUN')
# ('clásicas', 'ADJ')
# ('.', 'PUNCT')
# ('Lo', 'PRON')
# ('que', 'PRON')
# ('sucede', 'VERB')
# ('es', 'AUX')
# ('que', 'SCONJ')
# ('las', 'DET')
# ('múltiples', 'ADJ')
# ('adaptaciones', 'NOUN')
# ('que', 'PRON')
# ('tenía', 'VERB')
# ('que', 'SCONJ')
# ('hacer', 'VERB')
# ('Aíto', 'PROPN')
# ('tenían', 'VERB')
# ('más', 'ADV')
# ('miga', 'NOUN')
# ('que', 'SCONJ')
# ('el', 'DET')
# ('retoque', 'NOUN')
# ('defensivo', 'ADJ')
# ('madridista', 'ADJ')
# ('(', 'PUNCT')
# ('que', 'PRON')
# (',', 'PUNCT')
# ('por', 'ADP')
# ('otra', 'NOUN')
# ('parte', 'NOUN')
# (',', 'PUNCT')
# ('funcionó', 'VERB')
# ('bien', 'ADV')
# (')', 'PUNCT')
# ('.', 'PUNCT')
# ('Y', 'CCONJ')
# ('la', 'DET')
# ('más', 'ADV')
# ('previsible', 'ADJ')
# ('por', 'ADP')
# ('todos', 'PRON')
# (',', 'PUNCT')
# ('esa', 'DET')
# ('zona', 'NOUN')
# ('2-3', 'NUM')
# ('para', 'ADP')
# ('ahogar', 'VERB')
# ('a', 'ADP')
# ('los', 'DET')
# ('grandes', 'ADJ')
# (',', 'PUNCT')
# ('resultó', 'VERB')
# ('de', 'ADP')
# ('patio', 'NOUN')
# ('de', 'ADP')
# ('colegio', 'NOUN')
# ('.', 'PUNCT')
# ('-', 'PUNCT')
# ('Por', 'ADP')
# ('qué', 'PRON')
# ('no', 'ADV')
# ('la', 'PRON')
# ('intentó', 'VERB')
# ('Aíto', 'PROPN')
# ('en', 'ADP')
# ('Madrid', 'PROPN')
# (',', 'PUNCT')
# ('donde', 'PRON')
# ('no', 'ADV')
# ('estaba', 'VERB')
# ('Kurtinaitis', 'PROPN')
# ('y', 'CCONJ')
# ('ningún', 'DET')
# ('blanco', 'NOUN')
# ('tiraba', 'VERB')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('sí', 'PRON')
# ('en', 'ADP')
# ('Barcelona', 'PROPN')
# ('?', 'PUNCT')
# ('Nunca', 'ADV')
# ('sabremos', 'VERB')
# ('la', 'DET')
# ('respuesta', 'NOUN')
# (',', 'PUNCT')
# ('pero', 'CCONJ')
# ('sí', 'INTJ')
# ('que', 'SCONJ')
# ('ahí', 'ADV')
# ('se', 'PRON')
# ('acabó', 'VERB')
# ('el', 'DET')
# ('partido', 'NOUN')
# ('de', 'ADP')
# ('ayer', 'ADV')
# ('.', 'PUNCT')
# ('Varios', 'DET')
# ('barcelonistas', 'NOUN')
# ('bajaron', 'VERB')
# ('ostensiblemente', 'ADV')
# ('los', 'DET')
# ('brazos', 'NOUN')
# ('Aíto', 'PROPN')
# ('se', 'PRON')
# ('lo', 'PRON')
# ('reprochaba', 'VERB')
# ('apenas', 'ADV')
# ('veladamente', 'ADV')
# ('en', 'ADP')
# ('el', 'DET')
# ('descanso', 'NOUN')
# (',', 'PUNCT')
# ('como', 'SCONJ')
# ('diciendo', 'VERB')
# ('-', 'PUNCT')
# ('si', 'SCONJ')
# ('también', 'ADV')
# ('de', 'ADP')
# ('lejos', 'ADV')
# ('nos', 'PRON')
# ('zurráis', 'VERB')
# (',', 'PUNCT')
# ('más', 'ADV')
# ('vale', 'VERB')
# ('irse', '_')
# ('ir', 'VERB')
# ('se', 'PRON')
# ('a', 'ADP')
# ('casa', 'NOUN')
# ('-', 'PUNCT')
# ('.', 'PUNCT')
# ('Hay', 'AUX')
# ('cosas', 'NOUN')
# ('que', 'PRON')
# ('este', 'DET')
# ('Barcelona', 'PROPN')
# ('no', 'ADV')
# ('podrá', 'VERB')
# ('quizá', 'ADV')
# ('nunca', 'ADV')
# ('resolver', 'VERB')
# ('contra', 'ADP')
# ('un', 'DET')
# ('Madrid', 'PROPN')
# ('en', 'ADP')
# ('buena', 'ADJ')
# ('forma', 'NOUN')
# ('.', 'PUNCT')
# ('Una', 'PRON')
# (',', 'PUNCT')
# ('general', 'ADJ')
# (':', 'PUNCT')
# ('la', 'DET')
# ('falta', 'NOUN')
# ('de', 'ADP')
# ('jugadores', 'NOUN')
# ('decisivos', 'ADJ')
# (',', 'PUNCT')
# ('hoy', 'ADV')
# ('que', 'PRON')
# ('Epi', 'PROPN')
# (',', 'PUNCT')
# ('¡', 'PUNCT')
# ('ay', 'INTJ')
# ('!', 'PUNCT')
# (',', 'PUNCT')
# ('ya', 'ADV')
# ('sólo', 'ADV')
# ('puede', 'AUX')
# ('ser', 'AUX')
# ('un', 'DET')
# ('recurso', 'NOUN')
# ('táctico', 'ADJ')
# ('.', 'PUNCT')
# ('Otra', 'PRON')
# (',', 'PUNCT')
# ('más', 'ADV')
# ('específica', 'ADJ')
# (':', 'PUNCT')
# ('con', 'ADP')
# ('Norris', 'PROPN')
# ('y', 'CCONJ')
# ('Savic', 'PROPN')
# ('había', 'AUX')
# ('un', 'DET')
# ('verdadero', 'ADJ')
# ('juego', 'NOUN')
# ('interior', 'ADJ')
# ('en', 'ADP')
# ('el', 'DET')
# ('conjunto', 'NOUN')
# ('blaugrana', 'ADJ')
# (',', 'PUNCT')
# ('pero', 'CCONJ')
# ('con', 'ADP')
# ('un', 'DET')
# ('Roberts', 'PROPN')
# ('que', 'PRON')
# ('es', 'AUX')
# ('un', 'DET')
# ('alero', 'NOUN')
# ('alto', 'ADJ')
# (',', 'PUNCT')
# ('pero', 'CCONJ')
# ('endeble', 'ADJ')
# ('bajo', 'ADP')
# ('los', 'DET')
# ('aros', 'NOUN')
# ('(', 'PUNCT')
# ('vean', 'VERB')
# ('por', 'ADP')
# ('ejemplo', 'NOUN')
# ('sus', 'DET')
# ('totales', 'ADJ')
# ('reboteadores', 'NOUN')
# (')', 'PUNCT')
# (',', 'PUNCT')
# ('con', 'ADP')
# ('un', 'DET')
# ('Massenburg', 'PROPN')
# ('potentísimo', 'ADJ')
# ('pero', 'CCONJ')
# ('carente', 'ADJ')
# ('de', 'ADP')
# ('un', 'DET')
# ('solo', 'ADJ')
# ('movimiento', 'NOUN')
# ('ofensivo', 'ADJ')
# ('de', 'ADP')
# ('espaldas', 'NOUN')
# ('a', 'ADP')
# ('la', 'DET')
# ('canasta', 'NOUN')
# (',', 'PUNCT')
# ...
# ('y', 'CCONJ')
# ('la', 'DET')
# ('calle', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Coronel', 'PROPN')
# ('Sanfeliu', 'PROPN')
# ('habrá', 'AUX')
# ('dos', 'NUM')
# ('carriles', 'NOUN')
# ('reservados', 'ADJ')
# ('para', 'ADP')
# ('la', 'DET')
# ('circulación', 'NOUN')
# ('-', 'PUNCT')
# ('-', 'PUNCT')
# ('en', 'ADP')
# ('las', 'DET')
# ('circunstancias', 'NOUN')
# ('en', 'ADP')
# ('que', 'PRON')
# ('esté', 'AUX')
# ('permitida', 'ADJ')
# ('-', 'PUNCT')
# ('-', 'PUNCT')
# ('y', 'CCONJ')
# ('la', 'DET')
# ('carga', 'NOUN')
# ('y', 'CCONJ')
# ('descarga', 'NOUN')
# ('.', 'PUNCT')
# ('En', 'ADP')
# ('el', 'DET')
# ('resto', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('calle', 'NOUN')
# ('se', 'PRON')
# ('reservará', 'VERB')
# ('un', 'DET')
# ('solo', 'ADJ')
# ('carril', 'NOUN')
# ('.', 'PUNCT')
# ('Durante', 'ADP')
# ('las', 'DET')
# ('obras', 'NOUN')
# (',', 'PUNCT')
# ('los', 'DET')
# ('comerciantes', 'NOUN')
# ('y', 'CCONJ')
# ('propietarios', 'NOUN')
# ('de', 'ADP')
# ('fincas', 'NOUN')
# ('que', 'PRON')
# ('lo', 'PRON')
# ('deseen', 'VERB')
# ('podrán', 'AUX')
# ('acogerse', '_')
# ('acoger', 'VERB')
# ('se', 'PRON')
# ('a', 'ADP')
# ('una', 'DET')
# ('campaña', 'NOUN')
# ('de', 'ADP')
# ('rehabilitación', 'NOUN')
# ('de', 'ADP')
# ('fachadas', 'NOUN')
# ('que', 'PRON')
# ('contará', 'VERB')
# ('con', 'ADP')
# ('bonificaciones', 'NOUN')
# ('gestionadas', 'ADJ')
# ('por', 'ADP')
# ('la', 'DET')
# ('Agencia', 'PROPN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Paisaje', 'PROPN')
# ('Urbano', 'PROPN')
# ('.', 'PUNCT')
# ('Mari', 'PROPN')
# ('Carmen', 'PROPN')
# ('Arévalo', 'PROPN')
# (',', 'PUNCT')
# ('presidenta', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('Associació', 'PROPN')
# ('de', 'ADP')
# ('Botiguers', 'PROPN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Clot', 'PROPN')
# (',', 'PUNCT')
# ('muestra', 'VERB')
# ('su', 'DET')
# ('satisfacción', 'NOUN')
# ('por', 'ADP')
# ('la', 'DET')
# ('próxima', 'ADJ')
# ('reforma', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('calle', 'NOUN')
# ('que', 'PRON')
# ('pondrá', 'VERB')
# ('fin', 'NOUN')
# ('a', 'ADP')
# ('la', 'DET')
# ('actual', 'ADJ')
# ('imagen', 'NOUN')
# ('degradada', 'ADJ')
# ('.', 'PUNCT')
# ('"', 'PUNCT')
# ('Lo', 'PRON')
# ('estamos', 'AUX')
# ('reclamando', 'VERB')
# ('desde', 'ADP')
# ('hace', 'VERB')
# ('15', 'NUM')
# ('años', 'NOUN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('asegura', 'VERB')
# ('.', 'PUNCT')
# ('Los', 'DET')
# ('comerciantes', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('calle', 'NOUN')
# ('muestran', 'VERB')
# ('su', 'DET')
# ('desacuerdo', 'NOUN')
# ('con', 'ADP')
# ('"', 'PUNCT')
# ('una', 'DET')
# ('peatonalización', 'NOUN')
# ('total', 'ADJ')
# ('"', 'PUNCT')
# ('.', 'PUNCT')
# ('"', 'PUNCT')
# ('Nosotros', 'PRON')
# ('pedimos', 'VERB')
# ('aceras', 'NOUN')
# ('anchas', 'ADJ')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('desde', 'ADP')
# ('el', 'DET')
# ('ayuntamiento', 'NOUN')
# ('siempre', 'ADV')
# ('nos', 'PRON')
# ('habían', 'AUX')
# ('hablado', 'VERB')
# ('de', 'ADP')
# ('semipeatonalización', 'NOUN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('añade', 'VERB')
# ('Arévalo', 'PROPN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('aboga', 'VERB')
# ('por', 'ADP')
# ('que', 'SCONJ')
# ('a', 'ADP')
# ('determinadas', 'ADJ')
# ('horas', 'NOUN')
# ('se', 'PRON')
# ('permita', 'VERB')
# ('la', 'DET')
# ('circulación', 'NOUN')
# ('bajando', 'VERB')
# ('los', 'DET')
# ('pilones', 'NOUN')
# ('.', 'PUNCT')
# ('Junto', 'ADJ')
# ('con', 'ADP')
# ('la', 'DET')
# ('calle', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Clot', 'PROPN')
# (',', 'PUNCT')
# ('el', 'DET')
# ('ayuntamiento', 'NOUN')
# ('también', 'ADV')
# ('convertirá', 'VERB')
# ('en', 'ADP')
# ('peatonal', 'ADJ')
# ('el', 'DET')
# ('pasaje', 'NOUN')
# ('de', 'ADP')
# ('Vintró', 'PROPN')
# ('.', 'PUNCT')
# ('"', 'PUNCT')
# ('El', 'DET')
# ('pasaje', 'NOUN')
# ('se', 'PRON')
# ('humanizará', 'VERB')
# ('cerrándolo', '_')
# ('cerrando', 'VERB')
# ('lo', 'PRON')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('tráfico', 'NOUN')
# ('y', 'CCONJ')
# ('al', '_')
# ('a', 'ADP')
# ('el', 'DET')
# ('estacionamiento', 'NOUN')
# ('de', 'ADP')
# ('coches', 'NOUN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('explica', 'VERB')
# ('Narváez', 'PROPN')
# ('.', 'PUNCT')
# ('"', 'PUNCT')
# ('La', 'DET')
# ('peatonalización', 'NOUN')
# ('-', 'PUNCT')
# ('-', 'PUNCT')
# ('añade', 'VERB')
# ('-', 'PUNCT')
# ('-', 'PUNCT')
# ('complementará', 'VERB')
# ('el', 'DET')
# ('uso', 'NOUN')
# ('lúdico', 'ADJ')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('pasaje', 'NOUN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('el', 'DET')
# ('que', 'PRON')
# ('se', 'PRON')
# ('encuentra', 'VERB')
# ('el', 'DET')
# ('polideportivo', 'NOUN')
# ('Vintró', 'PROPN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('cuenta', 'VERB')
# ('con', 'ADP')
# ('3.000', 'NUM')
# ('abonados', 'NOUN')
# ('y', 'CCONJ')
# ('una', 'DET')
# ('lista', 'NOUN')
# ('de', 'ADP')
# ('espera', 'NOUN')
# ('de', 'ADP')
# ('2.000', 'NOUN')
# ('.', 'PUNCT')
# ('Voces', 'NOUN')
# ('de', 'ADP')
# ('un', 'DET')
# ('ayer', 'NOUN')
# ('que', 'PRON')
# ('marcó', 'VERB')
# ('época', 'NOUN')
# ('y', 'CCONJ')
# ('estrellas', 'NOUN')
# ('de', 'ADP')
# ('las', 'DET')
# ('ondas', 'NOUN')
# ('de', 'ADP')
# ('hoy', 'ADV')
# (',', 'PUNCT')
# ('políticos', 'NOUN')
# ('de', 'ADP')
# ('ese', 'DET')
# ('centro', 'NOUN')
# ('que', 'PRON')
# ('se', 'PRON')
# ('disputan', 'VERB')
# ('desde', 'ADP')
# ('todas', 'DET')
# ('direcciones', 'NOUN')
# (',', 'PUNCT')
# ('deportistas', 'NOUN')
# (',', 'PUNCT')
# ('artistas', 'NOUN')
# ('y', 'CCONJ')
# ('altos', 'ADJ')
# ('ejecutivos', 'NOUN')
# ('de', 'ADP')
# ('medios', 'NOUN')
# ('de', 'ADP')
# ('comunicación', 'NOUN')
# ('se', 'PRON')
# ('reunieron', 'VERB')
# ('el', 'DET')
# ('Martes', 'NOUN')
# ('por', 'ADP')
# ('la', 'DET')
# ('noche', 'NOUN')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('las', 'DET')
# ('Reales', 'PROPN')
# ('Atarazanas', 'PROPN')
# (',', 'PUNCT')
# ('para', 'ADP')
# ('celebrar', 'VERB')
# ('el', 'DET')
# ('50º', 'NUM')
# ('aniversario', 'NOUN')
# ('de', 'ADP')
# ('Radio', 'PROPN')
# ('Nacional', 'PROPN')
# ('de', 'ADP')
# ('España', 'PROPN')
# ('en', 'ADP')
# ('Catalunya', 'PROPN')
# ('.', 'PUNCT')
# ('Toda', 'DET')
# ('una', 'DET')
# ('proeza', 'NOUN')
# (',', 'PUNCT')
# ('tanto', 'ADV')
# ('por', 'ADP')
# ('ese', 'DET')
# ('medio', 'NUM')
# ('siglo', 'NOUN')
# ('como', 'SCONJ')
# ('por', 'ADP')
# ('la', 'DET')
# ('sensibilidad', 'NOUN')
# ('para', 'ADP')
# ('con', 'ADP')
# ('su', 'DET')
# ('entorno', 'NOUN')
# ('social', 'ADJ')
# ('.', 'PUNCT')
# ('Carlos', 'PROPN')
# ('Herrera', 'PROPN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('se', 'PRON')
# ('expresó', 'VERB')
# ('en', 'ADP')
# ('catalán', 'NOUN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('Margarida', 'PROPN')
# ('Lluch', 'PROPN')
# ('presentaron', 'VERB')
# ('el', 'DET')
# ('acto', 'NOUN')
# (',', 'PUNCT')
# ('abierto', 'ADJ')
# ('con', 'ADP')
# ('un', 'DET')
# ('audiovisual', 'NOUN')
# ('de', 'ADP')
# ('momentos', 'NOUN')
# ('emblemáticos', 'ADJ')
# ('(', 'PUNCT')
# ('el', 'DET')
# ('"', 'PUNCT')
# ('ja', 'ADV')
# ('sóc', 'NOUN')
# ('aquí', 'ADV')
# ('"', 'PUNCT')
# ('de', 'ADP')
# ('Tarradellas', 'PROPN')
# ('o', 'CCONJ')
# ('el', 'DET')
# ('inicio', 'NOUN')
# ('de', 'ADP')
# ('los', 'DET')
# ('Juegos', 'PROPN')
# ('Olímpicos', 'PROPN')
# ('en', 'ADP')
# ('boca', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('rey', 'NOUN')
# ('Juan', 'PROPN')
# ('Carlos', 'PROPN')
# (')', 'PUNCT')
# (',', 'PUNCT')
# ('sintonías', 'NOUN')
# ('(', 'PUNCT')
# ('De', 'ADP')
# ('España', 'PROPN')
# ('para', 'ADP')
# ('los', 'DET')
# ('españoles', 'PROPN')
# (',', 'PUNCT')
# ('Elena', 'PROPN')
# ('Francis', 'PROPN')
# (',', 'PUNCT')
# ('Fantasía', 'PROPN')
# (',', 'PUNCT')
# ('Protagonistas', 'PROPN')
# ('nosotros', 'PRON')
# ('...', 'PUNCT')
# (')', 'PUNCT')
# ('y', 'CCONJ')
# ('hasta', 'ADV')
# ('anuncios', 'NOUN')
# ('(', 'PUNCT')
# ('Telefunken', 'PROPN')
# (',', 'PUNCT')
# ('La', 'DET')
# ('Lechera', 'PROPN')
# (')', 'PUNCT')
# ('.', 'PUNCT')
# ('Entre', 'ADP')
# ('la', 'DET')
# ('audiencia', 'NOUN')
# ('se', 'PRON')
# ('podía', 'AUX')
# ('ver', 'VERB')
# ('a', 'ADP')
# ('políticos', 'NOUN')
# ('como', 'SCONJ')
# ('Enrique', 'PROPN')
# ('Lacalle', 'PROPN')
# (';', 'PUNCT')
# ('el', 'DET')
# ('conseller', 'NOUN')
# ('de', 'ADP')
# ('Presidència', 'PROPN')
# ('de', 'ADP')
# ('la', 'DET')
# ('Generalitat', 'PROPN')
# (',', 'PUNCT')
# ('Xavier', 'PROPN')
# ('Trias', 'PROPN')
# (';', 'PUNCT')
# ('el', 'DET')
# ('ministro', 'NOUN')
# ('Josep', 'PROPN')
# ('Piqué', 'PROPN')
# ('y', 'CCONJ')
# ('la', 'DET')
# ('delegada', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Gobierno', 'PROPN')
# (',', 'PUNCT')
# ('Julia', 'PROPN')
# ('García-Valdecasas', 'PROPN')
# ('.', 'PUNCT')
# ('También', 'ADV')
# ('actuales', 'ADJ')
# ('cargos', 'NOUN')
# ('de', 'ADP')
# ('RTVE', 'PROPN')
# ('como', 'SCONJ')
# ('Javier', 'PROPN')
# ('González', 'PROPN')
# ('Ferrari', 'PROPN')
# ('y', 'CCONJ')
# ('Javier', 'PROPN')
# ('Grima', 'PROPN')
# (',', 'PUNCT')
# ('además', 'ADV')
# ('de', 'ADP')
# ('la', 'DET')
# ('antecesora', 'NOUN')
# ('de', 'ADP')
# ('éste', 'PRON')
# ('en', 'ADP')
# ('Sant', 'PROPN')
# ('Cugat', 'PROPN')
# (',', 'PUNCT')
# ('Aurora', 'PROPN')
# ('Catà', 'PROPN')
# (';', 'PUNCT')
# ('colegas', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('competencia', 'NOUN')
# ('como', 'SCONJ')
# ('Jordi', 'PROPN')
# ('Vilajoana', 'PROPN')
# ('y', 'CCONJ')
# ('Enric', 'PROPN')
# ('Sopena', 'PROPN')
# (';', 'PUNCT')
# ('el', 'DET')
# ('EX', 'PRON')
# ('de', 'ADP')
# ('la', 'DET')
# ('casa', 'NOUN')
# ('y', 'CCONJ')
# ('abogado', 'NOUN')
# ('Ricard', 'PROPN')
# ('Fernández', 'PROPN')
# ('Deu', 'PRON')
# (';', 'PUNCT')
# ('así', 'ADV')
# ('como', 'SCONJ')
# ('el', 'DET')
# ('analista', 'NOUN')
# ('político', 'ADJ')
# ('Fernando', 'PROPN')
# ('Jáuregui', 'PROPN')
# (',', 'PUNCT')
# ('el', 'DET')
# ('director', 'NOUN')
# ('teatral', 'ADJ')
# ('Lluís', 'PROPN')
# ('Pasqual', 'PROPN')
# ('y', 'CCONJ')
# ('el', 'DET')
# ('campeón', 'NOUN')
# ('motociclista', 'ADJ')
# ('Sito', 'PROPN')
# ('Pons', 'PROPN')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('director', 'NOUN')
# ('de', 'ADP')
# ('RNE', 'PROPN')
# (',', 'PUNCT')
# ('Diego', 'PROPN')
# ('Armario', 'PROPN')
# (',', 'PUNCT')
# ('aseguró', 'VERB')
# ('que', 'SCONJ')
# ('sus', 'DET')
# ('emisoras', 'NOUN')
# ('y', 'CCONJ')
# ('los', 'DET')
# ('profesionales', 'NOUN')
# ('están', 'AUX')
# ('"', 'PUNCT')
# ('preparados', 'ADJ')
# ('para', 'ADP')
# ('la', 'DET')
# ('radio', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('2000', 'NOUN')
# ('"', 'PUNCT')
# ('.', 'PUNCT')
# ('Fue', 'AUX')
# ('entonces', 'ADV')
# ('el', 'DET')
# ('momento', 'NOUN')
# ('de', 'ADP')
# ('homenajear', 'VERB')
# ('a', 'ADP')
# ('dos', 'NUM')
# ('"', 'PUNCT')
# ('personajes', 'NOUN')
# ('singulares', 'ADJ')
# ('que', 'PRON')
# ('representan', 'VERB')
# ('a', 'ADP')
# ('otros', 'DET')
# ('muchos', 'PRON')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('Jorge', 'PROPN')
# ('Arandes', 'PROPN')
# ('y', 'CCONJ')
# ('Joan', 'PROPN')
# ('Viñas', 'PROPN')
# (',', 'PUNCT')
# ('que', 'PRON')
# ('recibieron', 'VERB')
# ('dos', 'NUM')
# ('litografías', 'NOUN')
# ('y', 'CCONJ')
# ('el', 'DET')
# ('aplauso', 'NOUN')
# ('de', 'ADP')
# ('estrellas', 'NOUN')
# ('actuales', 'ADJ')
# ('de', 'ADP')
# ('las', 'DET')
# ('ondas', 'NOUN')
# ('tan', 'ADV')
# ('dispares', 'ADJ')
# ('como', 'SCONJ')
# ('Josep', 'PROPN')
# ('Cuní', 'PROPN')
# ('y', 'CCONJ')
# ('Nieves', 'PROPN')
# ('Herrero', 'PROPN')
# ('.', 'PUNCT')
# ('Hubo', 'AUX')
# (',', 'PUNCT')
# ('sin', 'ADP')
# ('embargo', 'NOUN')
# (',', 'PUNCT')
# ('un', 'DET')
# ('desliz', 'NOUN')
# ('protocolario', 'ADJ')
# (',', 'PUNCT')
# ('ya', 'ADV')
# ('que', 'SCONJ')
# ('Arandes', 'PROPN')
# ('y', 'CCONJ')
# ('Viñas', 'PROPN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('sus', 'DET')
# ('esposas', 'NOUN')
# (',', 'PUNCT')
# ('pasaron', 'VERB')
# ('la', 'DET')
# ('velada', 'NOUN')
# ('en', 'ADP')
# ('una', 'DET')
# ('mesa', 'NOUN')
# ('sin', 'ADP')
# ('más', 'ADV')
# ('compañía', 'NOUN')
# ('.', 'PUNCT')
# ('Pío', 'PROPN')
# ('Cabanillas', 'PROPN')
# (',', 'PUNCT')
# ('director', 'NOUN')
# ('general', 'ADJ')
# ('de', 'ADP')
# ('RTVE', 'PROPN')
# (',', 'PUNCT')
# ('resaltó', 'VERB')
# ('que', 'SCONJ')
# ('este', 'DET')
# ('aniversario', 'NOUN')
# ('"', 'PUNCT')
# ('no', 'ADV')
# ('es', 'AUX')
# ('un', 'DET')
# ('punto', 'NOUN')
# ('de', 'ADP')
# ('llegada', 'NOUN')
# (',', 'PUNCT')
# ('sino', 'CCONJ')
# ('el', 'DET')
# ('inicio', 'NOUN')
# ('de', 'ADP')
# ('una', 'DET')
# ('nueva', 'ADJ')
# ('etapa', 'NOUN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('concluyó', 'VERB')
# (':', 'PUNCT')
# ('"', 'PUNCT')
# ('Levanto', 'VERB')
# ('una', 'DET')
# ('barretina', 'NOUN')
# ('por', 'ADP')
# ('RTVE', 'PROPN')
# ('"', 'PUNCT')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('homenaje', 'NOUN')
# ('a', 'ADP')
# ('su', 'DET')
# ('padre', 'NOUN')
# (',', 'PUNCT')
# ('ex', 'ADJ')
# ('ministro', 'NOUN')
# ('de', 'ADP')
# ('Información', 'PROPN')
# ('y', 'CCONJ')
# ('Turismo', 'PROPN')
# ('que', 'PRON')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('1974', 'NOUN')
# (',', 'PUNCT')
# ('como', 'SCONJ')
# ('señal', 'NOUN')
# ('de', 'ADP')
# ('aperturismo', 'NOUN')
# (',', 'PUNCT')
# ('se', 'PRON')
# ('puso', 'VERB')
# ('una', 'DET')
# ('barretina', 'NOUN')
# ('en', 'ADP')
# ('Barcelona', 'PROPN')
# ('en', 'ADP')
# ('favor', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('cultura', 'NOUN')
# ('catalana', 'ADJ')
# ('.', 'PUNCT')
# ('El', 'DET')
# ('presidente', 'NOUN')
# ('de', 'ADP')
# ('Cuba', 'PROPN')
# (',', 'PUNCT')
# ('Fidel', 'PROPN')
# ('Castro', 'PROPN')
# (',', 'PUNCT')
# ('desfiló', 'VERB')
# ('ayer', 'ADV')
# ('junto', 'ADJ')
# ('a', 'ADP')
# ('una', 'DET')
# ('niña', 'NOUN')
# ('de', 'ADP')
# ('seis', 'NUM')
# ('años', 'NOUN')
# ('y', 'CCONJ')
# ('portando', 'VERB')
# ('una', 'DET')
# ('bandera', 'NOUN')
# ('cubana', 'ADJ')
# ('ante', 'ADP')
# ('la', 'DET')
# ('Oficina', 'PROPN')
# ('de', 'ADP')
# ('Intereses', 'PROPN')
# ('de', 'ADP')
# ('Estados', 'PROPN')
# ('Unidos', 'PROPN')
# ('en', 'ADP')
# ('el', 'DET')
# ('centro', 'NOUN')
# ('de', 'ADP')
# ('La', 'DET')
# ('Habana', 'PROPN')
# ('.', 'PUNCT')
# ('Castro', 'PROPN')
# ('pasó', 'VERB')
# ('acompañado', 'ADJ')
# ('de', 'ADP')
# ('miles', 'NUM')
# ('de', 'ADP')
# ('cubanos', 'NOUN')
# ('sin', 'ADP')
# ('dejar', 'VERB')
# ('de', 'ADP')
# ('mirar', 'VERB')
# ('el', 'DET')
# ('edificio', 'NOUN')
# ('americano', 'ADJ')
# ('y', 'CCONJ')
# ('bajo', 'ADP')
# ('las', 'DET')
# ('consignas', 'NOUN')
# ('de', 'ADP')
# ('Cuba', 'PROPN')
# ('sí', 'INTJ')
# (',', 'PUNCT')
# ('yanquis', 'NOUN')
# ('no', 'INTJ')
# ('en', 'ADP')
# ('los', 'DET')
# ('actos', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Día', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('Trabajo', 'NOUN')
# ('.', 'PUNCT')
# ('Hace', 'VERB')
# ('unos', 'DET')
# ('años', 'NOUN')
# (',', 'PUNCT')
# ('con', 'ADP')
# ('la', 'DET')
# ('recuperación', 'NOUN')
# ('de', 'ADP')
# ('la', 'DET')
# ('democracia', 'NOUN')
# ('y', 'CCONJ')
# ('las', 'DET')
# ('libertades', 'NOUN')
# (',', 'PUNCT')
# ('vivimos', 'VERB')
# ('con', 'ADP')
# ('regocijo', 'NOUN')
# ('libertador', 'ADJ')
# ('el', 'DET')
# ('momento', 'NOUN')
# ('en', 'ADP')
# ('que', 'PRON')
# ('nuestras', 'DET')
# ('compañeras', 'NOUN')
# (',', 'PUNCT')
# ('las', 'DET')
# ('mujeres', 'NOUN')
# (',', 'PUNCT')
# ('se', 'PRON')
# ('libraron', 'VERB')
# ('de', 'ADP')
# ('uno', 'PRON')
# ('de', 'ADP')
# ('los', 'DET')
# ('tabúes', 'NOUN')
# ('de', 'ADP')
# ('su', 'DET')
# ('sexo', 'NOUN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# ('empezaron', 'VERB')
# ('a', 'ADP')
# ('exhibir', 'VERB')
# (',', 'PUNCT')
# ('gozosas', 'ADJ')
# (',', 'PUNCT')
# ('en', 'ADP')
# ('playas', 'NOUN')
# ('y', 'CCONJ')
# ('piscinas', 'NOUN')
# (',', 'PUNCT')
# ('sus', 'DET')
# ('senos', 'NOUN')
# ('secularmente', 'ADV')
# ('escondidos', 'ADJ')
# ('.', 'PUNCT')
# ('Las', 'DET')
# ('tetas', 'NOUN')
# ('saltaron', 'VERB')
# ('a', 'ADP')
# ('la', 'DET')
# ('palestra', 'NOUN')
# ('y', 'CCONJ')
# ('se', 'PRON')
# ('reivindicaron', 'VERB')
# ('en', 'ADP')
# ('todas', 'DET')
# ('sus', 'DET')
# ('formas', 'NOUN')
# (',', 'PUNCT')
# ('tamaños', 'NOUN')
# ('y', 'CCONJ')
# ('colores', 'NOUN')
# (',', 'PUNCT')
# ('y', 'CCONJ')
# (',', 'PUNCT')
# ('todos', 'PRON')
# ('creíamos', 'VERB')
# ('que', 'SCONJ')
# ('ya', 'ADV')
# ('jamás', 'ADV')
# ('se', 'PRON')
# ('volverían', 'VERB')
# ('a', 'ADP')
# ('ocultar', 'VERB')
# ('.', 'PUNCT')
# ('Craso', 'ADJ')
# ('error', 'NOUN')
# ('.', 'PUNCT')
# ('Una', 'DET')
# ('visita', 'NOUN')
# ('a', 'ADP')
# ('la', 'DET')
# ('playa', 'NOUN')
# ('recién', 'ADV')
# ('inaugurada', 'ADJ')
# ('nos', 'PRON')
# ('informará', 'VERB')
# ('de', 'ADP')
# ('que', 'SCONJ')
# ('todo', 'PRON')
# ('había', 'AUX')
# ('sido', 'AUX')
# ('un', 'DET')
# ('espejismo', 'NOUN')
# ('.', 'PUNCT')
# ('Los', 'DET')
# ('pechos', 'NOUN')
# ('femeninos', 'ADJ')
# ('vuelven', 'VERB')
# ('a', 'ADP')
# ('estar', 'AUX')
# ('tapados', 'ADJ')
# ('.', 'PUNCT')
# ('¿', 'PUNCT')
# ('Será', 'AUX')
# ('que', 'SCONJ')
# ('el', 'DET')
# ('tabú', 'NOUN')
# ('del', '_')
# ('de', 'ADP')
# ('el', 'DET')
# ('seno', 'NOUN')
# ('materno', 'ADJ')
# ('es', 'AUX')
# ('demasiado', 'ADV')
# ('fuerte', 'ADJ')
# ('para', 'ADP')
# ('destruirlo', '_')
# ('destruir', 'VERB')
# ('lo', 'PRON')
# ('?', 'PUNCT')
# ('.', 'PUNCT')
# ('¿', 'PUNCT')
# ('O', 'CCONJ')
# ('que', 'SCONJ')
# ('los', 'DET')
# ('varones', 'NOUN')
# ('mirábamos', 'VERB')
# ('con', 'ADP')
# ('demasiada', 'DET')
# ('avidez', 'NOUN')
# ('?', 'PUNCT')
# ('.', 'PUNCT')
# ('Lo', 'PRON')
# ('cierto', 'ADJ')
# ('es', 'AUX')
# ('que', 'SCONJ')
# ('a', 'ADP')
# ('mí', 'PRON')
# (',', 'PUNCT')
# ('me', 'PRON')
# ('da', 'VERB')
# ('un', 'DET')
# ('poco', 'PRON')
# ('de', 'ADP')
# ('pena', 'NOUN')
# ('.', 'PUNCT')

# %%
data_file = open("UD_Spanish-AnCora/es_ancora-ud-dev.conllu", "r", encoding="utf-8")

wordList = []
for tokenlist in parse_incr(data_file): 
    wordList2 = []
    for token in tokenlist:
        wordList2.append((token['form'],token['upos']))
    wordList.append(wordList2)

# %%
len(word_tag),len(wordList)
# Out:
# (54685, 1654)

# %% [markdown]
# 2. **Entrenamiento:** Una vez que el dataset esta con la estructura correcta, utiliza la clase `hmm.HiddenMarkovModelTrainer()` para entrenar con el $80 \%$ del dataset como conjunto de `entrenamiento` y $20 \%$ para el conjunto de `test`.
#
# **Ayuda:** Para la separacion entre conjuntos de entrenamiento y test, puedes usar la funcion de Scikit Learn:
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# En este punto el curso de Machine Learning con Scikit Learn es un buen complemento para entender mejor las funcionalidades de Scikit Learn: https://platzi.com/cursos/scikitlearn-ml/

# %%
data_train,data_test = train_test_split(wordList, test_size = 0.2,random_state = 42)

# %%
tagger = hmm.HiddenMarkovModelTagger.train(data_train)

# %%
tagger.evaluate(data_train)
# Out:
# 0.969611436115727

# %%
tagger.evaluate(data_test)

# %% [markdown]
# # Modelo Markoviano de Máxima Entropia

# %% [markdown]
# La diferencia entre el modelo markoviano latente, es que en este caso, las probabilidades se calculan de una manera mas sencilla ó en un solo Paso.
#
# * Dada una palabra o una etiqueta anterior, cual es la probabilidad de que se de una etiqueta actual. es decir, el espacio muestral se ve reducido en conjunto a la condición de que el evento de una etiqueta anterior y una palabra ya se presentaron, por tanto, se calcula la probabilidad de que se de una etiqueta en la posición actual con esos dos datos.
# * No se usa especificamente la regla de bayes para calcular la probabilidad de emisión y transición, contrario al modelo Markoviano latente el cual si la usa.
# * En este caso se estan creando nuevas dependencias, es decir una probabilidad que no se descompone
#
# ![](.\MEMM.PNG)

# %% [markdown]
# * El modelo markoviano de maxima entropia, gira en torno al calculo de la probabilidad que se de una etiqueta en la posición actual, la cual recibe como insumo o condiciones las probabilidades de que ya se dió una etiqueta anterior, posterior y una palabra anterior, actual y posterior.
# * En este caso, el MEMM a diferencia del HMM, calcula una probabilidad a posteriori, hablando en el contexto del teorema de Bayes, es decir, dada unas circustancias del entorno que ya se dieron, cual es la probabilidad que se de una etiqueta en esta posición.
# * El HMM se concentra en la probabilidad a priori, el cual dada la probabilidad de transición, de que se de una etiqueta dada una etiqueta anterior por la probabilidad de emisión, es decir el primer dato que se obtiene por la probabilidad de que se de una palabra dado que se tiene una etiqueta.
# * En conclusión, dado un contexto al rededor de una etiqueta particular, cual es la probabilidad de que esa categoria sea cierta etiqueta gramatical. Esto tambien se conoce como un Hiper-parametro conocido como Window Size
#
# $$
# P(t_i|w_i,t_{i-1}) = \frac{C(w_i,t_{i-1},t_i)}{C(w_i,t_{i-1})}
# $$
#
# * El calculo se realiza bajo un esquema de conteo de frecuencias de las se cuencias de palabras y etiquetas en el corpus.
# * Cantidad de veces que se observa la palabra con cierta etiqueta anterior y cierta etiqueta actual.
# * Dividido en la cantidad de veces que se observa la palabra con la etiqueta anterior.

# %% [markdown]
# ## Algoritmo de Viterbi para MEMM
#
# Se aplica una ligera modificación, la probabilidad de la primera palabra se calcula como la probabilidad maxima entre el producto de la probabilidad de que dado un contexto se de una etiqueta en la posición actual.
#
# * La probabilidad a posterior, dada la probabilidad de la secuencia anterior por la probabilidad de que dado un contexto se de una etiqueta en la posición actual
#
# ![](.\viterbiMEMM.PNG)

# %% [markdown]
# ## Clasificación de Texto.

# %% [markdown]
# Para el desarrollo de un modelo se deben realizar un proceso de extracción de caracteristicas, tales como:
# - Tema de conservación
# - Sentimiento
# - Etiquetas
#
# Se deben vectorizar hasta cierto punto los atributos de cada uno de los datapoints para cada documento, dado unos atributos se debe llegar a una etiqueta.
#
# ### Tecnicas de Clasificación:
# - Basadas en teoria de la probabilidad
# - Basadas en teoria de la información
# - Basadas en espacios vectoriales
#
# ### Clasificación de Palabras:
# - Identificación de genero de nombres
# - Etiquetado POS (Categorias gramaticales)
# - Bloqueo de palabras ofensivas
#
# ### Clasificación de documentos:
# - Analisis de sentimientos
# - Topicos de conversación
# - Priorización de CRM

# %%
import nltk, random
from nltk.corpus import names

def atributos(palabra):
    return {'letra_f':palabra[-1]}

tagset = [
    
    (n, 'M'/'F') for n in names.words('')
]
